# %%
from argparse import Namespace
from nltk.tokenize import word_tokenize
import numpy as np
import pandas as pd

# %%
args = Namespace(
    source_data_path="data/nmt/eng-fra.txt",
    output_data_path="data/nmt/simplest_eng_fra.csv",
    perc_train=0.7,
    perc_val=0.15,
    perc_test=0.15,
    seed=1337
)

assert args.perc_test > 0 and (args.perc_test + args.perc_val + args.perc_train == 1.0)

# %%
with open(args.source_data_path, encoding="utf-8") as fp:
    lines = fp.readlines()
    
lines = [line.replace("\n", "").lower().split("\t") for line in lines]

# %%
data = []
for english_sentence, french_sentence in lines:
    data.append({"english_tokens": word_tokenize(english_sentence, language="english"),
                 "french_tokens": word_tokenize(french_sentence, language="french")})

# %%
data
# Out:
# [{'english_tokens': ['go', '.'], 'french_tokens': ['va', '!']},
#  {'english_tokens': ['run', '!'], 'french_tokens': ['cours', '!']},
#  {'english_tokens': ['run', '!'], 'french_tokens': ['courez', '!']},
#  {'english_tokens': ['wow', '!'], 'french_tokens': ['ça', 'alors', '!']},
#  {'english_tokens': ['fire', '!'], 'french_tokens': ['au', 'feu', '!']},
#  {'english_tokens': ['help', '!'], 'french_tokens': ['à', "l'aide", '!']},
#  {'english_tokens': ['jump', '.'], 'french_tokens': ['saute', '.']},
#  {'english_tokens': ['stop', '!'], 'french_tokens': ['ça', 'suffit', '!']},
#  {'english_tokens': ['stop', '!'], 'french_tokens': ['stop', '!']},
#  {'english_tokens': ['stop', '!'], 'french_tokens': ['arrête-toi', '!']},
#  {'english_tokens': ['wait', '!'], 'french_tokens': ['attends', '!']},
#  {'english_tokens': ['wait', '!'], 'french_tokens': ['attendez', '!']},
#  {'english_tokens': ['i', 'see', '.'],
#   'french_tokens': ['je', 'comprends', '.']},
#  {'english_tokens': ['i', 'try', '.'], 'french_tokens': ["j'essaye", '.']},
#  {'english_tokens': ['i', 'won', '!'],
#   'french_tokens': ["j'ai", 'gagné', '!']},
#  {'english_tokens': ['i', 'won', '!'],
#   'french_tokens': ['je', "l'ai", 'emporté', '!']},
#  {'english_tokens': ['oh', 'no', '!'], 'french_tokens': ['oh', 'non', '!']},
#  {'english_tokens': ['attack', '!'], 'french_tokens': ['attaque', '!']},
#  {'english_tokens': ['attack', '!'], 'french_tokens': ['attaquez', '!']},
#  {'english_tokens': ['cheers', '!'], 'french_tokens': ['santé', '!']},
#  {'english_tokens': ['cheers', '!'],
#   'french_tokens': ['à', 'votre', 'santé', '!']},
#  {'english_tokens': ['cheers', '!'], 'french_tokens': ['merci', '!']},
#  {'english_tokens': ['get', 'up', '.'], 'french_tokens': ['lève-toi', '.']},
#  {'english_tokens': ['got', 'it', '!'],
#   'french_tokens': ["j'ai", 'pigé', '!']},
#  {'english_tokens': ['got', 'it', '!'], 'french_tokens': ['compris', '!']},
#  {'english_tokens': ['got', 'it', '?'], 'french_tokens': ['pigé', '?']},
#  {'english_tokens': ['got', 'it', '?'], 'french_tokens': ['compris', '?']},
#  {'english_tokens': ['got', 'it', '?'],
#   'french_tokens': ["t'as", 'capté', '?']},
#  {'english_tokens': ['hop', 'in', '.'], 'french_tokens': ['monte', '.']},
#  {'english_tokens': ['hop', 'in', '.'], 'french_tokens': ['montez', '.']},
#  {'english_tokens': ['hug', 'me', '.'],
#   'french_tokens': ['serre-moi', 'dans', 'tes', 'bras', '!']},
#  {'english_tokens': ['hug', 'me', '.'],
#   'french_tokens': ['serrez-moi', 'dans', 'vos', 'bras', '!']},
#  {'english_tokens': ['i', 'fell', '.'],
#   'french_tokens': ['je', 'suis', 'tombée', '.']},
#  {'english_tokens': ['i', 'fell', '.'],
#   'french_tokens': ['je', 'suis', 'tombé', '.']},
#  {'english_tokens': ['i', 'know', '.'], 'french_tokens': ['je', 'sais', '.']},
#  {'english_tokens': ['i', 'left', '.'],
#   'french_tokens': ['je', 'suis', 'parti', '.']},
#  {'english_tokens': ['i', 'left', '.'],
#   'french_tokens': ['je', 'suis', 'partie', '.']},
#  {'english_tokens': ['i', 'lost', '.'],
#   'french_tokens': ["j'ai", 'perdu', '.']},
#  {'english_tokens': ['i', "'m", '19', '.'],
#   'french_tokens': ["j'ai", '19', 'ans', '.']},
#  {'english_tokens': ['i', "'m", 'ok', '.'],
#   'french_tokens': ['je', 'vais', 'bien', '.']},
#  {'english_tokens': ['i', "'m", 'ok', '.'],
#   'french_tokens': ['ça', 'va', '.']},
#  {'english_tokens': ['listen', '.'], 'french_tokens': ['écoutez', '!']},
#  {'english_tokens': ['no', 'way', '!'], 'french_tokens': ['impossible', '!']},
#  {'english_tokens': ['no', 'way', '!'],
#   'french_tokens': ['en', 'aucun', 'cas', '.']},
#  {'english_tokens': ['no', 'way', '!'],
#   'french_tokens': ["c'est", 'hors', 'de', 'question', '!']},
#  {'english_tokens': ['no', 'way', '!'],
#   'french_tokens': ['il', "n'en", 'est', 'pas', 'question', '!']},
#  {'english_tokens': ['no', 'way', '!'],
#   'french_tokens': ["c'est", 'exclu', '!']},
#  {'english_tokens': ['no', 'way', '!'],
#   'french_tokens': ['en', 'aucune', 'manière', '!']},
#  {'english_tokens': ['no', 'way', '!'],
#   'french_tokens': ['hors', 'de', 'question', '!']},
#  {'english_tokens': ['really', '?'], 'french_tokens': ['vraiment', '?']},
#  {'english_tokens': ['really', '?'], 'french_tokens': ['vrai', '?']},
#  {'english_tokens': ['really', '?'], 'french_tokens': ['ah', 'bon', '?']},
#  {'english_tokens': ['thanks', '.'], 'french_tokens': ['merci', '!']},
#  {'english_tokens': ['we', 'try', '.'],
#   'french_tokens': ['on', 'essaye', '.']},
#  {'english_tokens': ['we', 'won', '.'],
#   'french_tokens': ['nous', 'avons', 'gagné', '.']},
#  {'english_tokens': ['we', 'won', '.'],
#   'french_tokens': ['nous', 'gagnâmes', '.']},
#  {'english_tokens': ['we', 'won', '.'],
#   'french_tokens': ['nous', "l'avons", 'emporté', '.']},
#  {'english_tokens': ['we', 'won', '.'],
#   'french_tokens': ['nous', "l'emportâmes", '.']},
#  {'english_tokens': ['ask', 'tom', '.'],
#   'french_tokens': ['demande', 'à', 'tom', '.']},
#  {'english_tokens': ['awesome', '!'], 'french_tokens': ['fantastique', '!']},
#  {'english_tokens': ['be', 'calm', '.'],
#   'french_tokens': ['sois', 'calme', '!']},
#  {'english_tokens': ['be', 'calm', '.'],
#   'french_tokens': ['soyez', 'calme', '!']},
#  {'english_tokens': ['be', 'calm', '.'],
#   'french_tokens': ['soyez', 'calmes', '!']},
#  {'english_tokens': ['be', 'cool', '.'],
#   'french_tokens': ['sois', 'détendu', '!']},
#  {'english_tokens': ['be', 'fair', '.'],
#   'french_tokens': ['sois', 'juste', '!']},
#  {'english_tokens': ['be', 'fair', '.'],
#   'french_tokens': ['soyez', 'juste', '!']},
#  {'english_tokens': ['be', 'fair', '.'],
#   'french_tokens': ['soyez', 'justes', '!']},
#  {'english_tokens': ['be', 'fair', '.'],
#   'french_tokens': ['sois', 'équitable', '!']},
#  {'english_tokens': ['be', 'fair', '.'],
#   'french_tokens': ['soyez', 'équitable', '!']},
#  {'english_tokens': ['be', 'fair', '.'],
#   'french_tokens': ['soyez', 'équitables', '!']},
#  {'english_tokens': ['be', 'kind', '.'],
#   'french_tokens': ['sois', 'gentil', '.']},
#  {'english_tokens': ['be', 'nice', '.'],
#   'french_tokens': ['sois', 'gentil', '!']},
#  {'english_tokens': ['be', 'nice', '.'],
#   'french_tokens': ['sois', 'gentille', '!']},
#  {'english_tokens': ['be', 'nice', '.'],
#   'french_tokens': ['soyez', 'gentil', '!']},
#  {'english_tokens': ['be', 'nice', '.'],
#   'french_tokens': ['soyez', 'gentille', '!']},
#  {'english_tokens': ['be', 'nice', '.'],
#   'french_tokens': ['soyez', 'gentils', '!']},
#  {'english_tokens': ['be', 'nice', '.'],
#   'french_tokens': ['soyez', 'gentilles', '!']},
#  {'english_tokens': ['beat', 'it', '.'], 'french_tokens': ['dégage', '!']},
#  {'english_tokens': ['call', 'me', '.'],
#   'french_tokens': ['appelle-moi', '!']},
#  {'english_tokens': ['call', 'me', '.'],
#   'french_tokens': ['appellez-moi', '!']},
#  {'english_tokens': ['call', 'us', '.'],
#   'french_tokens': ['appelle-nous', '!']},
#  {'english_tokens': ['call', 'us', '.'],
#   'french_tokens': ['appelez-nous', '!']},
#  {'english_tokens': ['come', 'in', '.'], 'french_tokens': ['entrez', '!']},
#  {'english_tokens': ['come', 'in', '.'], 'french_tokens': ['entre', '.']},
#  {'english_tokens': ['come', 'in', '.'], 'french_tokens': ['entre', '!']},
#  {'english_tokens': ['come', 'in', '.'], 'french_tokens': ['entrez', '!']},
#  {'english_tokens': ['come', 'on', '!'], 'french_tokens': ['allez', '!']},
#  {'english_tokens': ['come', 'on', '.'], 'french_tokens': ['allez', '!']},
#  {'english_tokens': ['come', 'on', '.'], 'french_tokens': ['viens', '!']},
#  {'english_tokens': ['come', 'on', '.'], 'french_tokens': ['venez', '!']},
#  {'english_tokens': ['drop', 'it', '!'],
#   'french_tokens': ['laisse', 'tomber', '!']},
#  {'english_tokens': ['drop', 'it', '!'],
#   'french_tokens': ['laissez', 'tomber', '!']},
#  {'english_tokens': ['drop', 'it', '!'],
#   'french_tokens': ['laisse-le', 'tomber', '!']},
#  {'english_tokens': ['drop', 'it', '!'],
#   'french_tokens': ['laissez-le', 'tomber', '!']},
#  {'english_tokens': ['get', 'out', '!'], 'french_tokens': ['sortez', '!']},
#  {'english_tokens': ['get', 'out', '!'], 'french_tokens': ['sors', '!']},
#  {'english_tokens': ['get', 'out', '!'], 'french_tokens': ['sortez', '!']},
#  {'english_tokens': ['get', 'out', '.'], 'french_tokens': ['sors', '.']},
#  {'english_tokens': ['get', 'out', '.'], 'french_tokens': ['casse-toi', '.']},
#  {'english_tokens': ['go', 'away', '!'], 'french_tokens': ['dégage', '!']},
#  {'english_tokens': ['go', 'away', '!'], 'french_tokens': ['pars', '!']},
#  {'english_tokens': ['go', 'away', '.'],
#   'french_tokens': ['va', 'te', 'faire', 'foutre', '!']},
#  {'english_tokens': ['go', 'away', '.'], 'french_tokens': ['pars', '!']},
#  {'english_tokens': ['go', 'away', '.'], 'french_tokens': ['dégage', '!']},
#  {'english_tokens': ['go', 'away', '.'],
#   'french_tokens': ['fous', 'le', 'camp', '!']},
#  {'english_tokens': ['go', 'away', '.'],
#   'french_tokens': ['pars', "d'ici", '.']},
#  {'english_tokens': ['go', 'away', '.'], 'french_tokens': ['va', "t'en", '!']},
#  {'english_tokens': ['go', 'away', '.'], 'french_tokens': ['disparais', '!']},
#  {'english_tokens': ['go', 'away', '.'],
#   'french_tokens': ['allez-vous', 'en', '!']},
#  {'english_tokens': ['go', 'slow', '.'],
#   'french_tokens': ['va', 'doucement', '!']},
#  {'english_tokens': ['go', 'slow', '.'],
#   'french_tokens': ['allez', 'doucement', '!']},
#  {'english_tokens': ['goodbye', '!'],
#   'french_tokens': ['à', 'la', 'revoyure', '.']},
#  {'english_tokens': ['hang', 'on', '!'],
#   'french_tokens': ['attends', 'un', 'peu', '!']},
#  {'english_tokens': ['hang', 'on', '!'],
#   'french_tokens': ['attendez', 'un', 'peu', '!']},
#  {'english_tokens': ['hang', 'on', '.'],
#   'french_tokens': ['tiens', 'bon', '!']},
#  {'english_tokens': ['hang', 'on', '.'],
#   'french_tokens': ['tenez', 'bon', '!']},
#  {'english_tokens': ['he', 'quit', '.'],
#   'french_tokens': ['il', 'laissa', 'tomber', '.']},
#  {'english_tokens': ['he', 'quit', '.'],
#   'french_tokens': ['il', 'a', 'laissé', 'tomber', '.']},
#  {'english_tokens': ['he', 'runs', '.'],
#   'french_tokens': ['il', 'court', '.']},
#  {'english_tokens': ['help', 'me', '!'], 'french_tokens': ['aide-moi', '!']},
#  {'english_tokens': ['help', 'me', '.'], 'french_tokens': ['aide-moi', '.']},
#  {'english_tokens': ['help', 'me', '.'], 'french_tokens': ['aidez-moi', '.']},
#  {'english_tokens': ['help', 'us', '.'], 'french_tokens': ['aidez-nous', '!']},
#  {'english_tokens': ['help', 'us', '.'], 'french_tokens': ['aide-nous', '!']},
#  {'english_tokens': ['hold', 'it', '!'],
#   'french_tokens': ['ne', 'bouge', 'plus', '!']},
#  {'english_tokens': ['hold', 'on', '.'],
#   'french_tokens': ['ne', 'quittez', 'pas', '.']},
#  {'english_tokens': ['i', 'agree', '.'],
#   'french_tokens': ['je', 'suis', 'du', 'même', 'avis', '.']},
#  {'english_tokens': ['i', 'tried', '.'], 'french_tokens': ["j'essayai", '.']},
#  {'english_tokens': ['i', 'tried', '.'],
#   'french_tokens': ["j'ai", 'essayé', '.']},
#  {'english_tokens': ['i', 'tried', '.'],
#   'french_tokens': ["j'ai", 'tenté', '.']},
#  {'english_tokens': ['i', "'ll", 'go', '.'], 'french_tokens': ["j'irai", '.']},
#  {'english_tokens': ['i', "'m", 'fat', '.'],
#   'french_tokens': ['je', 'suis', 'gras', '.']},
#  {'english_tokens': ['i', "'m", 'fat', '.'],
#   'french_tokens': ['je', 'suis', 'gros', '.']},
#  {'english_tokens': ['i', "'m", 'fit', '.'],
#   'french_tokens': ['je', 'suis', 'en', 'forme', '.']},
#  {'english_tokens': ['i', "'m", 'hit', '!'],
#   'french_tokens': ['je', 'suis', 'touché', '!']},
#  {'english_tokens': ['i', "'m", 'hit', '!'],
#   'french_tokens': ['je', 'suis', 'touchée', '!']},
#  {'english_tokens': ['i', "'m", 'ill', '.'],
#   'french_tokens': ['je', 'suis', 'malade', '.']},
#  {'english_tokens': ['i', "'m", 'sad', '.'],
#   'french_tokens': ['je', 'suis', 'triste', '.']},
#  {'english_tokens': ['i', "'m", 'shy', '.'],
#   'french_tokens': ['je', 'suis', 'timide', '.']},
#  {'english_tokens': ['i', "'m", 'wet', '.'],
#   'french_tokens': ['je', 'suis', 'mouillé', '.']},
#  {'english_tokens': ['i', "'m", 'wet', '.'],
#   'french_tokens': ['je', 'suis', 'mouillée', '.']},
#  {'english_tokens': ['it', "'s", 'me', '!'],
#   'french_tokens': ["c'est", 'bibi', '!']},
#  {'english_tokens': ['join', 'us', '.'],
#   'french_tokens': ['joignez-vous', '.']},
#  {'english_tokens': ['join', 'us', '.'],
#   'french_tokens': ['joignez-vous', 'à', 'nous', '.']},
#  {'english_tokens': ['keep', 'it', '.'], 'french_tokens': ['garde-le', '!']},
#  {'english_tokens': ['keep', 'it', '.'], 'french_tokens': ['gardez-le', '!']},
#  {'english_tokens': ['kiss', 'me', '.'],
#   'french_tokens': ['embrasse-moi', '.']},
#  {'english_tokens': ['kiss', 'me', '.'],
#   'french_tokens': ['embrassez-moi', '.']},
#  {'english_tokens': ['me', ',', 'too', '.'],
#   'french_tokens': ['moi', 'aussi', '.']},
#  {'english_tokens': ['open', 'up', '.'], 'french_tokens': ['ouvre-moi', '!']},
#  {'english_tokens': ['open', 'up', '.'], 'french_tokens': ['ouvre', '.']},
#  {'english_tokens': ['perfect', '!'], 'french_tokens': ['parfait', '!']},
#  {'english_tokens': ['see', 'you', '.'], 'french_tokens': ['à', 'plus', '.']},
#  {'english_tokens': ['show', 'me', '.'], 'french_tokens': ['montre-moi', '!']},
#  {'english_tokens': ['show', 'me', '.'],
#   'french_tokens': ['montrez-moi', '!']},
#  {'english_tokens': ['shut', 'up', '!'],
#   'french_tokens': ['taisez-vous', '!']},
#  {'english_tokens': ['shut', 'up', '!'], 'french_tokens': ['ferme-la', '!']},
#  {'english_tokens': ['shut', 'up', '!'], 'french_tokens': ['tais-toi', '!']},
#  {'english_tokens': ['shut', 'up', '!'], 'french_tokens': ['ferme-la', '!']},
#  {'english_tokens': ['shut', 'up', '!'],
#   'french_tokens': ['la', 'ferme', '!']},
#  {'english_tokens': ['so', 'long', '.'],
#   'french_tokens': ['à', 'plus', 'tard', '!']},
#  {'english_tokens': ['take', 'it', '.'], 'french_tokens': ['prends-le', '!']},
#  {'english_tokens': ['take', 'it', '.'], 'french_tokens': ['prenez-le', '!']},
#  {'english_tokens': ['tell', 'me', '.'], 'french_tokens': ['dis-moi', '!']},
#  {'english_tokens': ['tell', 'me', '.'], 'french_tokens': ['dites-moi', '!']},
#  {'english_tokens': ['tom', 'won', '.'],
#   'french_tokens': ['tom', 'a', 'gagné', '.']},
#  {'english_tokens': ['wake', 'up', '!'],
#   'french_tokens': ['réveille-toi', '!']},
#  {'english_tokens': ['wake', 'up', '!'],
#   'french_tokens': ['réveille-toi', '!']},
#  {'english_tokens': ['wake', 'up', '!'],
#   'french_tokens': ['réveillez-vous', '!']},
#  {'english_tokens': ['wake', 'up', '.'],
#   'french_tokens': ['réveille-toi', '!']},
#  {'english_tokens': ['wake', 'up', '.'],
#   'french_tokens': ['réveillez-vous', '!']},
#  {'english_tokens': ['wash', 'up', '.'], 'french_tokens': ['lave-toi', '!']},
#  {'english_tokens': ['wash', 'up', '.'], 'french_tokens': ['lavez-vous', '!']},
#  {'english_tokens': ['we', 'know', '.'],
#   'french_tokens': ['nous', 'savons', '.']},
#  {'english_tokens': ['we', 'lost', '.'],
#   'french_tokens': ['nous', 'perdîmes', '.']},
#  {'english_tokens': ['we', 'lost', '.'],
#   'french_tokens': ['nous', 'avons', 'perdu', '.']},
#  {'english_tokens': ['we', 'lost', '.'],
#   'french_tokens': ['nous', 'fûmes', 'battus', '.']},
#  {'english_tokens': ['we', 'lost', '.'],
#   'french_tokens': ['nous', 'fûmes', 'battues', '.']},
#  {'english_tokens': ['we', 'lost', '.'],
#   'french_tokens': ['nous', 'fûmes', 'défaits', '.']},
#  {'english_tokens': ['we', 'lost', '.'],
#   'french_tokens': ['nous', 'fûmes', 'défaites', '.']},
#  {'english_tokens': ['we', 'lost', '.'],
#   'french_tokens': ['nous', 'avons', 'été', 'défaits', '.']},
#  {'english_tokens': ['we', 'lost', '.'],
#   'french_tokens': ['nous', 'avons', 'été', 'défaites', '.']},
#  {'english_tokens': ['we', 'lost', '.'],
#   'french_tokens': ['nous', 'avons', 'été', 'battus', '.']},
#  {'english_tokens': ['we', 'lost', '.'],
#   'french_tokens': ['nous', 'avons', 'été', 'battues', '.']},
#  {'english_tokens': ['who', 'won', '?'],
#   'french_tokens': ['qui', 'a', 'gagné', '?']},
#  {'english_tokens': ['who', 'won', '?'],
#   'french_tokens': ['qui', 'l', "'", 'a', 'emporté', '?']},
#  {'english_tokens': ['you', 'run', '.'],
#   'french_tokens': ['tu', 'cours', '.']},
#  {'english_tokens': ['am', 'i', 'fat', '?'],
#   'french_tokens': ['suis-je', 'gros', '?']},
#  {'english_tokens': ['am', 'i', 'fat', '?'],
#   'french_tokens': ['suis-je', 'grosse', '?']},
#  {'english_tokens': ['back', 'off', '.'], 'french_tokens': ['recule', '!']},
#  {'english_tokens': ['back', 'off', '.'], 'french_tokens': ['reculez', '.']},
#  {'english_tokens': ['back', 'off', '.'],
#   'french_tokens': ['retire-toi', '!']},
#  {'english_tokens': ['back', 'off', '.'],
#   'french_tokens': ['retirez-vous', '.']},
#  {'english_tokens': ['be', 'a', 'man', '.'],
#   'french_tokens': ['sois', 'un', 'homme', '!']},
#  {'english_tokens': ['be', 'a', 'man', '.'],
#   'french_tokens': ['soyez', 'un', 'homme', '!']},
#  {'english_tokens': ['be', 'still', '.'],
#   'french_tokens': ['sois', 'calme', '!']},
#  {'english_tokens': ['be', 'still', '.'],
#   'french_tokens': ['soyez', 'calme', '!']},
#  {'english_tokens': ['be', 'still', '.'],
#   'french_tokens': ['soyez', 'calmes', '!']},
#  {'english_tokens': ['beats', 'me', '.'],
#   'french_tokens': ['aucune', 'idée', '.']},
#  {'english_tokens': ['beats', 'me', '.'],
#   'french_tokens': ["j'en", 'sais', 'foutre', 'rien', '.']},
#  {'english_tokens': ['call', 'tom', '.'],
#   'french_tokens': ['appelle', 'tom', '.']},
#  {'english_tokens': ['call', 'tom', '.'],
#   'french_tokens': ['appelez', 'tom', '.']},
#  {'english_tokens': ['cheer', 'up', '!'], 'french_tokens': ['courage', '!']},
#  {'english_tokens': ['cool', 'off', '!'],
#   'french_tokens': ['détends-toi', '!']},
#  {'english_tokens': ['cuff', 'him', '.'],
#   'french_tokens': ['menottez-le', '.']},
#  {'english_tokens': ['drive', 'on', '.'], 'french_tokens': ['avance', '!']},
#  {'english_tokens': ['drive', 'on', '.'], 'french_tokens': ['avancez', '!']},
#  {'english_tokens': ['drive', 'on', '.'],
#   'french_tokens': ['continue', 'à', 'rouler', '!']},
#  {'english_tokens': ['drive', 'on', '.'],
#   'french_tokens': ['continuez', 'à', 'rouler', '!']},
#  {'english_tokens': ['get', 'down', '!'], 'french_tokens': ['lâche-toi', '!']},
#  {'english_tokens': ['get', 'down', '.'], 'french_tokens': ['descends', '!']},
#  {'english_tokens': ['get', 'down', '.'], 'french_tokens': ['descendez', '!']},
#  {'english_tokens': ['get', 'down', '.'], 'french_tokens': ['lâche-toi', '!']},
#  {'english_tokens': ['get', 'down', '.'],
#   'french_tokens': ['lâchez-vous', '!']},
#  {'english_tokens': ['get', 'lost', '!'],
#   'french_tokens': ['va',
#    'voir',
#    'ailleurs',
#    'si',
#    'j',
#    "'",
#    'y',
#    'suis',
#    '!']},
#  {'english_tokens': ['get', 'lost', '!'], 'french_tokens': ['dégage', '!']},
#  {'english_tokens': ['get', 'lost', '!'],
#   'french_tokens': ['va', 'au', 'diable', '!']},
#  {'english_tokens': ['get', 'real', '!'],
#   'french_tokens': ['sois', 'réaliste', '!']},
#  {'english_tokens': ['go', 'ahead', '.'], 'french_tokens': ['vas-y', '.']},
#  {'english_tokens': ['go', 'ahead', '.'], 'french_tokens': ['poursuis', '!']},
#  {'english_tokens': ['go', 'ahead', '.'],
#   'french_tokens': ['passe', 'devant', '!']},
#  {'english_tokens': ['go', 'ahead', '.'], 'french_tokens': ['vas-y', '!']},
#  {'english_tokens': ['good', 'job', '!'],
#   'french_tokens': ['bien', 'joué', '!']},
#  {'english_tokens': ['good', 'job', '!'],
#   'french_tokens': ['bon', 'boulot', '!']},
#  {'english_tokens': ['good', 'job', '!'],
#   'french_tokens': ['beau', 'travail', '!']},
#  {'english_tokens': ['grab', 'him', '.'],
#   'french_tokens': ['attrape-le', '.']},
#  {'english_tokens': ['grab', 'him', '.'],
#   'french_tokens': ['attrapez-le', '.']},
#  {'english_tokens': ['have', 'fun', '.'],
#   'french_tokens': ['amuse-toi', 'bien', '!']},
#  {'english_tokens': ['have', 'fun', '.'],
#   'french_tokens': ['amusez-vous', 'bien', '!']},
#  {'english_tokens': ['he', 'tries', '.'],
#   'french_tokens': ['il', 'essaye', '.']},
#  {'english_tokens': ['he', "'s", 'wet', '.'],
#   'french_tokens': ['il', 'est', 'mouillé', '.']},
#  {'english_tokens': ['hi', ',', 'guys', '.'],
#   'french_tokens': ['salut', ',', 'les', 'mecs', '!']},
#  {'english_tokens': ['how', 'cute', '!'],
#   'french_tokens': ['comme', "c'est", 'mignon', '!']},
#  {'english_tokens': ['how', 'deep', '?'],
#   'french_tokens': ['quelle', 'profondeur', '?']},
#  {'english_tokens': ['how', 'nice', '!'],
#   'french_tokens': ['comme', "c'est", 'chouette', '!']},
#  {'english_tokens': ['how', 'nice', '!'],
#   'french_tokens': ['comme', "c'est", 'gentil', '!']},
#  {'english_tokens': ['how', 'nice', '!'],
#   'french_tokens': ["c'est", 'du', 'joli', '!']},
#  {'english_tokens': ['how', 'nice', '!'],
#   'french_tokens': ['comme', "c'est", 'agréable', '!']},
#  {'english_tokens': ['humor', 'me', '.'],
#   'french_tokens': ['fais-moi', 'rire', '.']},
#  {'english_tokens': ['hurry', 'up', '.'],
#   'french_tokens': ['dépêche-toi', '.']},
#  {'english_tokens': ['hurry', 'up', '.'], 'french_tokens': ['grouille', '!']},
#  {'english_tokens': ['hurry', 'up', '.'],
#   'french_tokens': ['pressez-vous', '!']},
#  {'english_tokens': ['hurry', 'up', '.'], 'french_tokens': ['fiça', '!']},
#  {'english_tokens': ['i', 'am', 'fat', '.'],
#   'french_tokens': ['je', 'suis', 'gras', '.']},
#  {'english_tokens': ['i', 'did', 'ok', '.'],
#   'french_tokens': ['je', "m'en", 'suis', 'bien', 'sorti', '.']},
#  {'english_tokens': ['i', 'did', 'ok', '.'],
#   'french_tokens': ['je', "m'en", 'suis', 'bien', 'sortie', '.']},
#  {'english_tokens': ['i', 'did', 'it', '.'],
#   'french_tokens': ['je', "l'ai", 'fait', '.']},
#  {'english_tokens': ['i', 'did', 'it', '.'],
#   'french_tokens': ["c'est", 'moi', 'qui', "l'ai", 'fait', '.']},
#  {'english_tokens': ['i', 'forgot', '.'],
#   'french_tokens': ["j'ai", 'oublié', '.']},
#  {'english_tokens': ['i', 'get', 'it', '.'],
#   'french_tokens': ["j'ai", 'compris', '.']},
#  {'english_tokens': ['i', 'got', 'it', '.'],
#   'french_tokens': ["j'ai", 'compris', '.']},
#  {'english_tokens': ['i', 'got', 'it', '.'],
#   'french_tokens': ["j'ai", 'capté', '.']},
#  {'english_tokens': ['i', 'phoned', '.'],
#   'french_tokens': ['je', 'téléphonai', '.']},
#  {'english_tokens': ['i', 'phoned', '.'],
#   'french_tokens': ["j'ai", 'téléphoné', '.']},
#  {'english_tokens': ['i', 'refuse', '.'],
#   'french_tokens': ['je', 'refuse', '.']},
#  {'english_tokens': ['i', 'refuse', '.'],
#   'french_tokens': ['je', 'le', 'refuse', '.']},
#  {'english_tokens': ['i', 'saw', 'it', '.'],
#   'french_tokens': ['je', "l'ai", 'vu', '.']},
#  {'english_tokens': ['i', 'saw', 'it', '.'],
#   'french_tokens': ['je', 'l', '’', 'ai', 'vu', '.']},
#  {'english_tokens': ['i', 'stayed', '.'],
#   'french_tokens': ['je', 'suis', 'resté', '.']},
#  {'english_tokens': ['i', 'stayed', '.'],
#   'french_tokens': ['je', 'suis', 'restée', '.']},
#  {'english_tokens': ['i', 'use', 'it', '.'],
#   'french_tokens': ['je', "l'utilise", '.']},
#  {'english_tokens': ['i', 'use', 'it', '.'],
#   'french_tokens': ["j'en", 'fais', 'usage', '.']},
#  {'english_tokens': ['i', 'use', 'it', '.'],
#   'french_tokens': ['je', "m'en", 'sers', '.']},
#  {'english_tokens': ['i', "'ll", 'pay', '.'],
#   'french_tokens': ['je', 'paierai', '.']},
#  {'english_tokens': ['i', "'ll", 'try', '.'],
#   'french_tokens': ["j'essaierai", '.']},
#  {'english_tokens': ['i', "'m", 'back', '.'],
#   'french_tokens': ['je', 'suis', 'revenu', '.']},
#  {'english_tokens': ['i', "'m", 'back', '.'],
#   'french_tokens': ['me', 'revoilà', '.']},
#  {'english_tokens': ['i', "'m", 'bald', '.'],
#   'french_tokens': ['je', 'suis', 'chauve', '.']},
#  {'english_tokens': ['i', "'m", 'busy', '.'],
#   'french_tokens': ['je', 'suis', 'occupé', '.']},
#  {'english_tokens': ['i', "'m", 'busy', '.'],
#   'french_tokens': ['je', 'suis', 'occupée', '.']},
#  {'english_tokens': ['i', "'m", 'calm', '.'],
#   'french_tokens': ['je', 'suis', 'calme', '.']},
#  {'english_tokens': ['i', "'m", 'cold', '.'],
#   'french_tokens': ["j'ai", 'froid', '.']},
#  {'english_tokens': ['i', "'m", 'done', '.'],
#   'french_tokens': ["j'en", 'ai', 'fini', '.']},
#  {'english_tokens': ['i', "'m", 'fine', '.'],
#   'french_tokens': ['tout', 'va', 'bien', '.']},
#  {'english_tokens': ['i', "'m", 'fine', '.'],
#   'french_tokens': ['je', 'vais', 'bien', '.']},
#  {'english_tokens': ['i', "'m", 'fine', '.'],
#   'french_tokens': ['ça', 'va', '.']},
#  {'english_tokens': ['i', "'m", 'free', '!'],
#   'french_tokens': ['je', 'suis', 'libre', '!']},
#  {'english_tokens': ['i', "'m", 'free', '.'],
#   'french_tokens': ['je', 'suis', 'libre', '.']},
#  {'english_tokens': ['i', "'m", 'free', '.'],
#   'french_tokens': ['je', 'suis', 'disponible', '.']},
#  {'english_tokens': ['i', "'m", 'full', '.'],
#   'french_tokens': ['je', 'suis', 'repu', '!']},
#  {'english_tokens': ['i', "'m", 'full', '.'],
#   'french_tokens': ['je', 'suis', 'rassasié', '!']},
#  {'english_tokens': ['i', "'m", 'glad', '.'],
#   'french_tokens': ['je', 'suis', 'content', '.']},
#  {'english_tokens': ['i', "'m", 'home', '.'],
#   'french_tokens': ['je', 'suis', 'chez', 'moi', '.']},
#  {'english_tokens': ['i', "'m", 'late', '.'],
#   'french_tokens': ['je', 'suis', 'en', 'retard', '.']},
#  {'english_tokens': ['i', "'m", 'lazy', '.'],
#   'french_tokens': ['je', 'suis', 'paresseux', '.']},
#  {'english_tokens': ['i', "'m", 'lazy', '.'],
#   'french_tokens': ['je', 'suis', 'fainéant', '.']},
#  {'english_tokens': ['i', "'m", 'lazy', '.'],
#   'french_tokens': ['je', 'suis', 'paresseuse', '.']},
#  {'english_tokens': ['i', "'m", 'lazy', '.'],
#   'french_tokens': ['je', 'suis', 'fainéante', '.']},
#  {'english_tokens': ['i', "'m", 'okay', '.'],
#   'french_tokens': ['je', 'vais', 'bien', '.']},
#  {'english_tokens': ['i', "'m", 'okay', '.'],
#   'french_tokens': ['je', 'me', 'porte', 'bien', '.']},
#  {'english_tokens': ['i', "'m", 'safe', '.'],
#   'french_tokens': ['je', 'suis', 'en', 'sécurité', '.']},
#  {'english_tokens': ['i', "'m", 'sick', '.'],
#   'french_tokens': ['je', 'suis', 'malade', '.']},
#  {'english_tokens': ['i', "'m", 'sure', '.'],
#   'french_tokens': ["j'en", 'suis', 'certain', '.']},
#  {'english_tokens': ['i', "'m", 'sure', '.'],
#   'french_tokens': ['je', 'suis', 'certain', '.']},
#  {'english_tokens': ['i', "'m", 'sure', '.'],
#   'french_tokens': ["j'en", 'suis', 'sûr', '.']},
#  {'english_tokens': ['i', "'m", 'sure', '.'],
#   'french_tokens': ["j'en", 'suis', 'sûre', '.']},
#  {'english_tokens': ['i', "'m", 'tall', '.'],
#   'french_tokens': ['je', 'suis', 'grande', '.']},
#  {'english_tokens': ['i', "'m", 'thin', '.'],
#   'french_tokens': ['je', 'suis', 'mince', '.']},
#  {'english_tokens': ['i', "'m", 'tidy', '.'],
#   'french_tokens': ['je', 'suis', 'ordonné', '.']},
#  {'english_tokens': ['i', "'m", 'tidy', '.'],
#   'french_tokens': ['je', 'suis', 'ordonnée', '.']},
#  {'english_tokens': ['i', "'m", 'ugly', '.'],
#   'french_tokens': ['je', 'suis', 'laid', '.']},
#  {'english_tokens': ['i', "'m", 'ugly', '.'],
#   'french_tokens': ['je', 'suis', 'laide', '.']},
#  {'english_tokens': ['i', "'m", 'weak', '.'],
#   'french_tokens': ['je', 'suis', 'faible', '.']},
#  {'english_tokens': ['i', "'m", 'well', '.'],
#   'french_tokens': ['je', 'vais', 'bien', '.']},
#  {'english_tokens': ['i', "'m", 'well', '.'],
#   'french_tokens': ['je', 'me', 'porte', 'bien', '.']},
#  {'english_tokens': ['i', "'ve", 'won', '.'],
#   'french_tokens': ["j'ai", 'gagné', '.']},
#  {'english_tokens': ['i', "'ve", 'won', '.'],
#   'french_tokens': ['je', "l'ai", 'emporté', '.']},
#  {'english_tokens': ['it', 'works', '.'],
#   'french_tokens': ['elle', 'marche', '.']},
#  {'english_tokens': ['it', 'works', '.'],
#   'french_tokens': ['ça', 'fonctionne', '.']},
#  {'english_tokens': ['it', "'s", 'his', '.'],
#   'french_tokens': ["c'est", 'le', 'sien', '.']},
#  {'english_tokens': ['it', "'s", 'his', '.'],
#   'french_tokens': ["c'est", 'la', 'sienne', '.']},
#  {'english_tokens': ['it', "'s", 'new', '.'],
#   'french_tokens': ["c'est", 'nouveau', '.']},
#  {'english_tokens': ['it', "'s", 'new', '.'],
#   'french_tokens': ["c'est", 'neuf', '.']},
#  {'english_tokens': ['it', "'s", 'odd', '.'],
#   'french_tokens': ["c'est", 'bizarre', '.']},
#  {'english_tokens': ['it', "'s", 'sad', '.'],
#   'french_tokens': ['c', '’', 'est', 'triste', '.']},
#  {'english_tokens': ['keep', 'out', '!'],
#   'french_tokens': ['défense', "d'entrer", '.']},
#  {'english_tokens': ['keep', 'out', '.'],
#   'french_tokens': ["n'entrez", 'pas', '.']},
#  {'english_tokens': ['leave', 'it', '.'],
#   'french_tokens': ['laisse', 'tomber', '!']},
#  {'english_tokens': ['leave', 'it', '.'],
#   'french_tokens': ['laissez', 'tomber', '!']},
#  {'english_tokens': ['leave', 'me', '.'],
#   'french_tokens': ['laissez-moi', '!']},
#  {'english_tokens': ['leave', 'us', '.'],
#   'french_tokens': ['laisse-nous', '!']},
#  {'english_tokens': ['leave', 'us', '.'],
#   'french_tokens': ['laissez-nous', '!']},
#  {'english_tokens': ['let', "'s", 'go', '!'],
#   'french_tokens': ['allons-y', '!']},
#  {'english_tokens': ['let', "'s", 'go', '!'],
#   'french_tokens': ['allons', '!']},
#  {'english_tokens': ['let', "'s", 'go', '.'],
#   'french_tokens': ['allons-y', '!']},
#  {'english_tokens': ['look', 'out', '!'], 'french_tokens': ['attention', '!']},
#  {'english_tokens': ['marry', 'me', '.'],
#   'french_tokens': ['épouse-moi', '!']},
#  {'english_tokens': ['marry', 'me', '.'],
#   'french_tokens': ['épousez-moi', '!']},
#  {'english_tokens': ['may', 'i', 'go', '?'],
#   'french_tokens': ['puis-je', 'partir', '?']},
#  {'english_tokens': ['may', 'i', 'go', '?'],
#   'french_tokens': ['puis-je', 'y', 'aller', '?']},
#  {'english_tokens': ['may', 'i', 'go', '?'],
#   'french_tokens': ['puis-je', 'm', "'", 'y', 'rendre', '?']},
#  {'english_tokens': ['she', 'came', '.'],
#   'french_tokens': ['elle', 'est', 'venue', '.']},
#  {'english_tokens': ['she', 'died', '.'],
#   'french_tokens': ['elle', 'est', 'morte', '.']},
#  {'english_tokens': ['she', 'runs', '.'],
#   'french_tokens': ['elle', 'court', '.']},
#  {'english_tokens': ['sit', 'down', '!'],
#   'french_tokens': ['assieds-toi', '!']},
#  {'english_tokens': ['sit', 'down', '!'],
#   'french_tokens': ['asseyez-vous', '!']},
#  {'english_tokens': ['sit', 'here', '.'],
#   'french_tokens': ['assieds-toi', 'ici', '.']},
#  {'english_tokens': ['sit', 'here', '.'],
#   'french_tokens': ['asseyez-vous', 'ici', '.']},
#  {'english_tokens': ['speak', 'up', '!'],
#   'french_tokens': ['parle', 'plus', 'fort', '!']},
#  {'english_tokens': ['speak', 'up', '!'],
#   'french_tokens': ['parlez', 'plus', 'fort', '!']},
#  {'english_tokens': ['stop', 'tom', '.'],
#   'french_tokens': ['arrête', 'tom', '.']},
#  {'english_tokens': ['stop', 'tom', '.'],
#   'french_tokens': ['stoppez', 'tom', '.']},
#  {'english_tokens': ['terrific', '!'], 'french_tokens': ['génial', '!']},
#  {'english_tokens': ['terrific', '!'], 'french_tokens': ['excellent', '!']},
#  {'english_tokens': ['terrific', '!'], 'french_tokens': ['formidable', '!']},
#  {'english_tokens': ['they', 'won', '.'],
#   'french_tokens': ['ils', 'gagnèrent', '.']},
#  {'english_tokens': ['they', 'won', '.'],
#   'french_tokens': ['elles', 'gagnèrent', '.']},
#  {'english_tokens': ['they', 'won', '.'],
#   'french_tokens': ['ils', 'ont', 'gagné', '.']},
#  {'english_tokens': ['they', 'won', '.'],
#   'french_tokens': ['elles', 'ont', 'gagné', '.']},
#  {'english_tokens': ['tom', 'came', '.'],
#   'french_tokens': ['tom', 'est', 'venu', '.']},
#  {'english_tokens': ['tom', 'died', '.'],
#   'french_tokens': ['tom', 'est', 'mort', '.']},
#  {'english_tokens': ['tom', 'left', '.'],
#   'french_tokens': ['tom', 'est', 'parti', '.']},
#  {'english_tokens': ['tom', 'left', '.'],
#   'french_tokens': ['tom', 'partit', '.']},
#  {'english_tokens': ['tom', 'lost', '.'],
#   'french_tokens': ['tom', 'a', 'perdu', '.']},
#  {'english_tokens': ['too', 'late', '.'],
#   'french_tokens': ['trop', 'tard', '.']},
#  {'english_tokens': ['trust', 'me', '.'],
#   'french_tokens': ['faites-moi', 'confiance', '.']},
#  {'english_tokens': ['trust', 'me', '.'],
#   'french_tokens': ['fais-moi', 'confiance', '.']},
#  {'english_tokens': ['try', 'hard', '.'],
#   'french_tokens': ['fais', 'un', 'effort', '.']},
#  {'english_tokens': ['try', 'some', '.'],
#   'french_tokens': ['essaies-en', '!']},
#  {'english_tokens': ['try', 'some', '.'],
#   'french_tokens': ['essayez-en', '!']},
#  {'english_tokens': ['try', 'this', '.'],
#   'french_tokens': ['essaie', 'ceci', '!']},
#  {'english_tokens': ['try', 'this', '.'],
#   'french_tokens': ['essayez', 'ceci', '!']},
#  {'english_tokens': ['use', 'this', '.'],
#   'french_tokens': ['utilise', 'ceci', '.']},
#  {'english_tokens': ['use', 'this', '.'],
#   'french_tokens': ['utilisez', 'ceci', '.']},
#  {'english_tokens': ['use', 'this', '.'],
#   'french_tokens': ['emploie', 'ceci', '!']},
#  {'english_tokens': ['use', 'this', '.'],
#   'french_tokens': ['employez', 'ceci', '!']},
#  {'english_tokens': ['warn', 'tom', '.'],
#   'french_tokens': ['avertis', 'tom', '.']},
#  {'english_tokens': ['warn', 'tom', '.'],
#   'french_tokens': ['préviens', 'tom', '.']},
#  {'english_tokens': ['watch', 'me', '.'],
#   'french_tokens': ['regarde-moi', '!']},
#  {'english_tokens': ['watch', 'me', '.'],
#   'french_tokens': ['regardez-moi', '!']},
#  {'english_tokens': ['watch', 'us', '.'],
#   'french_tokens': ['regardez-nous', '!']},
#  {'english_tokens': ['watch', 'us', '.'],
#   'french_tokens': ['regarde-nous', '!']},
#  {'english_tokens': ['we', 'agree', '.'],
#   'french_tokens': ['nous', 'sommes', "d'accord", '.']},
#  {'english_tokens': ['we', "'ll", 'go', '.'],
#   'french_tokens': ['nous', 'irons', '.']},
#  {'english_tokens': ['what', 'for', '?'],
#   'french_tokens': ['pour', 'quoi', 'faire', '?']},
#  {'english_tokens': ['what', 'for', '?'],
#   'french_tokens': ['à', 'quoi', 'bon', '?']},
#  {'english_tokens': ['what', 'fun', '!'],
#   'french_tokens': ["qu'est-ce", "qu'on", "s'est", 'marrés', '!']},
#  {'english_tokens': ['what', 'fun', '!'],
#   'french_tokens': ["qu'est-ce", "qu'on", "s'est", 'marrées', '!']},
#  {'english_tokens': ['who', 'died', '?'],
#   'french_tokens': ['qui', 'est', 'mort', '?']},
#  {'english_tokens': ['who', "'s", 'he', '?'],
#   'french_tokens': ['qui', 'est-il', '?']},
#  {'english_tokens': ['write', 'me', '.'], 'french_tokens': ['écris-moi', '!']},
#  {'english_tokens': ['write', 'me', '.'],
#   'french_tokens': ['écrivez-moi', '!']},
#  {'english_tokens': ['after', 'you', '.'],
#   'french_tokens': ['après', 'vous', '.']},
#  {'english_tokens': ['aim', '.', 'fire', '!'],
#   'french_tokens': ['en', 'joue', '!', 'feu', '!']},
#  {'english_tokens': ['am', 'i', 'late', '?'],
#   'french_tokens': ['suis-je', 'en', 'retard', '?']},
#  {'english_tokens': ['answer', 'me', '.'],
#   'french_tokens': ['répondez-moi', '.']},
#  {'english_tokens': ['be', 'seated', '.'],
#   'french_tokens': ['assieds-toi', '!']},
#  {'english_tokens': ['be', 'seated', '.'],
#   'french_tokens': ['asseyez-vous', '!']},
#  {'english_tokens': ['birds', 'fly', '.'],
#   'french_tokens': ['les', 'oiseaux', 'volent', '.']},
#  {'english_tokens': ['bless', 'you', '.'],
#   'french_tokens': ['à', 'tes', 'souhaits', '!']},
#  {'english_tokens': ['call', 'home', '!'],
#   'french_tokens': ['appelle', 'à', 'la', 'maison', '!']},
#  {'english_tokens': ['calm', 'down', '!'],
#   'french_tokens': ['calmez-vous', '!']},
#  {'english_tokens': ['calm', 'down', '.'],
#   'french_tokens': ['calme-toi', '.']},
#  {'english_tokens': ['can', 'we', 'go', '?'],
#   'french_tokens': ['pouvons-nous', 'partir', '?']},
#  {'english_tokens': ['can', 'we', 'go', '?'],
#   'french_tokens': ['pouvons-nous', 'nous', 'en', 'aller', '?']},
#  {'english_tokens': ['can', 'we', 'go', '?'],
#   'french_tokens': ['pouvons-nous', 'y', 'aller', '?']},
#  {'english_tokens': ['catch', 'him', '.'],
#   'french_tokens': ['rattrape-le', '.']},
#  {'english_tokens': ['come', 'back', '.'], 'french_tokens': ['reviens', '!']},
#  {'english_tokens': ['come', 'back', '.'], 'french_tokens': ['revenez', '!']},
#  {'english_tokens': ['come', 'here', '.'],
#   'french_tokens': ['viens', 'ici', '.']},
#  {'english_tokens': ['come', 'here', '.'],
#   'french_tokens': ['venez', 'là', '.']},
#  {'english_tokens': ['come', 'over', '!'], 'french_tokens': ['viens', '!']},
#  {'english_tokens': ['come', 'over', '!'], 'french_tokens': ['venez', '!']},
#  {'english_tokens': ['come', 'over', '.'],
#   'french_tokens': ['venez', 'ici', '!']},
#  {'english_tokens': ['come', 'over', '.'],
#   'french_tokens': ['viens', 'chez', 'nous', '!']},
#  {'english_tokens': ['come', 'over', '.'],
#   'french_tokens': ['venez', 'chez', 'nous', '!']},
#  {'english_tokens': ['come', 'over', '.'],
#   'french_tokens': ['viens', 'chez', 'moi', '!']},
#  {'english_tokens': ['come', 'over', '.'],
#   'french_tokens': ['venez', 'chez', 'moi', '!']},
#  {'english_tokens': ['come', 'soon', '.'],
#   'french_tokens': ['viens', 'bientôt', '!']},
#  {'english_tokens': ['come', 'soon', '.'],
#   'french_tokens': ['venez', 'bientôt', '!']},
#  {'english_tokens': ['cool', 'down', '.'],
#   'french_tokens': ['calmez-vous', '!']},
#  {'english_tokens': ['did', 'i', 'win', '?'],
#   'french_tokens': ['ai-je', 'gagné', '?']},
#  {'english_tokens': ['did', 'i', 'win', '?'],
#   'french_tokens': ["l'ai-je", 'emporté', '?']},
#  {'english_tokens': ['did', 'i', 'win', '?'],
#   'french_tokens': ['est-ce', 'moi', 'qui', 'ai', 'gagné', '?']},
#  {'english_tokens': ['dogs', 'bark', '.'],
#   'french_tokens': ['des', 'chiens', 'aboient', '.']},
#  {'english_tokens': ['dogs', 'bark', '.'],
#   'french_tokens': ['les', 'chiens', 'aboient', '.']},
#  {'english_tokens': ['do', "n't", 'ask', '.'],
#   'french_tokens': ['ne', 'demande', 'pas', '!']},
#  {'english_tokens': ['do', "n't", 'cry', '.'],
#   'french_tokens': ['ne', 'pleure', 'pas', '!']},
#  {'english_tokens': ['do', "n't", 'die', '.'],
#   'french_tokens': ['ne', 'meurs', 'pas', '!']},
#  {'english_tokens': ['do', "n't", 'die', '.'],
#   'french_tokens': ['ne', 'mourez', 'pas', '!']},
#  {'english_tokens': ['do', "n't", 'lie', '.'],
#   'french_tokens': ['ne', 'mens', 'pas', '.']},
#  {'english_tokens': ['do', "n't", 'run', '.'],
#   'french_tokens': ['ne', 'courez', 'pas', '.']},
#  {'english_tokens': ['do', "n't", 'run', '.'],
#   'french_tokens': ['ne', 'cours', 'pas', '.']},
#  {'english_tokens': ['excuse', 'me', '.'],
#   'french_tokens': ['excuse-moi', '.']},
#  {'english_tokens': ['fantastic', '!'], 'french_tokens': ['fantastique', '!']},
#  {'english_tokens': ['feel', 'this', '.'],
#   'french_tokens': ['sens', 'ça', '!']},
#  {'english_tokens': ['feel', 'this', '.'],
#   'french_tokens': ['sentez', 'ça', '!']},
#  {'english_tokens': ['feel', 'this', '.'],
#   'french_tokens': ['touche', 'ça', '!']},
#  {'english_tokens': ['feel', 'this', '.'],
#   'french_tokens': ['touchez', 'ça', '!']},
#  {'english_tokens': ['follow', 'me', '.'], 'french_tokens': ['suis-moi', '.']},
#  {'english_tokens': ['follow', 'us', '.'],
#   'french_tokens': ['suis-nous', '!']},
#  {'english_tokens': ['follow', 'us', '.'],
#   'french_tokens': ['suivez-nous', '!']},
#  {'english_tokens': ['forget', 'it', '!'], 'french_tokens': ['oublie', '!']},
#  {'english_tokens': ['forget', 'it', '!'],
#   'french_tokens': ['oublie-le', '!']},
#  {'english_tokens': ['forget', 'it', '!'], 'french_tokens': ['oubliez', '!']},
#  {'english_tokens': ['forget', 'it', '!'],
#   'french_tokens': ['oubliez-le', '!']},
#  {'english_tokens': ['forget', 'it', '.'],
#   'french_tokens': ['laisse', 'tomber', '.']},
#  {'english_tokens': ['forget', 'it', '.'], 'french_tokens': ['oublie', '.']},
#  {'english_tokens': ['get', 'a', 'job', '.'],
#   'french_tokens': ['trouve', 'un', 'emploi', '!']},
#  {'english_tokens': ['get', 'a', 'job', '.'],
#   'french_tokens': ['trouve', 'un', 'boulot', '!']},
#  {'english_tokens': ['get', 'a', 'job', '.'],
#   'french_tokens': ['trouvez', 'un', 'emploi', '!']},
#  {'english_tokens': ['get', 'a', 'job', '.'],
#   'french_tokens': ['trouvez', 'un', 'boulot', '!']},
#  {'english_tokens': ['get', 'ready', '.'],
#   'french_tokens': ['prépare-toi', '.']},
#  {'english_tokens': ['get', 'ready', '.'],
#   'french_tokens': ['préparez-vous', '.']},
#  {'english_tokens': ['go', 'get', 'it', '.'],
#   'french_tokens': ['va', 'le', 'chercher', '!']},
#  {'english_tokens': ['go', 'get', 'it', '.'],
#   'french_tokens': ['allez', 'le', 'chercher', '!']},
#  {'english_tokens': ['go', 'inside', '.'], 'french_tokens': ['entrez', '!']},
#  {'english_tokens': ['go', 'to', 'bed', '.'],
#   'french_tokens': ['va', 'au', 'lit', '!']},
#  {'english_tokens': ['go', 'to', 'bed', '.'],
#   'french_tokens': ['allez', 'au', 'lit', '!']},
#  {'english_tokens': ['good', 'luck', '.'],
#   'french_tokens': ['bonne', 'chance', '!']},
#  {'english_tokens': ['good', 'luck', '.'],
#   'french_tokens': ['bonne', 'chance', '.']},
#  {'english_tokens': ['grab', 'that', '.'],
#   'french_tokens': ['attrape', 'ça', '!']},
#  {'english_tokens': ['grab', 'that', '.'],
#   'french_tokens': ['attrapez', 'ça', '!']},
#  {'english_tokens': ['grab', 'that', '.'],
#   'french_tokens': ['saisis-toi', 'de', 'ça', '!']},
#  {'english_tokens': ['grab', 'that', '.'],
#   'french_tokens': ['saisissez-vous', 'de', 'ça', '!']},
#  {'english_tokens': ['grab', 'this', '.'],
#   'french_tokens': ['attrape', 'ça', '!']},
#  {'english_tokens': ['grab', 'this', '.'],
#   'french_tokens': ['attrapez', 'ça', '!']},
#  {'english_tokens': ['hands', 'off', '.'],
#   'french_tokens': ['pas', 'touche', '!']},
#  {'english_tokens': ['he', 'is', 'ill', '.'],
#   'french_tokens': ['il', 'est', 'malade', '.']},
#  {'english_tokens': ['he', 'is', 'old', '.'],
#   'french_tokens': ['il', 'est', 'vieux', '.']},
#  {'english_tokens': ['he', "'s", 'a', 'dj', '.'],
#   'french_tokens': ['il', 'est', 'dj', '.']},
#  {'english_tokens': ['he', "'s", 'good', '.'],
#   'french_tokens': ['il', 'est', 'bon', '.']},
#  {'english_tokens': ['he', "'s", 'lazy', '.'],
#   'french_tokens': ['il', 'est', 'paresseux', '.']},
#  {'english_tokens': ['he', "'s", 'rich', '.'],
#   'french_tokens': ['il', 'est', 'riche', '.']},
#  {'english_tokens': ['here', 'i', 'am', '.'],
#   'french_tokens': ['me', 'voici', '.']},
#  {'english_tokens': ['here', "'s", '$', '5', '.'],
#   'french_tokens': ['voilà', 'cinq', 'dollars', '.']},
#  {'english_tokens': ['hold', 'fire', '.'],
#   'french_tokens': ['halte', 'au', 'feu', '!']},
#  {'english_tokens': ['hold', 'fire', '.'],
#   'french_tokens': ['cessez', 'le', 'feu', '!']},
#  {'english_tokens': ['hold', 'this', '.'],
#   'french_tokens': ['tiens', 'ça', '!']},
#  {'english_tokens': ['hold', 'this', '.'],
#   'french_tokens': ['tenez', 'ça', '!']},
#  {'english_tokens': ['hold', 'this', '.'],
#   'french_tokens': ['tenez', 'ceci', '!']},
#  {'english_tokens': ['hold', 'this', '.'],
#   'french_tokens': ['tiens', 'ceci', '!']},
#  {'english_tokens': ['how', 'awful', '!'],
#   'french_tokens': ["c'est", 'affreux', '!']},
#  {'english_tokens': ['how', "'s", 'tom', '?'],
#   'french_tokens': ['comment', 'tom', 'va-t-il', '?']},
#  {'english_tokens': ['how', "'s", 'tom', '?'],
#   'french_tokens': ['comment', 'va', 'tom', '?']},
#  {'english_tokens': ['i', 'am', 'busy', '.'],
#   'french_tokens': ['je', 'suis', 'occupé', '.']},
#  {'english_tokens': ['i', 'am', 'calm', '.'],
#   'french_tokens': ['je', 'suis', 'calme', '.']},
#  {'english_tokens': ['i', 'am', 'cold', '.'],
#   'french_tokens': ["j'ai", 'froid', '.']},
#  {'english_tokens': ['i', 'am', 'good', '.'],
#   'french_tokens': ['je', 'suis', 'bon', '.']},
#  {'english_tokens': ['i', 'am', 'here', '.'],
#   'french_tokens': ['je', 'suis', 'ici', '.']},
#  {'english_tokens': ['i', 'am', 'lazy', '.'],
#   'french_tokens': ['je', 'suis', 'paresseux', '.']},
#  {'english_tokens': ['i', 'am', 'lazy', '.'],
#   'french_tokens': ['je', 'suis', 'fainéant', '.']},
#  {'english_tokens': ['i', 'am', 'lazy', '.'],
#   'french_tokens': ['je', 'suis', 'paresseuse', '.']},
#  {'english_tokens': ['i', 'am', 'lazy', '.'],
#   'french_tokens': ['je', 'suis', 'fainéante', '.']},
#  {'english_tokens': ['i', 'am', 'okay', '.'],
#   'french_tokens': ['je', 'vais', 'bien', '.']},
#  {'english_tokens': ['i', 'am', 'sick', '.'],
#   'french_tokens': ['je', 'suis', 'malade', '.']},
#  {'english_tokens': ['i', 'am', 'sure', '.'],
#   'french_tokens': ['je', 'suis', 'sûr', '.']},
#  {'english_tokens': ['i', 'am', 'sure', '.'],
#   'french_tokens': ['je', 'suis', 'certain', '.']},
#  {'english_tokens': ['i', 'am', 'weak', '.'],
#   'french_tokens': ['je', 'suis', 'faible', '.']},
#  {'english_tokens': ['i', 'beg', 'you', '.'],
#   'french_tokens': ['je', 'vous', 'en', 'prie', '.']},
#  {'english_tokens': ['i', 'beg', 'you', '.'],
#   'french_tokens': ['je', 'vous', 'en', 'conjure', '.']},
#  {'english_tokens': ['i', 'beg', 'you', '.'],
#   'french_tokens': ['je', 'vous', 'en', 'supplie', '.']},
#  {'english_tokens': ['i', 'beg', 'you', '.'],
#   'french_tokens': ['je', 'te', 'prie', '.']},
#  {'english_tokens': ['i', 'can', 'run', '.'],
#   'french_tokens': ['je', 'sais', 'courir', '.']},
#  {'english_tokens': ['i', 'can', 'ski', '.'],
#   'french_tokens': ['je', 'sais', 'skier', '.']},
#  {'english_tokens': ['i', 'cringed', '.'],
#   'french_tokens': ["j'eus", 'un', 'mouvement', 'de', 'recul', '.']},
#  {'english_tokens': ['i', 'cringed', '.'],
#   'french_tokens': ["j'ai", 'eu', 'un', 'mouvement', 'de', 'recul', '.']},
#  {'english_tokens': ['i', 'cringed', '.'],
#   'french_tokens': ['je', 'suis', 'rentré', 'en', 'moi-même', '.']},
#  {'english_tokens': ['i', 'give', 'up', '.'],
#   'french_tokens': ["j'abandonne", '.']},
#  {'english_tokens': ['i', 'got', 'hot', '.'],
#   'french_tokens': ['je', 'me', 'suis', 'mis', 'à', 'avoir', 'chaud', '.']},
#  {'english_tokens': ['i', 'got', 'hot', '.'],
#   'french_tokens': ['je', 'me', 'suis', 'mise', 'à', 'avoir', 'chaud', '.']},
#  {'english_tokens': ['i', 'had', 'fun', '.'],
#   'french_tokens': ['je', 'me', 'suis', 'amusé', '.']},
#  {'english_tokens': ['i', 'had', 'fun', '.'],
#   'french_tokens': ['je', 'me', 'suis', 'amusée', '.']},
#  {'english_tokens': ['i', 'had', 'fun', '.'],
#   'french_tokens': ['je', 'me', 'suis', 'marré', '.']},
#  {'english_tokens': ['i', 'had', 'fun', '.'],
#   'french_tokens': ['je', 'me', 'suis', 'marrée', '.']},
#  {'english_tokens': ['i', 'hate', 'it', '.'],
#   'french_tokens': ['je', 'déteste', 'ça', '.']},
#  {'english_tokens': ['i', 'hope', 'so', '.'],
#   'french_tokens': ["j'espère", 'bien', '.']},
#  {'english_tokens': ['i', 'knew', 'it', '.'],
#   'french_tokens': ['je', 'le', 'savais', '.']},
#  {'english_tokens': ['i', 'like', 'it', '.'],
#   'french_tokens': ["j'aime", 'ça', '.']},
#  {'english_tokens': ['i', 'lost', 'it', '.'],
#   'french_tokens': ['je', 'l', '’', 'ai', 'perdu', '.']},
#  {'english_tokens': ['i', 'love', 'it', '!'],
#   'french_tokens': ["j'adore", 'ça', '!']},
#  {'english_tokens': ['i', 'love', 'it', '.'],
#   'french_tokens': ["j'adore", 'ça', '!']},
#  {'english_tokens': ['i', 'mean', 'it', '!'],
#   'french_tokens': ['je', 'suis', 'sérieux', '!']},
#  {'english_tokens': ['i', 'mean', 'it', '.'],
#   'french_tokens': ['je', 'suis', 'sérieux', '.']},
#  {'english_tokens': ['i', 'must', 'go', '.'],
#   'french_tokens': ['je', 'dois', 'y', 'aller', '.']},
#  {'english_tokens': ['i', 'must', 'go', '.'],
#   'french_tokens': ['il', 'faut', 'que', 'j', "'", 'y', 'aille', '.']},
#  {'english_tokens': ['i', 'must', 'go', '.'],
#   'french_tokens': ['il', 'me', 'faut', 'y', 'aller', '.']},
#  {'english_tokens': ['i', 'must', 'go', '.'],
#   'french_tokens': ['il', 'me', 'faut', 'partir', '.']},
#  {'english_tokens': ['i', 'must', 'go', '.'],
#   'french_tokens': ['il', 'me', 'faut', "m'en", 'aller', '.']},
#  {'english_tokens': ['i', 'must', 'go', '.'],
#   'french_tokens': ['je', 'dois', 'partir', '.']},
#  {'english_tokens': ['i', 'must', 'go', '.'],
#   'french_tokens': ['je', 'dois', "m'en", 'aller', '.']},
#  {'english_tokens': ['i', 'must', 'go', '.'],
#   'french_tokens': ['il', 'faut', 'que', 'je', "m'en", 'aille', '.']},
#  {'english_tokens': ['i', 'need', 'it', '.'],
#   'french_tokens': ["j'en", 'ai', 'besoin', '.']},
#  {'english_tokens': ['i', 'need', 'it', '.'],
#   'french_tokens': ['il', 'me', 'le', 'faut', '.']},
#  {'english_tokens': ['i', 'noticed', '.'],
#   'french_tokens': ["j'ai", 'remarqué', '.']},
#  {'english_tokens': ['i', 'promise', '.'],
#   'french_tokens': ['je', 'le', 'promets', '.']},
#  {'english_tokens': ['i', 'said', 'no', '.'],
#   'french_tokens': ["j'ai", 'dit', 'non', '.']},
#  {'english_tokens': ['i', 'said', 'so', '.'],
#   'french_tokens': ['je', "l'ai", 'dit', '.']},
#  {'english_tokens': ['i', 'saw', 'him', '.'],
#   'french_tokens': ['je', "l'ai", 'vu', '.']},
#  {'english_tokens': ['i', 'saw', 'him', '.'],
#   'french_tokens': ['je', 'l', '’', 'ai', 'vu', '.']},
#  {'english_tokens': ['i', 'saw', 'him', '.'],
#   'french_tokens': ['je', 'le', 'vis', '.']},
#  {'english_tokens': ['i', 'saw', 'one', '.'],
#   'french_tokens': ["j'en", 'ai', 'vu', 'une', '.']},
#  {'english_tokens': ['i', 'saw', 'one', '.'],
#   'french_tokens': ["j'en", 'ai', 'vu', 'un', '.']},
#  {'english_tokens': ['i', 'saw', 'you', '.'],
#   'french_tokens': ['je', 'vous', 'vis', '.']},
#  {'english_tokens': ['i', 'saw', 'you', '.'],
# ...
#   'french_tokens': ['es-tu', 'debout', '?']},
#  {'english_tokens': ['are', 'you', 'up', '?'],
#   'french_tokens': ['êtes-vous', 'debout', '?']},
#  {'english_tokens': ['ask', 'anyone', '.'],
#   'french_tokens': ['demandez', 'à', "n'importe", 'qui', '.']},
#  {'english_tokens': ['ask', 'anyone', '.'],
#   'french_tokens': ['demande', 'à', "n'importe", 'qui', '.']},
#  {'english_tokens': ['ask', 'anyone', '.'],
#   'french_tokens': ['demande', 'à', 'quiconque', '!']},
#  {'english_tokens': ['ask', 'around', '.'],
#   'french_tokens': ['demande', 'alentour', '!']},
#  {'english_tokens': ['ask', 'around', '.'],
#   'french_tokens': ['demandez', 'alentour', '!']},
#  {'english_tokens': ['be', 'careful', '.'],
#   'french_tokens': ['sois', 'prudent', '!']},
#  {'english_tokens': ['be', 'careful', '.'],
#   'french_tokens': ['sois', 'prudente', '!']},
#  {'english_tokens': ['be', 'careful', '.'],
#   'french_tokens': ['soyez', 'prudent', '!']},
#  {'english_tokens': ['be', 'careful', '.'],
#   'french_tokens': ['soyez', 'prudente', '!']},
#  {'english_tokens': ['be', 'careful', '.'],
#   'french_tokens': ['soyez', 'prudents', '!']},
#  {'english_tokens': ['be', 'careful', '.'],
#   'french_tokens': ['soyez', 'prudentes', '!']},
#  {'english_tokens': ['be', 'content', '.'],
#   'french_tokens': ['sois', 'satisfait', '!']},
#  {'english_tokens': ['be', 'content', '.'],
#   'french_tokens': ['sois', 'satisfaite', '!']},
#  {'english_tokens': ['be', 'content', '.'],
#   'french_tokens': ['soyez', 'satisfait', '!']},
#  {'english_tokens': ['be', 'content', '.'],
#   'french_tokens': ['soyez', 'satisfaite', '!']},
#  {'english_tokens': ['be', 'content', '.'],
#   'french_tokens': ['soyez', 'satisfaits', '!']},
#  {'english_tokens': ['be', 'content', '.'],
#   'french_tokens': ['soyez', 'satisfaites', '!']},
#  {'english_tokens': ['be', 'serious', '.'],
#   'french_tokens': ['soyez', 'sérieux', '!']},
#  {'english_tokens': ['be', 'serious', '.'],
#   'french_tokens': ['soyez', 'sérieuse', '!']},
#  {'english_tokens': ['be', 'serious', '.'],
#   'french_tokens': ['soyez', 'sérieuses', '!']},
#  {'english_tokens': ['be', 'serious', '.'],
#   'french_tokens': ['sois', 'sérieux', '!']},
#  {'english_tokens': ['be', 'serious', '.'],
#   'french_tokens': ['sois', 'sérieuse', '!']},
#  {'english_tokens': ['birds', 'sing', '.'],
#   'french_tokens': ['les', 'oiseaux', 'chantent', '.']},
#  {'english_tokens': ['bottoms', 'up', '!'], 'french_tokens': ['santé', '!']},
#  {'english_tokens': ['can', 'i', 'come', '?'],
#   'french_tokens': ['puis-je', 'venir', '?']},
#  {'english_tokens': ['can', 'i', 'help', '?'],
#   'french_tokens': ['puis-je', 'aider', '?']},
#  {'english_tokens': ['can', 'i', 'stay', '?'],
#   'french_tokens': ['puis-je', 'rester', '?']},
#  {'english_tokens': ['check', 'this', '.'],
#   'french_tokens': ['vérifie', 'ça', '.']},
#  {'english_tokens': ['check', 'this', '.'],
#   'french_tokens': ['regarde', 'ça', '.']},
#  {'english_tokens': ['choose', 'one', '.'],
#   'french_tokens': ['choisis-en', 'un', '.']},
#  {'english_tokens': ['choose', 'one', '.'],
#   'french_tokens': ['choisis-en', 'une', '.']},
#  {'english_tokens': ['come', 'along', '.'],
#   'french_tokens': ['joignez-vous', 'à', 'nous', '.']},
#  {'english_tokens': ['come', 'on', 'in', '!'],
#   'french_tokens': ['entre', 'donc', '!']},
#  {'english_tokens': ['come', 'on', 'in', '.'],
#   'french_tokens': ['entre', '.']},
#  {'english_tokens': ['come', 'quick', '!'],
#   'french_tokens': ['viens', 'vite', '!']},
#  {'english_tokens': ['come', 'quick', '!'],
#   'french_tokens': ['jouis', 'vite', '!']},
#  {'english_tokens': ['come', 'to', 'me', '.'],
#   'french_tokens': ['venez', 'à', 'moi', '.']},
#  {'english_tokens': ['come', 'to', 'us', '.'],
#   'french_tokens': ['venez', 'à', 'nous', '.']},
#  {'english_tokens': ['cut', 'it', 'out', '!'],
#   'french_tokens': ['arrête', '!']},
#  {'english_tokens': ['cut', 'it', 'out', '!'],
#   'french_tokens': ['arrêtez', '!']},
#  {'english_tokens': ['cut', 'it', 'out', '.'],
#   'french_tokens': ['assez', '!']},
#  {'english_tokens': ['did', 'we', 'win', '?'],
#   'french_tokens': ['avons-nous', 'gagné', '?']},
#  {'english_tokens': ['do', 'i', 'stink', '?'],
#   'french_tokens': ['est-ce', 'que', 'je', 'pue', '?']},
#  {'english_tokens': ['do', 'come', 'in', '!'],
#   'french_tokens': ['je', 'vous', 'en', 'prie', ',', 'entrez', '!']},
#  {'english_tokens': ['do', 'men', 'cry', '?'],
#   'french_tokens': ['les', 'hommes', 'pleurent-ils', '?']},
#  {'english_tokens': ['do', "n't", 'fret', '.'],
#   'french_tokens': ['te', 'tracasse', 'pas', '.']},
#  {'english_tokens': ['do', "n't", 'fret', '.'],
#   'french_tokens': ['vous', 'tracassez', 'pas', '.']},
#  {'english_tokens': ['do', "n't", 'fret', '.'],
#   'french_tokens': ['ne', 'te', 'tracasse', 'pas', '.']},
#  {'english_tokens': ['do', "n't", 'fret', '.'],
#   'french_tokens': ['ne', 'vous', 'tracassez', 'pas', '.']},
#  {'english_tokens': ['do', "n't", 'move', '!'],
#   'french_tokens': ['ne', 'bouge', 'pas', '!']},
#  {'english_tokens': ['do', "n't", 'move', '!'],
#   'french_tokens': ['ne', 'bougez', 'pas', '!']},
#  {'english_tokens': ['do', "n't", 'move', '.'],
#   'french_tokens': ['ne', 'bougez', 'pas', '.']},
#  {'english_tokens': ['do', "n't", 'move', '.'],
#   'french_tokens': ['ne', 'bouge', 'pas', '.']},
#  {'english_tokens': ['do', "n't", 'rush', '.'],
#   'french_tokens': ['ne', 'te', 'précipite', 'pas', '.']},
#  {'english_tokens': ['do', "n't", 'rush', '.'],
#   'french_tokens': ['ne', 'vous', 'précipitez', 'pas', '.']},
#  {'english_tokens': ['do', "n't", 'talk', '!'],
#   'french_tokens': ['ne', 'parle', 'pas', '!']},
#  {'english_tokens': ['do', "n't", 'talk', '!'],
#   'french_tokens': ['ne', 'parlez', 'pas', '!']},
#  {'english_tokens': ['do', "n't", 'wait', '.'],
#   'french_tokens': ["n'attends", 'pas', '!']},
#  {'english_tokens': ['do', "n't", 'wait', '.'],
#   'french_tokens': ["n'attendez", 'pas', '!']},
#  {'english_tokens': ['duty', 'calls', '.'],
#   'french_tokens': ['le', 'devoir', "m'appelle", '.']},
#  {'english_tokens': ['fill', 'it', 'up', '.'],
#   'french_tokens': ['le', 'plein', '.']},
#  {'english_tokens': ['find', 'a', 'job', '.'],
#   'french_tokens': ['trouve', 'un', 'emploi', '!']},
#  {'english_tokens': ['find', 'a', 'job', '.'],
#   'french_tokens': ['trouve', 'un', 'boulot', '!']},
#  {'english_tokens': ['follow', 'him', '.'], 'french_tokens': ['suis-le', '!']},
#  {'english_tokens': ['follow', 'him', '.'],
#   'french_tokens': ['suivez-le', '!']},
#  {'english_tokens': ['forget', 'him', '.'],
#   'french_tokens': ['oublie-le', '.']},
#  {'english_tokens': ['forget', 'him', '.'],
#   'french_tokens': ['oubliez-le', '.']},
#  {'english_tokens': ['forgive', 'me', '.'],
#   'french_tokens': ['pardonnez-moi', '.']},
#  {'english_tokens': ['get', 'a', 'life', '!'],
#   'french_tokens': ['achète-toi', 'une', 'vie', '!']},
#  {'english_tokens': ['get', 'to', 'bed', '.'],
#   'french_tokens': ['va', 'au', 'lit', '!']},
#  {'english_tokens': ['get', 'to', 'bed', '.'],
#   'french_tokens': ['au', 'lit', '!']},
#  {'english_tokens': ['get', 'to', 'bed', '.'],
#   'french_tokens': ['allez', 'au', 'lit', '!']},
#  {'english_tokens': ['give', 'it', 'up', '.'],
#   'french_tokens': ['laisse', 'tomber', '.']},
#  {'english_tokens': ['give', 'it', 'up', '.'],
#   'french_tokens': ['abandonne', '!']},
#  {'english_tokens': ['go', 'warm', 'up', '.'],
#   'french_tokens': ['va', "t'échauffer", '!']},
#  {'english_tokens': ['go', 'warm', 'up', '.'],
#   'french_tokens': ['allez', 'vous', 'échauffer', '!']},
#  {'english_tokens': ['he', 'gave', 'in', '.'],
#   'french_tokens': ['il', 'a', 'cédé', '.']},
#  {'english_tokens': ['he', 'gave', 'in', '.'],
#   'french_tokens': ['il', 'céda', '.']},
#  {'english_tokens': ['he', 'hung', 'up', '.'],
#   'french_tokens': ['il', 'a', 'raccroché', '.']},
#  {'english_tokens': ['he', 'hung', 'up', '.'],
#   'french_tokens': ['il', 'raccrocha', '.']},
#  {'english_tokens': ['he', 'is', 'a', 'dj', '.'],
#   'french_tokens': ['il', 'est', 'dj', '.']},
#  {'english_tokens': ['he', 'is', 'busy', '.'],
#   'french_tokens': ['il', 'a', 'à', 'faire', '.']},
#  {'english_tokens': ['he', 'is', 'here', '!'],
#   'french_tokens': ['il', 'est', 'ici', '!']},
#  {'english_tokens': ['he', 'is', 'kind', '.'],
#   'french_tokens': ['il', 'est', 'gentil', '.']},
#  {'english_tokens': ['he', 'is', 'late', '.'],
#   'french_tokens': ['il', 'est', 'en', 'retard', '.']},
#  {'english_tokens': ['he', 'is', 'lazy', '.'],
#   'french_tokens': ['il', 'est', 'fainéant', '.']},
#  {'english_tokens': ['he', 'is', 'lazy', '.'],
#   'french_tokens': ['il', 'est', 'paresseux', '.']},
#  {'english_tokens': ['he', 'is', 'poor', '.'],
#   'french_tokens': ['il', 'est', 'pauvre', '.']},
#  {'english_tokens': ['he', 'is', 'sick', '.'],
#   'french_tokens': ['il', 'est', 'malade', '.']},
#  {'english_tokens': ['he', 'made', 'it', '.'],
#   'french_tokens': ['il', 'a', 'réussi', '.']},
#  {'english_tokens': ['he', "'s", 'swiss', '.'],
#   'french_tokens': ['il', 'est', 'suisse', '.']},
#  {'english_tokens': ['he', "'s", 'swiss', '.'],
#   'french_tokens': ['il', 'est', 'helvète', '.']},
#  {'english_tokens': ['he', "'s", 'broke', '.'],
#   'french_tokens': ['il', 'est', 'ruiné', '.']},
#  {'english_tokens': ['he', "'s", 'broke', '.'],
#   'french_tokens': ['il', 'est', 'fauché', '.']},
#  {'english_tokens': ['he', "'s", 'drunk', '.'],
#   'french_tokens': ['il', 'est', 'ivre', '.']},
#  {'english_tokens': ['he', "'s", 'drunk', '.'],
#   'french_tokens': ['il', 'est', 'soûl', '.']},
#  {'english_tokens': ['he', "'s", 'smart', '.'],
#   'french_tokens': ['il', 'est', 'intelligent', '.']},
#  {'english_tokens': ['here', 'he', 'is', '!'],
#   'french_tokens': ['il', 'est', 'ici', '!']},
#  {'english_tokens': ['here', 'it', 'is', '.'],
#   'french_tokens': ['le', 'voilà', '.']},
#  {'english_tokens': ['here', 'it', 'is', '.'],
#   'french_tokens': ['tenez', '.']},
#  {'english_tokens': ['here', 'it', 'is', '.'],
#   'french_tokens': ['le', 'voici', '.']},
#  {'english_tokens': ['here', 'we', 'go', '.'],
#   'french_tokens': ["c'est", 'parti', '!']},
#  {'english_tokens': ['here', 'we', 'go', '.'],
#   'french_tokens': ['on', 'est', 'partis', '!']},
#  {'english_tokens': ['hold', 'still', '.'],
#   'french_tokens': ['tiens-toi', 'tranquille', '!']},
#  {'english_tokens': ['hold', 'still', '.'],
#   'french_tokens': ['tenez-vous', 'tranquille', '!']},
#  {'english_tokens': ['how', 'lovely', '!'],
#   'french_tokens': ['comme', "c'est", 'charmant', '!']},
#  {'english_tokens': ['how', "'s", 'work', '?'],
#   'french_tokens': ['comment', 'va', 'le', 'travail', '?']},
#  {'english_tokens': ['hurry', 'home', '.'],
#   'french_tokens': ['dépêche-toi', "d'aller", 'chez', 'toi', '!']},
#  {'english_tokens': ['hurry', 'home', '.'],
#   'french_tokens': ['dépêchez-vous', "d'aller", 'chez', 'vous', '!']},
#  {'english_tokens': ['i', 'am', 'a', 'man', '.'],
#   'french_tokens': ['je', 'suis', 'un', 'homme', '.']},
#  {'english_tokens': ['i', 'am', 'human', '.'],
#   'french_tokens': ['je', 'suis', 'humain', '.']},
#  {'english_tokens': ['i', 'am', 'ready', '.'],
#   'french_tokens': ['je', 'suis', 'prêt', '.']},
#  {'english_tokens': ['i', 'am', 'right', '.'],
#   'french_tokens': ["j'ai", 'raison', '.']},
#  {'english_tokens': ['i', 'am', 'sorry', '.'],
#   'french_tokens': ['je', 'suis', 'désolé', '.']},
#  {'english_tokens': ['i', 'am', 'sorry', '.'],
#   'french_tokens': ['je', 'suis', 'désolée', '.']},
#  {'english_tokens': ['i', 'am', 'tired', '.'],
#   'french_tokens': ['je', 'suis', 'fatigué', '!']},
#  {'english_tokens': ['i', 'am', 'tired', '.'],
#   'french_tokens': ['je', 'suis', 'crevé', '.']},
#  {'english_tokens': ['i', 'broke', 'it', '.'],
#   'french_tokens': ['je', "l'ai", 'cassé', '.']},
#  {'english_tokens': ['i', 'broke', 'it', '.'],
#   'french_tokens': ['je', "l'ai", 'cassée', '.']},
#  {'english_tokens': ['i', 'built', 'it', '.'],
#   'french_tokens': ['je', "l'ai", 'construit', '.']},
#  {'english_tokens': ['i', 'built', 'it', '.'],
#   'french_tokens': ['je', "l'ai", 'construite', '.']},
#  {'english_tokens': ['i', 'can', 'come', '.'],
#   'french_tokens': ['je', 'peux', 'venir', '.']},
#  {'english_tokens': ['i', 'can', 'cook', '.'],
#   'french_tokens': ['je', 'sais', 'cuisiner', '.']},
#  {'english_tokens': ['i', 'can', 'jump', '.'],
#   'french_tokens': ['je', 'peux', 'sauter', '.']},
#  {'english_tokens': ['i', 'can', 'read', '.'],
#   'french_tokens': ['je', 'sais', 'lire', '.']},
#  {'english_tokens': ['i', 'can', 'read', '.'],
#   'french_tokens': ['je', 'peux', 'lire', '.']},
#  {'english_tokens': ['i', 'can', 'sing', '.'],
#   'french_tokens': ['je', 'sais', 'chanter', '.']},
#  {'english_tokens': ['i', 'can', 'stay', '.'],
#   'french_tokens': ['je', 'peux', 'rester', '.']},
#  {'english_tokens': ['i', 'can', 'swim', '.'],
#   'french_tokens': ['je', 'sais', 'nager', '.']},
#  {'english_tokens': ['i', 'can', 'wait', '.'],
#   'french_tokens': ['je', 'peux', 'attendre', '.']},
#  {'english_tokens': ['i', 'can', 'walk', '.'],
#   'french_tokens': ['je', 'peux', 'marcher', '.']},
#  {'english_tokens': ['i', 'ca', "n't", 'go', '.'],
#   'french_tokens': ['je', 'ne', 'peux', 'pas', 'y', 'aller', '.']},
#  {'english_tokens': ['i', 'ca', "n't", 'go', '.'],
#   'french_tokens': ['je', 'ne', 'peux', 'pas', 'm', "'", 'y', 'rendre', '.']},
#  {'english_tokens': ['i', 'ca', "n't", 'go', '.'],
#   'french_tokens': ['je', 'ne', 'peux', 'pas', 'partir', '.']},
#  {'english_tokens': ['i', 'did', 'that', '.'],
#   'french_tokens': ["j'ai", 'fait', 'cela', '.']},
#  {'english_tokens': ['i', 'did', 'that', '.'],
#   'french_tokens': ["c'est", 'moi', 'qui', "l'ai", 'fait', '.']},
#  {'english_tokens': ['i', 'disagree', '.'],
#   'french_tokens': ['je', 'ne', 'suis', 'pas', "d'accord", '.']},
#  {'english_tokens': ['i', 'do', 'worry', '.'],
#   'french_tokens': ['je', 'me', 'fais', 'vraiment', 'du', 'souci', '.']},
#  {'english_tokens': ['i', 'doubt', 'it', '.'],
#   'french_tokens': ["j'en", 'doute', '.']},
#  {'english_tokens': ['i', 'eat', 'here', '.'],
#   'french_tokens': ['je', 'mange', 'ici', '.']},
#  {'english_tokens': ['i', 'envy', 'him', '.'],
#   'french_tokens': ['je', "l'envie", '.']},
#  {'english_tokens': ['i', 'envy', 'you', '.'],
#   'french_tokens': ['je', 'vous', 'envie', '.']},
#  {'english_tokens': ['i', 'envy', 'you', '.'],
#   'french_tokens': ['je', "t'envie", '.']},
#  {'english_tokens': ['i', 'feel', 'bad', '.'],
#   'french_tokens': ['je', 'me', 'sens', 'mal', '.']},
#  {'english_tokens': ['i', 'feel', 'old', '.'],
#   'french_tokens': ['je', 'me', 'sens', 'vieux', '.']},
#  {'english_tokens': ['i', 'feel', 'old', '.'],
#   'french_tokens': ['je', 'me', 'sens', 'vieille', '.']},
#  {'english_tokens': ['i', 'felt', 'bad', '.'],
#   'french_tokens': ['je', 'me', 'suis', 'senti', 'mal', '.']},
#  {'english_tokens': ['i', 'felt', 'ill', '.'],
#   'french_tokens': ['je', 'me', 'suis', 'senti', 'mal', '.']},
#  {'english_tokens': ['i', 'felt', 'ill', '.'],
#   'french_tokens': ['je', 'me', 'sentais', 'malade', '.']},
#  {'english_tokens': ['i', 'felt', 'ill', '.'],
#   'french_tokens': ['je', 'me', 'sentis', 'malade', '.']},
#  {'english_tokens': ['i', 'felt', 'sad', '.'],
#   'french_tokens': ["j'ai", 'ressenti', 'de', 'la', 'tristesse', '.']},
#  {'english_tokens': ['i', 'fixed', 'it', '.'],
#   'french_tokens': ['je', "l'ai", 'réparé', '.']},
#  {'english_tokens': ['i', 'fixed', 'it', '.'],
#   'french_tokens': ['je', "l'ai", 'réparée', '.']},
#  {'english_tokens': ['i', 'fixed', 'it', '.'],
#   'french_tokens': ['je', 'la', 'réparai', '.']},
#  {'english_tokens': ['i', 'fixed', 'it', '.'],
#   'french_tokens': ['je', 'le', 'réparai', '.']},
#  {'english_tokens': ['i', 'found', 'it', '.'],
#   'french_tokens': ['je', "l'ai", 'trouvé', '.']},
#  {'english_tokens': ['i', 'found', 'it', '.'],
#   'french_tokens': ['je', 'le', 'trouvai', '.']},
#  {'english_tokens': ['i', 'got', 'busy', '.'],
#   'french_tokens': ['je', 'suis', 'devenu', 'occupé', '.']},
#  {'english_tokens': ['i', 'got', 'busy', '.'],
#   'french_tokens': ['je', 'suis', 'devenu', 'occupée', '.']},
#  {'english_tokens': ['i', 'got', 'lost', '.'],
#   'french_tokens': ['je', 'me', 'suis', 'perdu', '.']},
#  {'english_tokens': ['i', 'got', 'sick', '.'],
#   'french_tokens': ['je', 'suis', 'devenu', 'malade', '.']},
#  {'english_tokens': ['i', 'got', 'sick', '.'],
#   'french_tokens': ['je', 'suis', 'devenue', 'malade', '.']},
#  ...]

# %%
filter_phrases = (
    ("i", "am"), ("i", "'m"), 
    ("he", "is"), ("he", "'s"),
    ("she", "is"), ("she", "'s"),
    ("you", "are"), ("you", "'re"),
    ("we", "are"), ("we", "'re"),
    ("they", "are"), ("they", "'re")
)

# %%
data_subset = {phrase: [] for phrase in filter_phrases}
for datum in data:
    key = tuple(datum['english_tokens'][:2])
    if key in data_subset:
        data_subset[key].append(datum)

# %%
data_subset
# Out:
# {('i',
#   'am'): [{'english_tokens': ['i', 'am', 'fat', '.'],
#    'french_tokens': ['je', 'suis', 'gras', '.']}, {'english_tokens': ['i',
#     'am',
#     'busy',
#     '.'],
#    'french_tokens': ['je', 'suis', 'occupé', '.']}, {'english_tokens': ['i',
#     'am',
#     'calm',
#     '.'],
#    'french_tokens': ['je', 'suis', 'calme', '.']}, {'english_tokens': ['i',
#     'am',
#     'cold',
#     '.'],
#    'french_tokens': ["j'ai", 'froid', '.']}, {'english_tokens': ['i',
#     'am',
#     'good',
#     '.'],
#    'french_tokens': ['je', 'suis', 'bon', '.']}, {'english_tokens': ['i',
#     'am',
#     'here',
#     '.'],
#    'french_tokens': ['je', 'suis', 'ici', '.']}, {'english_tokens': ['i',
#     'am',
#     'lazy',
#     '.'],
#    'french_tokens': ['je', 'suis', 'paresseux', '.']}, {'english_tokens': ['i',
#     'am',
#     'lazy',
#     '.'],
#    'french_tokens': ['je', 'suis', 'fainéant', '.']}, {'english_tokens': ['i',
#     'am',
#     'lazy',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'paresseuse',
#     '.']}, {'english_tokens': ['i', 'am', 'lazy', '.'],
#    'french_tokens': ['je', 'suis', 'fainéante', '.']}, {'english_tokens': ['i',
#     'am',
#     'okay',
#     '.'],
#    'french_tokens': ['je', 'vais', 'bien', '.']}, {'english_tokens': ['i',
#     'am',
#     'sick',
#     '.'],
#    'french_tokens': ['je', 'suis', 'malade', '.']}, {'english_tokens': ['i',
#     'am',
#     'sure',
#     '.'],
#    'french_tokens': ['je', 'suis', 'sûr', '.']}, {'english_tokens': ['i',
#     'am',
#     'sure',
#     '.'],
#    'french_tokens': ['je', 'suis', 'certain', '.']}, {'english_tokens': ['i',
#     'am',
#     'weak',
#     '.'],
#    'french_tokens': ['je', 'suis', 'faible', '.']}, {'english_tokens': ['i',
#     'am',
#     'a',
#     'man',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'un',
#     'homme',
#     '.']}, {'english_tokens': ['i', 'am', 'human', '.'],
#    'french_tokens': ['je', 'suis', 'humain', '.']}, {'english_tokens': ['i',
#     'am',
#     'ready',
#     '.'],
#    'french_tokens': ['je', 'suis', 'prêt', '.']}, {'english_tokens': ['i',
#     'am',
#     'right',
#     '.'],
#    'french_tokens': ["j'ai", 'raison', '.']}, {'english_tokens': ['i',
#     'am',
#     'sorry',
#     '.'],
#    'french_tokens': ['je', 'suis', 'désolé', '.']}, {'english_tokens': ['i',
#     'am',
#     'sorry',
#     '.'],
#    'french_tokens': ['je', 'suis', 'désolée', '.']}, {'english_tokens': ['i',
#     'am',
#     'tired',
#     '.'],
#    'french_tokens': ['je', 'suis', 'fatigué', '!']}, {'english_tokens': ['i',
#     'am',
#     'tired',
#     '.'],
#    'french_tokens': ['je', 'suis', 'crevé', '.']}, {'english_tokens': ['i',
#     'am',
#     'french',
#     '.'],
#    'french_tokens': ['je', 'suis', 'français', '.']}, {'english_tokens': ['i',
#     'am',
#     'korean',
#     '.'],
#    'french_tokens': ['je', 'suis', 'coréen', '.']}, {'english_tokens': ['i',
#     'am',
#     'a',
#     'cook',
#     '.'],
#    'french_tokens': ['je', 'suis', 'cuisinier', '.']}, {'english_tokens': ['i',
#     'am',
#     'a',
#     'monk',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'un',
#     'moine',
#     '.']}, {'english_tokens': ['i', 'am', 'better', '.'],
#    'french_tokens': ['je', 'vais', 'mieux', '.']}, {'english_tokens': ['i',
#     'am',
#     'better',
#     '.'],
#    'french_tokens': ['je', 'suis', 'mieux', '.']}, {'english_tokens': ['i',
#     'am',
#     'coming',
#     '.'],
#    'french_tokens': ["j'arrive", '.']}, {'english_tokens': ['i',
#     'am',
#     'hungry',
#     '.'],
#    'french_tokens': ["j'ai", 'faim', '!']}, {'english_tokens': ['i',
#     'am',
#     'joking',
#     '.'],
#    'french_tokens': ['je', 'plaisante', '.']}, {'english_tokens': ['i',
#     'am',
#     'single',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'célibataire',
#     '.']}, {'english_tokens': ['i', 'am', 'taller', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'plus',
#     'grand',
#     '.']}, {'english_tokens': ['i', 'am', 'italian', '.'],
#    'french_tokens': ['je', 'suis', 'italien', '.']}, {'english_tokens': ['i',
#     'am',
#     'ashamed',
#     '.'],
#    'french_tokens': ["j'ai", 'honte', '.']}, {'english_tokens': ['i',
#     'am',
#     'at',
#     'home',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'à',
#     'la',
#     'maison',
#     '.']}, {'english_tokens': ['i', 'am', 'curious', '.'],
#    'french_tokens': ['je', 'suis', 'curieux', '.']}, {'english_tokens': ['i',
#     'am',
#     'married',
#     '.'],
#    'french_tokens': ['je', 'suis', 'mariée', '.']}, {'english_tokens': ['i',
#     'am',
#     'so',
#     'sick',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'tellement',
#     'malade',
#     '.']}, {'english_tokens': ['i', 'am', 'so', 'sick', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'si',
#     'malade',
#     '.']}, {'english_tokens': ['i', 'am', 'so', 'sick', '.'],
#    'french_tokens': ["c'est",
#     'moi',
#     'qui',
#     'suis',
#     'tellement',
#     'malade',
#     '.']}, {'english_tokens': ['i', 'am', 'so', 'sick', '.'],
#    'french_tokens': ["c'est",
#     'moi',
#     'qui',
#     'suis',
#     'si',
#     'malade',
#     '.']}, {'english_tokens': ['i', 'am', 'thirsty', '.'],
#    'french_tokens': ["j'ai", 'soif', '.']}, {'english_tokens': ['i',
#     'am',
#     'working',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'en',
#     'train',
#     'de',
#     'travailler',
#     '.']}, {'english_tokens': ['i', 'am', 'american', '.'],
#    'french_tokens': ['je', 'suis', 'américain', '.']}, {'english_tokens': ['i',
#     'am',
#     'american',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'américaine',
#     '.']}, {'english_tokens': ['i', 'am', 'japanese', '.'],
#    'french_tokens': ['je', 'suis', 'japonais', '.']}, {'english_tokens': ['i',
#     'am',
#     'a',
#     'muslim',
#     '.'],
#    'french_tokens': ['je', 'suis', 'musulman', '.']}, {'english_tokens': ['i',
#     'am',
#     'a',
#     'muslim',
#     '.'],
#    'french_tokens': ['je', 'suis', 'musulmane', '.']}, {'english_tokens': ['i',
#     'am',
#     'a',
#     'muslim',
#     '.'],
#    'french_tokens': ['je', 'suis', 'musulman', '.']}, {'english_tokens': ['i',
#     'am',
#     'a',
#     'runner',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'un',
#     'coureur',
#     '.']}, {'english_tokens': ['i', 'am', 'all', 'ears', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'tout',
#     'ouïe',
#     '.']}, {'english_tokens': ['i', 'am', 'diabetic', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'diabétique',
#     '.']}, {'english_tokens': ['i', 'am', 'divorced', '.'],
#    'french_tokens': ['je', 'suis', 'divorcé', '.']}, {'english_tokens': ['i',
#     'am',
#     'divorced',
#     '.'],
#    'french_tokens': ['je', 'suis', 'divorcée', '.']}, {'english_tokens': ['i',
#     'am',
#     'in',
#     'paris',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'à',
#     'paris',
#     '.']}, {'english_tokens': ['i', 'am', 'new', 'here', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'nouveau',
#     'ici',
#     '.']}, {'english_tokens': ['i', 'am', 'new', 'here', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'nouveau',
#     ',',
#     'ici',
#     '.']}, {'english_tokens': ['i', 'am', 'not', 'deaf', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'pas',
#     'sourd',
#     '.']}, {'english_tokens': ['i', 'am', 'so', 'sorry', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'tellement',
#     'désolé',
#     '!']}, {'english_tokens': ['i', 'am', 'so', 'sorry', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'tellement',
#     'désolée',
#     '!']}, {'english_tokens': ['i', 'am', 'very', 'sad', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'très',
#     'triste',
#     '.']}, {'english_tokens': ['i', 'am', 'hungarian', '.'],
#    'french_tokens': ['je', 'suis', 'hongrois', '.']}, {'english_tokens': ['i',
#     'am',
#     'a',
#     'shy',
#     'boy',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'un',
#     'garçon',
#     'timide',
#     '.']}, {'english_tokens': ['i', 'am', 'a', 'student', '.'],
#    'french_tokens': ['je', 'suis', 'étudiant', '.']}, {'english_tokens': ['i',
#     'am',
#     'a',
#     'teacher',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'professeur',
#     '.']}, {'english_tokens': ['i', 'am', 'a', 'tourist', '.'],
#    'french_tokens': ['je', 'suis', 'touriste', '.']}, {'english_tokens': ['i',
#     'am',
#     'after',
#     'him',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'après',
#     'lui',
#     '.']}, {'english_tokens': ['i', 'am', 'an', 'artist', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'un',
#     'artiste',
#     '.']}, {'english_tokens': ['i', 'am', 'an', 'artist', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'une',
#     'artiste',
#     '.']}, {'english_tokens': ['i', 'am', 'exhausted', '.'],
#    'french_tokens': ['je', 'suis', 'épuisée', '.']}, {'english_tokens': ['i',
#     'am',
#     'exhausted',
#     '.'],
#    'french_tokens': ['je', 'suis', 'épuisé', '.']}, {'english_tokens': ['i',
#     'am',
#     'exhausted',
#     '.'],
#    'french_tokens': ['je', 'suis', 'vanné', '.']}, {'english_tokens': ['i',
#     'am',
#     'exhausted',
#     '.'],
#    'french_tokens': ['je', 'suis', 'vannée', '.']}, {'english_tokens': ['i',
#     'am',
#     'exhausted',
#     '.'],
#    'french_tokens': ['je', 'suis', 'fourbu', '.']}, {'english_tokens': ['i',
#     'am',
#     'exhausted',
#     '.'],
#    'french_tokens': ['je', 'suis', 'crevé', '.']}, {'english_tokens': ['i',
#     'am',
#     'in',
#     'london',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'à',
#     'londres',
#     '.']}, {'english_tokens': ['i', 'am', 'in', 'a', 'spot', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'dans',
#     'le',
#     'pétrin',
#     '.']}, {'english_tokens': ['i', 'am', 'in', 'a', 'spot', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'dans',
#     'un',
#     'endroit',
#     '.']}, {'english_tokens': ['i', 'am', 'not', 'happy', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'pas',
#     'content',
#     '.']}, {'english_tokens': ['i', 'am', 'not', 'happy', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'pas',
#     'heureux',
#     '.']}, {'english_tokens': ['i', 'am', 'not', 'happy', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'pas',
#     'heureuse',
#     '.']}, {'english_tokens': ['i', 'am', 'not', 'happy', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'pas',
#     'contente',
#     '.']}, {'english_tokens': ['i', 'am', 'off', 'today', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'en',
#     'congé',
#     ',',
#     "aujourd'hui",
#     '.']}, {'english_tokens': ['i', 'am', 'off', 'today', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'pas',
#     'de',
#     'service',
#     ',',
#     "aujourd'hui",
#     '.']}, {'english_tokens': ['i', 'am', 'off', 'today', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'pas',
#     'en',
#     'service',
#     ',',
#     "aujourd'hui",
#     '.']}, {'english_tokens': ['i', 'am', 'too', 'short', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'trop',
#     'petit',
#     '.']}, {'english_tokens': ['i', 'am', 'very', 'tall', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'très',
#     'grand',
#     '.']}, {'english_tokens': ['i', 'am', 'very', 'tall', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'très',
#     'grande',
#     '.']}, {'english_tokens': ['i', 'am', 'a', 'japanese', '.'],
#    'french_tokens': ['je', 'suis', 'japonais', '.']}, {'english_tokens': ['i',
#     'am',
#     'a',
#     'bachelor',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'célibataire',
#     '.']}, {'english_tokens': ['i', 'am', 'a', 'good', 'boy', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'un',
#     'bon',
#     'garçon',
#     '.']}, {'english_tokens': ['i', 'am', 'busy', 'today', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'occupé',
#     'aujourd',
#     '’',
#     'hui',
#     '.']}, {'english_tokens': ['i', 'am', 'from', 'egypt', '.'],
#    'french_tokens': ['je', 'viens', "d'égypte", '.']}, {'english_tokens': ['i',
#     'am',
#     'in',
#     'trouble',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'dans',
#     'le',
#     'pétrin',
#     '.']}, {'english_tokens': ['i', 'am', 'in', 'trouble', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'mal',
#     'barré',
#     '.']}, {'english_tokens': ['i', 'am', 'in', 'trouble', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'mal',
#     'barrée',
#     '.']}, {'english_tokens': ['i', 'am', 'not', 'eating', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'pas',
#     'en',
#     'train',
#     'de',
#     'manger',
#     '.']}, {'english_tokens': ['i', 'am', 'undressing', '.'],
#    'french_tokens': ['je', 'me', 'déshabille', '.']}, {'english_tokens': ['i',
#     'am',
#     'undressing',
#     '.'],
#    'french_tokens': ['je', 'me', 'dévêts', '.']}, {'english_tokens': ['i',
#     'am',
#     'very',
#     'sorry',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'vraiment',
#     'désolé',
#     '.']}, {'english_tokens': ['i', 'am', 'very', 'tired', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'très',
#     'fatigué',
#     '.']}, {'english_tokens': ['i', 'am', 'a', 'bit', 'drunk', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'un',
#     'peu',
#     'ivre',
#     '.']}, {'english_tokens': ['i', 'am', 'a', 'foreigner', '.'],
#    'french_tokens': ['je', 'suis', 'étranger', '.']}, {'english_tokens': ['i',
#     'am',
#     'a',
#     'housewife',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'femme',
#     'au',
#     'foyer',
#     '.']}, {'english_tokens': ['i', 'am', 'a', 'masochist', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'masochiste',
#     '.']}, {'english_tokens': ['i', 'am', 'a', 'professor', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'professeur',
#     '.']}, {'english_tokens': ['i', 'am', 'a', 'volunteer', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'volontaire',
#     '.']}, {'english_tokens': ['i', 'am', 'an', 'american', '.'],
#    'french_tokens': ['je', 'suis', 'américain', '.']}, {'english_tokens': ['i',
#     'am',
#     'an',
#     'american',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'américaine',
#     '.']}, {'english_tokens': ['i', 'am', 'cooking', 'now', '.'],
#    'french_tokens': ['je',
#     'cuisine',
#     'en',
#     'ce',
#     'moment',
#     '.']}, {'english_tokens': ['i', 'am', 'dumbfounded', '.'],
#    'french_tokens': ['je', 'suis', 'sidéré', '.']}, {'english_tokens': ['i',
#     'am',
#     'from',
#     'brazil',
#     '.'],
#    'french_tokens': ['je',
#     'viens',
#     'du',
#     'brésil',
#     '.']}, {'english_tokens': ['i', 'am', 'from', 'france', '.'],
#    'french_tokens': ['je',
#     'viens',
#     'de',
#     'france',
#     '.']}, {'english_tokens': ['i', 'am', 'from', 'russia', '.'],
#    'french_tokens': ['je',
#     'viens',
#     'de',
#     'russie',
#     '.']}, {'english_tokens': ['i', 'am', 'frying', 'fish', '.'],
#    'french_tokens': ['je',
#     'fais',
#     'frire',
#     'du',
#     'poisson',
#     '.']}, {'english_tokens': ['i', 'am', 'not', 'kidding', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'blague',
#     'pas',
#     '.']}, {'english_tokens': ['i', 'am', 'on', 'duty', 'now', '.'],
#    'french_tokens': ['maintenant',
#     'je',
#     'suis',
#     'en',
#     'service',
#     '.']}, {'english_tokens': ['i', 'am', 'on', 'duty', 'now', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'actuellement',
#     'en',
#     'service',
#     '.']}, {'english_tokens': ['i', 'am', 'only', 'joking', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'fais',
#     'que',
#     'blaguer',
#     '.']}, {'english_tokens': ['i', 'am', 'out', 'of', 'time', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'à',
#     'court',
#     'de',
#     'temps',
#     '.']}, {'english_tokens': ['i', 'am', 'out', 'of', 'work', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'au',
#     'chômage',
#     '.']}, {'english_tokens': ['i', 'am', 'out', 'of', 'work', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'sans',
#     'travail',
#     '.']}, {'english_tokens': ['i', 'am', 'paid', 'weekly', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'payée',
#     'à',
#     'la',
#     'semaine',
#     '.']}, {'english_tokens': ['i', 'am', 'pretty', 'sure', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'relativement',
#     'sûr',
#     '.']}, {'english_tokens': ['i', 'am', 'truly', 'sorry', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'vraiment',
#     'désolé',
#     '.']}, {'english_tokens': ['i', 'am', 'truly', 'sorry', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'vraiment',
#     'désolée',
#     '.']}, {'english_tokens': ['i', 'am', '18', 'years', 'old', '.'],
#    'french_tokens': ["j'ai", 'dix-huit', 'ans', '.']}, {'english_tokens': ['i',
#     'am',
#     '19',
#     'years',
#     'old',
#     '.'],
#    'french_tokens': ["j'ai", '19', 'ans', '.']}, {'english_tokens': ['i',
#     'am',
#     'a',
#     'bad',
#     'person',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'un',
#     'être',
#     'mauvais',
#     '.']}, {'english_tokens': ['i', 'am', 'a', 'cat', 'person', '.'],
#    'french_tokens': ["j'aime", 'les', 'chats', '.']}, {'english_tokens': ['i',
#     'am',
#     'a',
#     'vegetarian',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'végétarienne',
#     '.']}, {'english_tokens': ['i', 'am', 'afraid', 'to', 'go', '.'],
#    'french_tokens': ["j'ai",
#     'peur',
#     'd',
#     "'",
#     'y',
#     'aller',
#     '.']}, {'english_tokens': ['i', 'am', 'afraid', 'to', 'go', '.'],
#    'french_tokens': ["j'ai",
#     'peur',
#     'de',
#     'm',
#     "'",
#     'y',
#     'rendre',
#     '.']}, {'english_tokens': ['i', 'am', 'almost', 'ready', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'presque',
#     'prêt',
#     '.']}, {'english_tokens': ['i', 'am', 'almost', 'ready', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'presque',
#     'prête',
#     '.']}, {'english_tokens': ['i', 'am', 'almost', 'ready', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'quasiment',
#     'prête',
#     '.']}, {'english_tokens': ['i', 'am', 'baking', 'bread', '.'],
#    'french_tokens': ['je',
#     'cuis',
#     'du',
#     'pain',
#     '.']}, {'english_tokens': ['i', 'am', 'baking', 'bread', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'en',
#     'train',
#     'de',
#     'cuire',
#     'du',
#     'pain',
#     '.']}, {'english_tokens': ['i', 'am', 'from', 'england', '.'],
#    'french_tokens': ['je',
#     'viens',
#     "d'angleterre",
#     '.']}, {'english_tokens': ['i', 'am', 'going', 'to', 'bed', '.'],
#    'french_tokens': ['je', 'vais', 'au', 'lit', '.']}, {'english_tokens': ['i',
#     'am',
#     'going',
#     'to',
#     'bed',
#     '.'],
#    'french_tokens': ['je', 'vais', 'dormir', '.']}, {'english_tokens': ['i',
#     'am',
#     'good',
#     'at',
#     'math',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'bon',
#     'en',
#     'maths',
#     '.']}, {'english_tokens': ['i', 'am', 'in', 'the', 'house', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'dans',
#     'la',
#     'maison',
#     '.']}, {'english_tokens': ['i', 'am', 'in', 'your', 'debt', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'votre',
#     'débiteur',
#     '.']}, {'english_tokens': ['i', 'am', 'in', 'your', 'debt', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'votre',
#     'débitrice',
#     '.']}, {'english_tokens': ['i', 'am', 'not', 'like', 'you', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'pas',
#     'comme',
#     'toi',
#     '.']}, {'english_tokens': ['i', 'am', 'not', 'like', 'you', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'pas',
#     'comme',
#     'vous',
#     '.']}, {'english_tokens': ['i', 'am', 'rather', 'happy', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'assez',
#     'content',
#     '.']}, {'english_tokens': ['i', 'am', 'ready', 'to', 'die', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'préparé',
#     'à',
#     'mourir',
#     '.']}, {'english_tokens': ['i', 'am', 'ready', 'to', 'die', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'prêt',
#     'à',
#     'mourir',
#     '.']}, {'english_tokens': ['i', 'am', 'so', 'exhausted', '!'],
#    'french_tokens': ['je',
#     'suis',
#     'si',
#     'épuisé',
#     '!']}, {'english_tokens': ['i', 'am', 'so', 'exhausted', '!'],
#    'french_tokens': ['je',
#     'suis',
#     'si',
#     'épuisée',
#     '!']}, {'english_tokens': ['i', 'am', 'studying', 'now', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'en',
#     'train',
#     "d'étudier",
#     '.']}, {'english_tokens': ['i', 'am', 'the', 'same', 'age', '.'],
#    'french_tokens': ["j'ai",
#     'le',
#     'même',
#     'âge',
#     '.']}, {'english_tokens': ['i', 'am', 'the', 'same', 'age', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'du',
#     'même',
#     'âge',
#     '.']}, {'english_tokens': ['i', 'am', 'very', 'curious', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'très',
#     'curieux',
#     '.']}, {'english_tokens': ['i', 'am', 'very', 'pleased', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'très',
#     'satisfait',
#     '.']}, {'english_tokens': ['i', 'am', 'very', 'pleased', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'très',
#     'content',
#     '.']}, {'english_tokens': ['i', 'am', 'a', 'new', 'student', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'un',
#     'nouvel',
#     'étudiant',
#     '.']}, {'english_tokens': ['i', 'am', 'an', 'only', 'child', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'enfant',
#     'unique',
#     '.']}, {'english_tokens': ['i', 'am', 'boiling', 'water', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'en',
#     'train',
#     'de',
#     'bouillir',
#     'de',
#     "l'eau",
#     '.']}, {'english_tokens': ['i', 'am', 'doing', 'my', 'best', '.'],
#    'french_tokens': ['je',
#     'fais',
#     'de',
#     'mon',
#     'mieux',
#     '.']}, {'english_tokens': ['i', 'am', 'done', 'teaching', '.'],
#    'french_tokens': ["j'ai",
#     'fini',
#     "d'enseigner",
#     '.']}, {'english_tokens': ['i', 'am', 'fond', 'of', 'music', '.'],
#    'french_tokens': ["j'adore",
#     'la',
#     'musique',
#     '.']}, {'english_tokens': ['i', 'am', 'from', 'portugal', '.'],
#    'french_tokens': ['je',
#     'viens',
#     'de',
#     'portugal',
#     '.']}, {'english_tokens': ['i', 'am', 'from', 'shizuoka', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'de',
#     'shizuoka',
#     '.']}, {'english_tokens': ['i', 'am', 'grilling', 'fish', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'en',
#     'train',
#     'de',
#     'griller',
#     'du',
#     'poisson',
#     '.']}, {'english_tokens': ['i', 'am', 'in', 'deep', 'water', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'en',
#     'grande',
#     'difficulté',
#     '.']}, {'english_tokens': ['i', 'am', 'in', 'the', 'garden', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'dans',
#     'le',
#     'jardin',
#     '.']}, {'english_tokens': ['i', 'am', 'just', 'a', 'nobody', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'juste',
#     'un',
#     'monsieur',
#     'tout-le-monde',
#     '.']}, {'english_tokens': ['i', 'am', 'not', 'a', 'teacher', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'pas',
#     'un',
#     'enseignant',
#     '.']}, {'english_tokens': ['i', 'am', 'not', 'a', 'teacher', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'pas',
#     'enseignant',
#     '.']}, {'english_tokens': ['i', 'am', 'not', 'ready', 'yet', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'pas',
#     'encore',
#     'prêt',
#     '.']}, {'english_tokens': ['i', 'am', 'not', 'ready', 'yet', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'pas',
#     'encore',
#     'prête',
#     '.']}, {'english_tokens': ['i', 'am', 'not', 'too', 'tired', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'pas',
#     'trop',
#     'fatigué',
#     '.']}, {'english_tokens': ['i', 'am', 'sorry', 'for', 'you', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'désolé',
#     'pour',
#     'toi',
#     '.']}, {'english_tokens': ['i', 'am', 'a', 'fast', 'swimmer', '.'],
#    'french_tokens': ['je',
#     'peux',
#     'nager',
#     'très',
#     'vite',
#     '.']}, {'english_tokens': ['i', 'am', 'a', 'teacher', ',', 'too', '.'],
#    'french_tokens': ['moi',
#     'aussi',
#     ',',
#     'je',
#     'suis',
#     'professeur',
#     '.']}, {'english_tokens': ['i', 'am', 'a', 'teacher', ',', 'too', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'également',
#     'enseignant',
#     '.']}, {'english_tokens': ['i', 'am', 'afraid', 'of', 'dogs', '.'],
#    'french_tokens': ["j'ai",
#     'peur',
#     'des',
#     'chiens',
#     '.']}, {'english_tokens': ['i', 'am', 'an', 'electrician', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'électricien',
#     '.']}, {'english_tokens': ['i', 'am', 'an', 'electrician', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'un',
#     'électricien',
#     '.']}, {'english_tokens': ['i', 'am', 'bored', 'to', 'death', '.'],
#    'french_tokens': ['je',
#     "m'ennuie",
#     'à',
#     'en',
#     'mourir',
#     '.']}, {'english_tokens': ['i', 'am', 'eating', 'noodles', '.'],
#    'french_tokens': ['je',
#     'mange',
#     'des',
#     'nouilles',
#     '.']}, {'english_tokens': ['i', 'am', 'engaged', 'to', 'her', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'fiancé',
#     'avec',
#     'elle',
#     '.']}, {'english_tokens': ['i', 'am', 'fond', 'of', 'skiing', '.'],
#    'french_tokens': ["j'aime", 'skier', '.']}, {'english_tokens': ['i',
#     'am',
#     'free',
#     'from',
#     'care',
#     '.'],
#    'french_tokens': ['je',
#     'ne',
#     "m'en",
#     'fais',
#     'pas',
#     '.']}, {'english_tokens': ['i', 'am', 'going', 'to', 'sleep', '.'],
#    'french_tokens': ['je',
#     'vais',
#     'aller',
#     'rejoindre',
#     'les',
#     'bras',
#     'de',
#     'morphée',
#     '.']}, {'english_tokens': ['i', 'am', 'going', 'to', 'sleep', '.'],
#    'french_tokens': ['je', 'vais', 'dormir', '.']}, {'english_tokens': ['i',
#     'am',
#     'going',
#     'to',
#     'study',
#     '.'],
#    'french_tokens': ['je', 'vais', 'étudier', '.']}, {'english_tokens': ['i',
#     'am',
#     'in',
#     'charge',
#     'here',
#     '.'],
#    'french_tokens': ["c'est",
#     'moi',
#     'le',
#     'patron',
#     ',',
#     'ici',
#     '.']}, {'english_tokens': ['i', 'am', 'like', 'my', 'mother', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'comme',
#     'ma',
#     'mère',
#     '.']}, {'english_tokens': ['i', 'am', 'not', 'your', 'enemy', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'pas',
#     'votre',
#     'ennemi',
#     '.']}, {'english_tokens': ['i', 'am', 'not', 'your', 'enemy', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'pas',
#     'votre',
#     'ennemie',
#     '.']}, {'english_tokens': ['i', 'am', 'not', 'your', 'enemy', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'pas',
#     'ton',
#     'ennemi',
#     '.']}, {'english_tokens': ['i', 'am', 'not', 'your', 'enemy', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'pas',
#     'ton',
#     'ennemie',
#     '.']}, {'english_tokens': ['i', 'am', 'off', 'duty', 'today', '.'],
#    'french_tokens': ["j'ai",
#     'congé',
#     ',',
#     "aujourd'hui",
#     '.']}, {'english_tokens': ['i', 'am', 'older', 'than', 'him', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'plus',
#     'vieux',
#     'que',
#     'lui',
#     '.']}, {'english_tokens': ['i', 'am', 'peeling', 'apples', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'en',
#     'train',
#     "d'éplucher",
#     'des',
#     'pommes',
#     '.']}, {'english_tokens': ['i', 'am', 'poor', 'at', 'tennis', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'médiocre',
#     'au',
#     'tennis',
#     '.']}, {'english_tokens': ['i', 'am', 'reading', 'a', 'book', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'en',
#     'train',
#     'de',
#     'lire',
#     'un',
#     'livre',
#     '.']}, {'english_tokens': ['i', 'am', 'right', 'for', 'once', '.'],
#    'french_tokens': ['pour',
#     'une',
#     'fois',
#     "j'ai",
#     'raison',
#     '.']}, {'english_tokens': ['i', 'am', 'sad', 'to', 'hear', 'it', '.'],
#    'french_tokens': ['ça',
#     'me',
#     'rend',
#     'triste',
#     "d'entendre",
#     'ça',
#     '.']}, {'english_tokens': ['i', 'am', 'short', 'of', 'money', '.'],
#    'french_tokens': ['je',
#     'manque',
#     "d'argent",
#     '.']}, {'english_tokens': ['i', 'am', 'short', 'of', 'money', '.'],
#    'french_tokens': ["j'ai",
#     'un',
#     'problème',
#     "d'argent",
#     '.']}, {'english_tokens': ['i', 'am', 'the', 'chosen', 'one', '.'],
#    'french_tokens': ['je', 'suis', "l'élu", '.']}, {'english_tokens': ['i',
#     'am',
#     'the',
#     'chosen',
#     'one',
#     '.'],
#    'french_tokens': ['je', 'suis', "l'élue", '.']}, {'english_tokens': ['i',
#     'am',
#     'very',
#     'dangerous',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'vraiment',
#     'dangereux',
#     '.']}, {'english_tokens': ['i', 'am', 'a', 'stranger', 'here', '.'],
#    'french_tokens': ['ici',
#     ',',
#     'je',
#     'suis',
#     'un',
#     'étranger',
#     '.']}, {'english_tokens': ['i', 'am', 'a', 'stranger', 'here', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'étranger',
#     'ici',
#     '.']}, {'english_tokens': ['i', 'am', 'a', 'stranger', 'here', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'un',
#     'étranger',
#     'ici',
#     '.']}, {'english_tokens': ['i', 'am', 'a', 'stranger', 'here', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'un',
#     'étranger',
#     ',',
#     'ici',
#     '.']}, {'english_tokens': ['i', 'am', 'afraid', 'of', 'bears', '.'],
#    'french_tokens': ["j'ai",
#     'peur',
#     'des',
#     'ours',
#     '.']}, {'english_tokens': ['i', 'am', 'afraid', 'of', 'death', '.'],
#    'french_tokens': ["j'ai",
#     'peur',
#     'de',
#     'la',
#     'mort',
#     '.']}, {'english_tokens': ['i', 'am', 'afraid', 'of', 'dying', '.'],
#    'french_tokens': ["j'ai",
#     'peur',
#     'de',
#     'mourir',
#     '.']}, {'english_tokens': ['i', 'am', 'better', 'than', 'you', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'meilleur',
#     'que',
#     'toi',
#     '.']}, {'english_tokens': ['i', 'am', 'counting', 'on', 'you', '.'],
#    'french_tokens': ['je',
#     'compte',
#     'sur',
#     'toi',
#     '.']}, {'english_tokens': ['i', 'am', 'drinking', 'coffee', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'en',
#     'train',
#     'de',
#     'boire',
#     'du',
#     'café',
#     '.']}, {'english_tokens': ['i', 'am', 'eating', 'an', 'apple', '.'],
#    'french_tokens': ['je',
#     'mange',
#     'une',
#     'pomme',
#     '.']}, {'english_tokens': ['i', 'am', 'forced', 'to', 'do', 'it', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'contraint',
#     'à',
#     'le',
#     'faire',
#     '.']}, {'english_tokens': ['i', 'am', 'getting', 'dressed', '.'],
#    'french_tokens': ['je', 'me', 'vêts', '.']}, {'english_tokens': ['i',
#     'am',
#     'glad',
#     'to',
#     'see',
#     'her',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'contente',
#     'de',
#     'la',
#     'voir',
#     '.']}, {'english_tokens': ['i', 'am', 'glad', 'to', 'see', 'her', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'content',
#     'de',
#     'la',
#     'voir',
#     '.']}, {'english_tokens': ['i', 'am', 'looking', 'at', 'that', '.'],
#    'french_tokens': ['je', 'regarde', 'ça', '.']}, {'english_tokens': ['i',
#     'am',
#     'no',
#     'longer',
#     'tired',
#     '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'plus',
#     'fatigué',
#     '.']}, {'english_tokens': ['i', 'am', 'no', 'longer', 'tired', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'plus',
#     'fatiguée',
#     '.']}, {'english_tokens': ['i', 'am', 'not', 'well', 'at', 'all', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'vais',
#     'pas',
#     'bien',
#     'du',
#     'tout',
#     '.']}, {'english_tokens': ['i', 'am', 'playing', 'it', 'safe', '.'],
#    'french_tokens': ['je',
#     'joue',
#     'prudemment',
#     '.']}, {'english_tokens': ['i', 'am', 'poor', 'at', 'drawing', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'mauvais',
#     'en',
#     'dessin',
#     '.']}, {'english_tokens': ['i', 'am', 'telling', 'a', 'story', '.'],
#    'french_tokens': ['je',
#     'conte',
#     'une',
#     'histoire',
#     '.']}, {'english_tokens': ['i', 'am', 'terribly', 'hungry', '.'],
#    'french_tokens': ["j'ai",
#     'terriblement',
#     'faim',
#     '.']}, {'english_tokens': ['i', 'am', 'waiting', 'my', 'turn', '.'],
#    'french_tokens': ["j'attends",
#     'mon',
#     'tour',
#     '.']}, {'english_tokens': ['i', 'am', 'wasting', 'my', 'time', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'en',
#     'train',
#     'de',
#     'perdre',
#     'mon',
#     'temps',
#     '.']}, {'english_tokens': ['i', 'am', 'weighing', 'myself', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'en',
#     'train',
#     'de',
#     'me',
#     'peser',
#     '.']}, {'english_tokens': ['i', 'am', 'an', 'office', 'worker', '.'],
#    'french_tokens': ["j'ai",
#     'un',
#     'emploi',
#     'de',
#     'bureau',
#     '.']}, {'english_tokens': ['i', 'am', 'folding', 'my', 'dress', '.'],
#    'french_tokens': ['je',
#     'plie',
#     'ma',
#     'robe',
#     '.']}, {'english_tokens': ['i', 'am', 'glad', 'to', 'help', 'you', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'content',
#     'de',
#     "t'aider",
#     '.']}, {'english_tokens': ['i', 'am', 'glad', 'to', 'help', 'you', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'ravi',
#     'de',
#     "t'aider",
#     '.']}, {'english_tokens': ['i', 'am', 'glad', 'to', 'help', 'you', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'contente',
#     'de',
#     "t'aider",
#     '.']}, {'english_tokens': ['i', 'am', 'glad', 'to', 'help', 'you', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'ravie',
#     'de',
#     "t'aider",
#     '.']}, {'english_tokens': ['i', 'am', 'glad', 'to', 'help', 'you', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'content',
#     'de',
#     'vous',
#     'aider',
#     '.']}, {'english_tokens': ['i', 'am', 'glad', 'to', 'help', 'you', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'ravie',
#     'de',
#     'vous',
#     'aider',
#     '.']}, {'english_tokens': ['i', 'am', 'glad', 'to', 'help', 'you', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'ravi',
#     'de',
#     'vous',
#     'aider',
#     '.']}, {'english_tokens': ['i', 'am', 'glad', 'to', 'help', 'you', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'contente',
#     'de',
#     'vous',
#     'aider',
#     '.']}, {'english_tokens': ['i', 'am', 'grateful', 'to', 'them', '.'],
#    'french_tokens': ['je',
#     'leur',
#     'suis',
#     'reconnaissant',
#     '.']}, {'english_tokens': ['i', 'am', 'harvesting', 'wheat', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'en',
#     'train',
#     'de',
#     'récolter',
#     'du',
#     'blé',
#     '.']}, {'english_tokens': ['i', 'am', 'here', 'on', 'business', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'ici',
#     'pour',
#     'affaires',
#     '.']}, {'english_tokens': ['i', 'am', 'in', 'the', 'classroom', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'en',
#     'salle',
#     'de',
#     'classe',
#     '.']}, {'english_tokens': ['i', 'am', 'near', 'the', 'station', '.'],
#    'french_tokens': ['je',
#     'me',
#     'trouve',
#     'près',
#     'de',
#     'la',
#     'gare',
#     '.']}, {'english_tokens': ['i', 'am', 'no', 'match', 'for', 'him', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'peux',
#     'pas',
#     'me',
#     'comparer',
#     'à',
#     'lui',
#     '.']}, {'english_tokens': ['i', 'am', 'no', 'match', 'for', 'him', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'pas',
#     'de',
#     'taille',
#     'à',
#     'me',
#     'mesurer',
#     'à',
#     'lui',
#     '.']}, {'english_tokens': ['i', 'am', 'not', 'studying', 'now', '.'],
#    'french_tokens': ['en',
#     'ce',
#     'moment',
#     'je',
#     "n'étudie",
#     'pas',
#     '.']}, {'english_tokens': ['i', 'am', 'poor', 'at', 'swimming', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'sais',
#     'pas',
#     'bien',
#     'nager',
#     '.']}, {'english_tokens': ['i', 'am', 'reading', 'a', 'letter', '.'],
#    'french_tokens': ['je',
#     'lis',
#     'une',
#     'lettre',
#     '.']}, {'english_tokens': ['i', 'am', 'reading', 'a', 'letter', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'en',
#     'train',
#     'de',
#     'lire',
#     'une',
#     'lettre',
#     '.']}, {'english_tokens': ['i', 'am', 'shorter', 'than', 'you', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'plus',
#     'petit',
#     'que',
#     'toi',
#     '.']}, {'english_tokens': ['i', 'am', 'shorter', 'than', 'you', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'plus',
#     'petite',
#     'que',
#     'vous',
#     '.']}, {'english_tokens': ['i', 'am', 'shorter', 'than', 'you', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'plus',
#     'petit',
#     'que',
#     'vous',
#     '.']}, {'english_tokens': ['i', 'am', 'tired', 'of', 'reading', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'fatigué',
#     'de',
#     'lire',
#     '.']}, {'english_tokens': ['i', 'am', 'too', 'tired', 'to', 'run', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'trop',
#     'fatigué',
#     'pour',
#     'courir',
#     '.']}, {'english_tokens': ['i', 'am', 'totally', 'confused', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'complètement',
#     'confus',
#     '.']}, {'english_tokens': ['i', 'am', 'totally', 'confused', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'complètement',
#     'confuse',
#     '.']}, {'english_tokens': ['i', 'am', 'writing', 'a', 'letter', '.'],
#    'french_tokens': ["j'écris",
#     'une',
#     'lettre',
#     '.']}, {'english_tokens': ['i', 'am', 'afraid', 'of', 'heights', '.'],
#    'french_tokens': ['je',
#     'souffre',
#     'de',
#     'vertige',
#     '.']}, {'english_tokens': ['i', 'am', 'ashamed', 'of', 'myself', '.'],
#    'french_tokens': ["j'ai",
#     'honte',
#     'de',
#     'moi-même',
#     '.']}, {'english_tokens': ['i', 'am', 'brushing', 'my', 'teeth', '.'],
#    'french_tokens': ['je',
#     'me',
#     'brosse',
#     'les',
#     'dents',
#     '.']}, {'english_tokens': ['i', 'am', 'doing', 'my', 'homework', '.'],
#    'french_tokens': ['je',
#     'fais',
#     'mes',
#     'devoirs',
#     '.']}, {'english_tokens': ['i', 'am', 'doing', 'my', 'homework', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'en',
#     'train',
#     'de',
#     'faire',
#     'mes',
#     'devoirs',
#     '.']}, {'english_tokens': ['i', 'am', 'eating', 'a', 'sandwich', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'en',
#     'train',
#     'de',
#     'manger',
#     'un',
#     'sandwich',
#     '.']}, {'english_tokens': ['i', 'am', 'happy', 'to', 'meet', 'you', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'heureux',
#     'de',
#     'te',
#     'voir',
#     '.']}, {'english_tokens': ['i', 'am', 'leaving', 'next', 'week', '.'],
#    'french_tokens': ['je',
#     'pars',
#     'la',
#     'semaine',
#     'prochaine',
#     '.']}, {'english_tokens': ['i', 'am', 'moving', 'next', 'month', '.'],
#    'french_tokens': ['je',
#     'déménage',
#     'le',
#     'mois',
#     'prochain',
#     '.']}, {'english_tokens': ['i', 'am', 'moving', 'next', 'month', '.'],
#    'french_tokens': ['je',
#     "m'en",
#     'vais',
#     'le',
#     'mois',
#     'prochain',
#     '.']}, {'english_tokens': ['i', 'am', 'no', 'longer', 'a', 'child', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'plus',
#     'un',
#     'enfant',
#     '.']}, {'english_tokens': ['i', 'am', 'not', 'proud', 'of', 'this', '.'],
#    'french_tokens': ['je',
#     "n'en",
#     'suis',
#     'pas',
#     'fier',
#     '.']}, {'english_tokens': ['i', 'am', 'not', 'proud', 'of', 'this', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'pas',
#     'fier',
#     'de',
#     'ça',
#     '.']}, {'english_tokens': ['i', 'am', 'off', 'duty', 'tomorrow', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'libre',
#     'demain',
#     '.']}, {'english_tokens': ['i', 'am', 'off', 'duty', 'tomorrow', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'pas',
#     'de',
#     'garde',
#     ',',
#     'demain',
#     '.']}, {'english_tokens': ['i', 'am', 'ready', 'to', 'help', 'you', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'prêt',
#     'à',
#     "t'aider",
#     '.']}, {'english_tokens': ['i', 'am', 'sixteen', 'years', 'old', '.'],
#    'french_tokens': ["j'ai", 'seize', 'ans', '.']}, {'english_tokens': ['i',
#     'am',
#     'swamped',
#     'with',
#     'work',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'submergé',
#     'de',
#     'travail',
#     '.']}, {'english_tokens': ['i', 'am', 'taking', 'a', 'bath', 'now', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'actuellement',
#     'en',
#     'train',
#     'de',
#     'prendre',
#     'un',
#     'bain',
#     '.']}, {'english_tokens': ['i', 'am', 'tired', 'of', 'homework', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'fatigué',
#     'des',
#     'devoirs',
#     '.']}, {'english_tokens': ['i', 'am', 'tired', 'of', 'homework', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'fatiguée',
#     'des',
#     'devoirs',
#     '.']}, {'english_tokens': ['i', 'am', 'worried', 'about', 'him', '.'],
#    'french_tokens': ['je',
#     'me',
#     'fais',
#     'du',
#     'souci',
#     'pour',
#     'lui',
#     '.']}, {'english_tokens': ['i', 'am', 'an', 'english', 'teacher', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'professeur',
#     "d'anglais",
#     '.']}, {'english_tokens': ['i', 'am', 'disgusted', 'with', 'him', '.'],
#    'french_tokens': ['il', 'me', 'dégoute', '.']}, {'english_tokens': ['i',
#     'am',
#     'eighteen',
#     'years',
#     'old',
#     '.'],
#    'french_tokens': ["j'ai", 'dix-huit', 'ans', '.']}, {'english_tokens': ['i',
#     'am',
#     'following',
#     'that',
#     'car',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'cette',
#     'voiture',
#     '.']}, {'english_tokens': ['i', 'am', 'loved', 'by', 'my', 'mother', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'aimé',
#     'de',
#     'ma',
#     'mère',
#     '.']}, {'english_tokens': ['i', 'am', 'loved', 'by', 'my', 'mother', '.'],
#    'french_tokens': ['ma', 'mère', "m'aime", '.']}, {'english_tokens': ['i',
#     'am',
#     'not',
#     'going',
#     'anywhere',
#     '.'],
#    'french_tokens': ['je',
#     'ne',
#     'vais',
#     'nulle',
#     'part',
#     '.']}, {'english_tokens': ['i', 'am', 'not', 'going', 'anywhere', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'me',
#     'rends',
#     'nulle',
#     'part',
#     '.']}, {'english_tokens': ['i', 'am', 'reading', 'a', 'magazine', '.'],
#    'french_tokens': ['je',
#     'lis',
#     'un',
#     'magazine',
#     '.']}, {'english_tokens': ['i', 'am', 'the', 'fastest', 'runner', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'le',
#     'coureur',
#     'le',
#     'plus',
#     'rapide',
#     '.']}, {'english_tokens': ['i', 'am', 'too', 'tired', 'to', 'climb', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'trop',
#     'fatigué',
#     'pour',
#     'grimper',
#     '.']}, {'english_tokens': ['i', 'am', 'very', 'happy', 'with', 'it', '.'],
#    'french_tokens': ['ça',
#     'me',
#     'plaît',
#     'beaucoup',
#     '.']}, {'english_tokens': ['i', 'am', 'your', 'friend', ',', 'right', '?'],
#    'french_tokens': ['je',
#     'suis',
#     'bien',
#     'ton',
#     'ami',
#     ',',
#     'non',
#     '?']}, {'english_tokens': ['i',
#     'am',
#     'able',
#     'to',
#     'drive',
#     'a',
#     'car',
#     '.'],
#    'french_tokens': ['je',
#     'peux',
#     'conduire',
#     'une',
#     'voiture',
#     '.']}, {'english_tokens': ['i', 'am', 'about', 'to', 'leave', 'here', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'sur',
#     'le',
#     'point',
#     'de',
#     'quitter',
#     'ici',
#     '.']}, {'english_tokens': ['i', 'am', 'afraid', 'he', 'will', 'fail', '.'],
#    'french_tokens': ["j'ai",
#     'peur',
#     "qu'il",
#     'échoue',
#     '.']}, {'english_tokens': ['i',
#     'am',
#     'at',
#     'a',
#     'loss',
#     'for',
#     'words',
#     '.'],
#    'french_tokens': ['je',
#     'cherche',
#     'mes',
#     'mots',
#     '.']}, {'english_tokens': ['i', 'am', 'content', 'with', 'my', 'job', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'content',
#     'de',
#     'mon',
#     'emploi',
#     '.']}, {'english_tokens': ['i', 'am', 'free', 'this', 'afternoon', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'libre',
#     'cet',
#     'après-midi',
#     '.']}, {'english_tokens': ['i', 'am', 'going', 'to', 'that', 'place', '.'],
#    'french_tokens': ['je',
#     'vais',
#     'à',
#     'cet',
#     'endroit',
#     '.']}, {'english_tokens': ['i', 'am', 'interested', 'in', 'music', '.'],
#    'french_tokens': ["j'ai",
#     'de',
#     "l'intérêt",
#     'pour',
#     'la',
#     'musique',
#     '.']}, {'english_tokens': ['i', 'am', 'just', 'warming', 'up', 'now', '.'],
#    'french_tokens': ['pour',
#     "l'instant",
#     'je',
#     "m'entraîne",
#     'seulement',
#     '.']}, {'english_tokens': ['i', 'am', 'loved', 'by', 'my', 'parents', '.'],
#    'french_tokens': ['mes',
#     'parents',
#     "m'adorent",
#     '.']}, {'english_tokens': ['i', 'am', 'not', 'romantic', 'at', 'all', '.'],
#    'french_tokens': ['je',
#     'ne',
#     'suis',
#     'pas',
#     'du',
#     'tout',
#     'romantique',
#     '.']}, {'english_tokens': ['i', 'am', 'only', 'warming', 'up', 'now', '.'],
#    'french_tokens': ['pour',
#     "l'instant",
#     'je',
#     "m'entraîne",
#     'seulement',
#     '.']}, {'english_tokens': ['i', 'am', 'playing', 'video', 'games', '.'],
#    'french_tokens': ['je',
#     'joue',
#     'à',
#     'des',
#     'jeux',
#     'vidéo',
#     '.']}, {'english_tokens': ['i', 'am', 'quite', 'all', 'right', 'now', '.'],
#    'french_tokens': ['je',
#     'vais',
#     'tout',
#     'à',
#     'fait',
#     'bien',
#     'maintenant',
#     '.']}, {'english_tokens': ['i', 'am', 'ready', 'to', 'follow', 'you', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'prêt',
#     'à',
#     'te',
#     'suivre',
#     '.']}, {'english_tokens': ['i', 'am', 'ready', 'to', 'follow', 'you', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'prête',
#     'à',
#     'te',
#     'suivre',
#     '.']}, {'english_tokens': ['i', 'am', 'ready', 'to', 'follow', 'you', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'prêt',
#     'à',
#     'vous',
#     'suivre',
#     '.']}, {'english_tokens': ['i', 'am', 'ready', 'to', 'follow', 'you', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'prête',
#     'à',
#     'vous',
#     'suivre',
#     '.']}, {'english_tokens': ['i', 'am', 'sure', 'of', 'her', 'success', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'sûr',
#     'de',
#     'son',
#     'succès',
#     '.']}, {'english_tokens': ['i', 'am', 'sure', 'of', 'her', 'success', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'certaine',
#     'de',
#     'son',
#     'succès',
#     '.']}, {'english_tokens': ['i', 'am', 'sure', 'of', 'her', 'success', '.'],
#    'french_tokens': ['je',
#     'tiens',
#     'son',
#     'succès',
#     'pour',
#     'certain',
#     '.']}, {'english_tokens': ['i', 'am', 'sure', 'of', 'his', 'honesty', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'certaine',
#     'de',
#     'son',
#     'honnêteté',
#     '.']}, {'english_tokens': ['i', 'am', 'sure', 'of', 'his', 'success', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'sûre',
#     "qu'il",
#     'réussira',
#     '.']}, {'english_tokens': ['i', 'am', 'sure', 'of', 'his', 'success', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'sûr',
#     'de',
#     'son',
#     'succès',
#     '.']}, {'english_tokens': ['i', 'am', 'sure', 'of', 'his', 'success', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'sûre',
#     'de',
#     'son',
#     'succès',
#     '.']}, {'english_tokens': ['i', 'am', 'tired', 'of', 'hearing', 'it', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'fatigué',
#     'de',
#     "l'entendre",
#     '.']}, {'english_tokens': ['i', 'am', 'very', 'poor', 'at', 'sports', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'très',
#     'médiocre',
#     'en',
#     'sport',
#     '.']}, {'english_tokens': ['i', 'am', 'willing', 'to', 'help', 'you', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'désireux',
#     'de',
#     "t'aider",
#     '.']}, {'english_tokens': ['i', 'am', 'willing', 'to', 'help', 'you', '.'],
#    'french_tokens': ['je',
#     'suis',
#     'désireux',
#     'de',
#     'vous',
#     'aider',
#     '.']}, {'english_tokens': ['i', 'am', 'a', 'university', 'student', '.'],
#    'french_tokens': ['je', 'suis', 'étudiant', '.']}, {'english_tokens': ['i',
#     'am',
#     'a',
#     'university',
#     'student',
#     '.'],
#    'french_tokens': ['je',
#     'suis',
#     'étudiant',
#     'à',
#     "l'université",
#     '.']}, {'english_tokens': ['i',
#     'am',
#     'acting',
#     'for',
#     'my',
#     'father',
#     '.'],
#    'french_tokens': ["j'agis",
#     'pour',
#     'mon',
#     'père',
#     '.']}, {'english_tokens': ['i',
#     'am',
#     'afraid',
#     'it',
#     "'s",
#     'too',
#     'late',
#     '.'],
#    'french_tokens': ['je',
#     'crains',
#     "qu'il",
#     'ne',
#     'soit',
#     'trop',
#     'tard',
#     '.']}, {'english_tokens': ['i',
#     'am',
#     'bored',
#     'out',
#     'of',
#     'my',
#     'mind',
#     '.'],
#    'french_tokens': ['je',
#     "m'ennuie",
#     'tellement',
#     'que',
#     'je',
#     "n'en",
#     'peux',
#     'plus',
#     '.']}, {'english_tokens': ['i',
#     'am',
#     'bored',
#     'out',
#     'of',
#     'my',
#     'mind',
#     '.'],
#    'french_tokens': ['je',
#     "m'ennuie",
#     'tellement',
# ...
#     "'re",
#     'lucky',
#     'to',
#     'be',
#     'alive',
#     '.'],
#    'french_tokens': ['ils',
#     'ont',
#     'de',
#     'la',
#     'chance',
#     "d'être",
#     'vivants',
#     '.']}, {'english_tokens': ['they', "'re", 'not', 'all', 'criminals', '.'],
#    'french_tokens': ['ce',
#     'ne',
#     'sont',
#     'pas',
#     'tous',
#     'des',
#     'criminels',
#     '.']}, {'english_tokens': ['they', "'re", 'of', 'no', 'consequence', '.'],
#    'french_tokens': ['ils',
#     'sont',
#     'sans',
#     'conséquence',
#     '.']}, {'english_tokens': ['they', "'re", 'young', 'and', 'healthy', '.'],
#    'french_tokens': ['ils',
#     'sont',
#     'jeunes',
#     'et',
#     'en',
#     'bonne',
#     'santé',
#     '.']}, {'english_tokens': ['they', "'re", 'young', 'and', 'healthy', '.'],
#    'french_tokens': ['elles',
#     'sont',
#     'jeunes',
#     'et',
#     'en',
#     'bonne',
#     'santé',
#     '.']}, {'english_tokens': ['they', "'re", 'cleaning', 'the', 'beach', '.'],
#    'french_tokens': ['ils',
#     'nettoient',
#     'la',
#     'plage',
#     '.']}, {'english_tokens': ['they', "'re", 'cleaning', 'the', 'beach', '.'],
#    'french_tokens': ['ils',
#     'sont',
#     'en',
#     'train',
#     'de',
#     'nettoyer',
#     'la',
#     'plage',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'in',
#     'the',
#     'science',
#     'lab',
#     '.'],
#    'french_tokens': ['ils',
#     'sont',
#     'dans',
#     'le',
#     'laboratoire',
#     'de',
#     'sciences',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'in',
#     'the',
#     'science',
#     'lab',
#     '.'],
#    'french_tokens': ['elles',
#     'sont',
#     'dans',
#     'le',
#     'laboratoire',
#     'de',
#     'sciences',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'out',
#     'of',
#     'their',
#     'minds',
#     '.'],
#    'french_tokens': ['ils',
#     'ont',
#     'perdu',
#     "l'esprit",
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'out',
#     'of',
#     'their',
#     'minds',
#     '.'],
#    'french_tokens': ['elles',
#     'ont',
#     'perdu',
#     "l'esprit",
#     '.']}, {'english_tokens': ['they', "'re", 'probably', 'americans', '.'],
#    'french_tokens': ['ils',
#     'sont',
#     'probablement',
#     'étasuniens',
#     '.']}, {'english_tokens': ['they', "'re", 'probably', 'americans', '.'],
#    'french_tokens': ['elles',
#     'sont',
#     'probablement',
#     'étasuniennes',
#     '.']}, {'english_tokens': ['they', "'re", 'very', 'close', 'friends', '.'],
#    'french_tokens': ['ce',
#     'sont',
#     'des',
#     'amis',
#     'très',
#     'proches',
#     '.']}, {'english_tokens': ['they', "'re", 'very', 'close', 'friends', '.'],
#    'french_tokens': ['ce',
#     'sont',
#     'des',
#     'amies',
#     'très',
#     'proches',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'acting',
#     'on',
#     'their',
#     'own',
#     '.'],
#    'french_tokens': ['ils',
#     'agissent',
#     'de',
#     'leur',
#     'propre',
#     'chef',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'acting',
#     'on',
#     'their',
#     'own',
#     '.'],
#    'french_tokens': ['elles',
#     'agissent',
#     'de',
#     'leur',
#     'propre',
#     'chef',
#     '.']}, {'english_tokens': ['they', "'re", 'enjoying', 'themselves', '.'],
#    'french_tokens': ['ils', "s'amusent", '.']}, {'english_tokens': ['they',
#     "'re",
#     'enjoying',
#     'themselves',
#     '.'],
#    'french_tokens': ['elles', "s'amusent", '.']}, {'english_tokens': ['they',
#     "'re",
#     'part-time',
#     'employees',
#     '.'],
#    'french_tokens': ['ce',
#     'sont',
#     'des',
#     'employés',
#     'à',
#     'temps',
#     'partiel',
#     '.']}, {'english_tokens': ['they', "'re", 'part-time', 'employees', '.'],
#    'french_tokens': ['ce',
#     'sont',
#     'des',
#     'employées',
#     'à',
#     'temps',
#     'partiel',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'thirty',
#     'dollars',
#     'each',
#     '.'],
#    'french_tokens': ['ils',
#     'sont',
#     'à',
#     'trente',
#     'dollars',
#     'chacun',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'thirty',
#     'dollars',
#     'each',
#     '.'],
#    'french_tokens': ['elles',
#     'sont',
#     'à',
#     'trente',
#     'dollars',
#     'chacune',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'washing',
#     'their',
#     'hands',
#     '.'],
#    'french_tokens': ['elles',
#     'se',
#     'lavent',
#     'les',
#     'mains',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'against',
#     'animal',
#     'abuse',
#     '.'],
#    'french_tokens': ['ils',
#     'militent',
#     'contre',
#     'les',
#     'violences',
#     'aux',
#     'animaux',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'dragging',
#     'their',
#     'heels',
#     '.'],
#    'french_tokens': ['ils',
#     'traînent',
#     'les',
#     'pieds',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'going',
#     'to',
#     'have',
#     'a',
#     'look',
#     '.'],
#    'french_tokens': ['ils',
#     'vont',
#     'jeter',
#     'un',
#     'coup',
#     "d'œil",
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'going',
#     'to',
#     'torture',
#     'tom',
#     '.'],
#    'french_tokens': ['ils',
#     'vont',
#     'torturer',
#     'tom',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'going',
#     'to',
#     'torture',
#     'tom',
#     '.'],
#    'french_tokens': ['elles',
#     'vont',
#     'torturer',
#     'tom',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'not',
#     'going',
#     'to',
#     'catch',
#     'us',
#     '.'],
#    'french_tokens': ['ils',
#     'ne',
#     'vont',
#     'pas',
#     'nous',
#     'attraper',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'related',
#     'to',
#     'each',
#     'other',
#     '.'],
#    'french_tokens': ['ils',
#     'sont',
#     'apparentés',
#     '.']}, {'english_tokens': ['they', "'re", 'smiling', 'at', 'each', 'other', '.'],
#    'french_tokens': ['ils',
#     'se',
#     'sourient',
#     '.']}, {'english_tokens': ['they', "'re", 'smiling', 'at', 'each', 'other', '.'],
#    'french_tokens': ['elles',
#     'se',
#     'sourient',
#     '.']}, {'english_tokens': ['they', "'re", 'the', 'cream', 'of', 'the', 'crop', '.'],
#    'french_tokens': ['ils',
#     'forment',
#     'le',
#     'dessus',
#     'du',
#     'panier',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'the',
#     'cream',
#     'of',
#     'the',
#     'crop',
#     '.'],
#    'french_tokens': ['elles',
#     'forment',
#     'le',
#     'dessus',
#     'du',
#     'panier',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'walking',
#     'without',
#     'shoes',
#     '.'],
#    'french_tokens': ['ils',
#     'marchent',
#     'pieds',
#     'nus',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'eating',
#     'high',
#     'on',
#     'the',
#     'hog',
#     '.'],
#    'french_tokens': ['ils',
#     'mènent',
#     'grand',
#     'train',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'going',
#     'to',
#     'make',
#     'mistakes',
#     '.'],
#    'french_tokens': ['ils',
#     'vont',
#     'commettre',
#     'des',
#     'erreurs',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'going',
#     'to',
#     'make',
#     'mistakes',
#     '.'],
#    'french_tokens': ['elles',
#     'vont',
#     'commettre',
#     'des',
#     'erreurs',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'keeping',
#     'it',
#     'under',
#     'wraps',
#     '.'],
#    'french_tokens': ['ils',
#     'le',
#     'tiennent',
#     'secret',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'keeping',
#     'it',
#     'under',
#     'wraps',
#     '.'],
#    'french_tokens': ['ils',
#     'le',
#     'gardent',
#     'secret',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'suffering',
#     'from',
#     'malaria',
#     '.'],
#    'french_tokens': ['ils',
#     'souffrent',
#     'du',
#     'paludisme',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'looking',
#     'for',
#     'a',
#     'scapegoat',
#     '.'],
#    'french_tokens': ['ils',
#     'cherchent',
#     'un',
#     'bouc',
#     'émissaire',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'looking',
#     'for',
#     'a',
#     'scapegoat',
#     '.'],
#    'french_tokens': ['elles',
#     'cherchent',
#     'un',
#     'bouc',
#     'émissaire',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'barely',
#     'paid',
#     'minimum',
#     'wage',
#     '.'],
#    'french_tokens': ['ils',
#     'sont',
#     'à',
#     'peine',
#     'payés',
#     'le',
#     'smic',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'giving',
#     'away',
#     'samples',
#     'free',
#     '.'],
#    'french_tokens': ['ils',
#     'distribuent',
#     'des',
#     'échantillons',
#     'gratuits',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'not',
#     'telling',
#     'us',
#     'the',
#     'truth',
#     '.'],
#    'french_tokens': ['ils',
#     'ne',
#     'nous',
#     'disent',
#     'pas',
#     'la',
#     'vérité',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'living',
#     'in',
#     'a',
#     'fantasy',
#     'world',
#     '.'],
#    'french_tokens': ['elles',
#     'vivent',
#     'dans',
#     'un',
#     'monde',
#     'de',
#     'fantaisie',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'two',
#     'very',
#     'different',
#     'things',
#     '.'],
#    'french_tokens': ['ce',
#     'sont',
#     'deux',
#     'choses',
#     'absolument',
#     'différentes',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'back',
#     'where',
#     'they',
#     'want',
#     'to',
#     'be',
#     '.'],
#    'french_tokens': ['ils',
#     'sont',
#     'de',
#     'retour',
#     'là',
#     'où',
#     'ils',
#     'veulent',
#     'être',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'back',
#     'where',
#     'they',
#     'want',
#     'to',
#     'be',
#     '.'],
#    'french_tokens': ['elles',
#     'sont',
#     'de',
#     'retour',
#     'là',
#     'où',
#     'elles',
#     'veulent',
#     'être',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'sunbathing',
#     'around',
#     'the',
#     'pool',
#     '.'],
#    'french_tokens': ['ils',
#     'bronzent',
#     'autour',
#     'de',
#     'la',
#     'piscine',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'sunbathing',
#     'around',
#     'the',
#     'pool',
#     '.'],
#    'french_tokens': ['elles',
#     'bronzent',
#     'autour',
#     'de',
#     'la',
#     'piscine',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'going',
#     'to',
#     'give',
#     'me',
#     'an',
#     'estimate',
#     '.'],
#    'french_tokens': ['ils',
#     'vont',
#     'me',
#     'donner',
#     'un',
#     'devis',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'having',
#     'a',
#     'break',
#     'at',
#     'the',
#     'moment',
#     '.'],
#    'french_tokens': ['pour',
#     'le',
#     'moment',
#     ',',
#     'ils',
#     'font',
#     'une',
#     'pause',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'really',
#     'good',
#     'at',
#     'making',
#     'clothes',
#     '.'],
#    'french_tokens': ['ils',
#     'sont',
#     'vraiment',
#     'bons',
#     'dans',
#     'la',
#     'confection',
#     'de',
#     'vêtements',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'both',
#     'in',
#     'love',
#     'with',
#     'the',
#     'same',
#     'guy',
#     '.'],
#    'french_tokens': ['elles',
#     'sont',
#     'toutes',
#     'les',
#     'deux',
#     'amoureuses',
#     'du',
#     'même',
#     'type',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'both',
#     'in',
#     'love',
#     'with',
#     'the',
#     'same',
#     'guy',
#     '.'],
#    'french_tokens': ['elles',
#     'sont',
#     'toutes',
#     'deux',
#     'amoureuses',
#     'du',
#     'même',
#     'type',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'here',
#     'until',
#     'the',
#     'end',
#     'of',
#     'the',
#     'week',
#     '.'],
#    'french_tokens': ['ils',
#     'sont',
#     'là',
#     'jusqu',
#     "'",
#     'à',
#     'la',
#     'fin',
#     'de',
#     'la',
#     'semaine',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'studying',
#     'french',
#     'and',
#     'web',
#     'design',
#     '.'],
#    'french_tokens': ['ils',
#     'étudient',
#     'le',
#     'français',
#     'et',
#     'le',
#     'webdesign',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'both',
#     'in',
#     'love',
#     'with',
#     'the',
#     'same',
#     'girl',
#     '.'],
#    'french_tokens': ['ils',
#     'sont',
#     'tous',
#     'les',
#     'deux',
#     'amoureux',
#     'de',
#     'la',
#     'même',
#     'fille',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'both',
#     'in',
#     'love',
#     'with',
#     'the',
#     'same',
#     'girl',
#     '.'],
#    'french_tokens': ['ils',
#     'sont',
#     'tous',
#     'deux',
#     'amoureux',
#     'de',
#     'la',
#     'même',
#     'fille',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'going',
#     'to',
#     'have',
#     'a',
#     'party',
#     'next',
#     'week',
#     '.'],
#    'french_tokens': ['ils',
#     'vont',
#     'faire',
#     'une',
#     'fête',
#     'la',
#     'semaine',
#     'prochaine',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'expressing',
#     'their',
#     'love',
#     'by',
#     'hugging',
#     '.'],
#    'french_tokens': ['ils',
#     'expriment',
#     'leur',
#     'amour',
#     'en',
#     "s'enlaçant",
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'taking',
#     'mary',
#     'to',
#     'the',
#     'emergency',
#     'room',
#     '.'],
#    'french_tokens': ['ils',
#     'emmènent',
#     'marie',
#     'à',
#     'la',
#     'salle',
#     'des',
#     'urgences',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'bringing',
#     'him',
#     'in',
#     'for',
#     'questioning',
#     'now',
#     '.'],
#    'french_tokens': ['ils',
#     'sont',
#     'actuellement',
#     'en',
#     'train',
#     'de',
#     "l'amener",
#     'pour',
#     'lui',
#     'poser',
#     'des',
#     'questions',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'having',
#     'a',
#     'going-out-of-business',
#     'sale',
#     '.'],
#    'french_tokens': ['ils',
#     'ont',
#     'une',
#     'liquidation',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'constructing',
#     'a',
#     'bridge',
#     'over',
#     'the',
#     'river',
#     '.'],
#    'french_tokens': ['ils',
#     'construisent',
#     'un',
#     'pont',
#     'au-dessus',
#     'de',
#     'la',
#     'rivière',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'eating',
#     'dinner',
#     'now',
#     'in',
#     'the',
#     'dining',
#     'room',
#     '.'],
#    'french_tokens': ['ils',
#     'déjeunent',
#     'maintenant',
#     'dans',
#     'la',
#     'salle-à-manger',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'eating',
#     'dinner',
#     'now',
#     'in',
#     'the',
#     'dining',
#     'room',
#     '.'],
#    'french_tokens': ['elles',
#     'déjeunent',
#     'maintenant',
#     'dans',
#     'la',
#     'salle-à-manger',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'eating',
#     'dinner',
#     'now',
#     'in',
#     'the',
#     'dining',
#     'room',
#     '.'],
#    'french_tokens': ['ils',
#     'dînent',
#     'maintenant',
#     'dans',
#     'la',
#     'salle-à-manger',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'eating',
#     'dinner',
#     'now',
#     'in',
#     'the',
#     'dining',
#     'room',
#     '.'],
#    'french_tokens': ['elles',
#     'dînent',
#     'maintenant',
#     'dans',
#     'la',
#     'salle-à-manger',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'just',
#     'like',
#     'rats',
#     'leaving',
#     'a',
#     'sinking',
#     'ship',
#     '.'],
#    'french_tokens': ['ils',
#     'sont',
#     'juste',
#     'comme',
#     'des',
#     'rats',
#     'quittant',
#     'un',
#     'navire',
#     'qui',
#     'sombre',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'not',
#     'going',
#     'to',
#     'be',
#     'able',
#     'to',
#     'find',
#     'the',
#     'hotel',
#     '.'],
#    'french_tokens': ['ils',
#     'ne',
#     'vont',
#     'pas',
#     'pouvoir',
#     'trouver',
#     "l'hôtel",
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'hoping',
#     'the',
#     'wheat',
#     'harvest',
#     'will',
#     'be',
#     'good',
#     'this',
#     'year',
#     '.'],
#    'french_tokens': ['ils',
#     'espèrent',
#     'que',
#     'la',
#     'récolte',
#     'de',
#     'blé',
#     'sera',
#     'bonne',
#     'cette',
#     'année',
#     '.']}, {'english_tokens': ['they',
#     "'re",
#     'experiencing',
#     'white',
#     'water',
#     'rafting',
#     'on',
#     'a',
#     'class',
#     'five',
#     'river',
#     '.'],
#    'french_tokens': ['ils',
#     'font',
#     "l'expérience",
#     'du',
#     'radeau',
#     'en',
#     'eau',
#     'vive',
#     ',',
#     'sur',
#     'une',
#     'rivière',
#     'de',
#     'classe',
#     'cinq',
#     '.']}]}

# %%
counts = {k: len(v) for k,v in data_subset.items()}
counts, sum(counts.values())
# Out:
# ({('i', 'am'): 805,
#   ('i', "'m"): 4760,
#   ('he', 'is'): 1069,
#   ('he', "'s"): 787,
#   ('she', 'is'): 504,
#   ('she', "'s"): 316,
#   ('you', 'are'): 449,
#   ('you', "'re"): 2474,
#   ('we', 'are'): 181,
#   ('we', "'re"): 1053,
#   ('they', 'are'): 194,
#   ('they', "'re"): 470},
#  13062)

# %%
np.random.seed(args.seed)

dataset_stage3 = []
for phrase, datum_list in sorted(data_subset.items()):
    np.random.shuffle(datum_list)
    n_train = int(len(datum_list) * args.perc_train)
    n_val = int(len(datum_list) * args.perc_val)

    for datum in datum_list[:n_train]:
        datum['split'] = 'train'
        
    for datum in datum_list[n_train:n_train+n_val]:
        datum['split'] = 'val'
        
    for datum in datum_list[n_train+n_val:]:
        datum['split'] = 'test'
    
    dataset_stage3.extend(datum_list)

# %%
# here we pop and assign into the dictionary, thus modifying in place
for datum in dataset_stage3:
    datum['source_language'] = " ".join(datum.pop('english_tokens'))
    datum['target_language'] = " ".join(datum.pop('french_tokens'))

# %%
nmt_df = pd.DataFrame(dataset_stage3)

# %%
nmt_df.head()
# Out:
#    split                    source_language  \
# 0  train     he 's the cutest boy in town .
# 1  train                he 's a nonsmoker .
# 2  train            he 's smarter than me .
# 3  train         he 's a lovely young man .
# 4  train  he 's three years older than me .
#
#                              target_language
# 0  c'est le garçon le plus mignon en ville .
# 1                        il est non-fumeur .
# 2          il est plus intelligent que moi .
# 3            c'est un adorable jeune homme .
# 4           il a trois ans de plus que moi .

# %%
nmt_df.to_csv(args.output_data_path)
