# %% [markdown]
# # Data Preparation for Learning Embeddings with Continuous Bag of Words (CBOW)

# %%
import os

from argparse import Namespace
import collections
import nltk.data
import numpy as np
import pandas as pd
import re
import string
from tqdm.notebook import tqdm

# %%
args = Namespace(
    raw_dataset_txt="data/books/frankenstein.txt",
    window_size=5,
    train_proportion=0.7,
    val_proportion=0.15,
    test_proportion=0.15,
    output_munged_csv="data/books/frankenstein_with_splits.csv",
    seed=1337
)

# %%
# Split the raw text book into sentences
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')  # sentence tokenizer
with open(args.raw_dataset_txt) as fp:
    book = fp.read()
sentences = tokenizer.tokenize(book)

# %%
print (len(sentences), "sentences")
print ("Sample:", sentences[0])
# Out:
# 3427 sentences
# Sample: Frankenstein,
#
# or the Modern Prometheus
#
#
# by
#
# Mary Wollstonecraft (Godwin) Shelley
#
#
# Letter 1
#
#
# St. Petersburgh, Dec. 11th, 17--
#
# TO Mrs. Saville, England
#
# You will rejoice to hear that no disaster has accompanied the
# commencement of an enterprise which you have regarded with such evil
# forebodings.

# %%
# Clean sentences
def preprocess_text(text):
    text = ' '.join(word.lower() for word in text.split(" "))
    text = re.sub(r"([.,!?])", r" \1 ", text)
    text = re.sub(r"[^a-zA-Z.,!?]+", r" ", text)
    return text

# %%
cleaned_sentences = [preprocess_text(sentence) for sentence in sentences]

# %%
cleaned_sentences[0]
# Out:
# 'frankenstein , or the modern prometheus by mary wollstonecraft godwin shelley letter st . petersburgh , dec . th , to mrs . saville , england you will rejoice to hear that no disaster has accompanied the commencement of an enterprise which you have regarded with such evil forebodings . '

# %% [markdown]
# ### Generate 11 ngrams from each sentence, and create \[context, target\] lists
# - nltk.ngarms (["<MASK\>", "<MASK\>", "<MASK\>", "<MASK\>", "<MASK\>", "frankenstein", ",", "or", "the", "modern", "prometheus", "by", ......, "evil", "forebodings", ".", "<MASK\>", "<MASK\>", "<MASK\>", "<MASK\>", "<MASK\>"', 11)
# - 1st: [ "<MASK\>", "<MASK\>", "<MASK\>", "<MASK\>", "<MASK\>", <b>"frankenstein"</b>, ",", "or", "the", "modern", "prometheus"]
# - 2nd: [ "<MASK\>", "<MASK\>", "<MASK\>", "<MASK\>", "frankenstein", <b>","</b>, "or", "the", "modern", "prometheus", "by"]
# - Output from 1st: [", or the modern prometheus", "frankenstein"]
# - Output from 2nd: ["frankenstein, or the modern prometheus by", ","]

# %%
# Global vars
MASK_TOKEN = "<MASK>"

# %%
# Create windows: use 11 ngrams
flatten = lambda outer_list: [item for inner_list in outer_list for item in inner_list]
windows = flatten([list(nltk.ngrams([MASK_TOKEN] * args.window_size + sentence.split(' ') + \
    [MASK_TOKEN] * args.window_size, args.window_size * 2 + 1)) \
    for sentence in tqdm(cleaned_sentences)])

# Create cbow data
data = []
for window in tqdm(windows):
    target_token = window[args.window_size]
    context = []
    for i, token in enumerate(window):
        if token == MASK_TOKEN or i == args.window_size:
            continue
        else:
            context.append(token)
    data.append([' '.join(token for token in context), target_token])
    
            
# Convert to dataframe
cbow_data = pd.DataFrame(data, columns=["context", "target"])
# Out:
#   0%|          | 0/3427 [00:00<?, ?it/s]
#   0%|          | 0/90698 [00:00<?, ?it/s]

# %%
windows
# Out:
# [('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'frankenstein',
#   ',',
#   'or',
#   'the',
#   'modern',
#   'prometheus'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'frankenstein',
#   ',',
#   'or',
#   'the',
#   'modern',
#   'prometheus',
#   'by'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'frankenstein',
#   ',',
#   'or',
#   'the',
#   'modern',
#   'prometheus',
#   'by',
#   'mary'),
#  ('<MASK>',
#   '<MASK>',
#   'frankenstein',
#   ',',
#   'or',
#   'the',
#   'modern',
#   'prometheus',
#   'by',
#   'mary',
#   'wollstonecraft'),
#  ('<MASK>',
#   'frankenstein',
#   ',',
#   'or',
#   'the',
#   'modern',
#   'prometheus',
#   'by',
#   'mary',
#   'wollstonecraft',
#   'godwin'),
#  ('frankenstein',
#   ',',
#   'or',
#   'the',
#   'modern',
#   'prometheus',
#   'by',
#   'mary',
#   'wollstonecraft',
#   'godwin',
#   'shelley'),
#  (',',
#   'or',
#   'the',
#   'modern',
#   'prometheus',
#   'by',
#   'mary',
#   'wollstonecraft',
#   'godwin',
#   'shelley',
#   'letter'),
#  ('or',
#   'the',
#   'modern',
#   'prometheus',
#   'by',
#   'mary',
#   'wollstonecraft',
#   'godwin',
#   'shelley',
#   'letter',
#   'st'),
#  ('the',
#   'modern',
#   'prometheus',
#   'by',
#   'mary',
#   'wollstonecraft',
#   'godwin',
#   'shelley',
#   'letter',
#   'st',
#   '.'),
#  ('modern',
#   'prometheus',
#   'by',
#   'mary',
#   'wollstonecraft',
#   'godwin',
#   'shelley',
#   'letter',
#   'st',
#   '.',
#   'petersburgh'),
#  ('prometheus',
#   'by',
#   'mary',
#   'wollstonecraft',
#   'godwin',
#   'shelley',
#   'letter',
#   'st',
#   '.',
#   'petersburgh',
#   ','),
#  ('by',
#   'mary',
#   'wollstonecraft',
#   'godwin',
#   'shelley',
#   'letter',
#   'st',
#   '.',
#   'petersburgh',
#   ',',
#   'dec'),
#  ('mary',
#   'wollstonecraft',
#   'godwin',
#   'shelley',
#   'letter',
#   'st',
#   '.',
#   'petersburgh',
#   ',',
#   'dec',
#   '.'),
#  ('wollstonecraft',
#   'godwin',
#   'shelley',
#   'letter',
#   'st',
#   '.',
#   'petersburgh',
#   ',',
#   'dec',
#   '.',
#   'th'),
#  ('godwin',
#   'shelley',
#   'letter',
#   'st',
#   '.',
#   'petersburgh',
#   ',',
#   'dec',
#   '.',
#   'th',
#   ','),
#  ('shelley',
#   'letter',
#   'st',
#   '.',
#   'petersburgh',
#   ',',
#   'dec',
#   '.',
#   'th',
#   ',',
#   'to'),
#  ('letter', 'st', '.', 'petersburgh', ',', 'dec', '.', 'th', ',', 'to', 'mrs'),
#  ('st', '.', 'petersburgh', ',', 'dec', '.', 'th', ',', 'to', 'mrs', '.'),
#  ('.', 'petersburgh', ',', 'dec', '.', 'th', ',', 'to', 'mrs', '.', 'saville'),
#  ('petersburgh', ',', 'dec', '.', 'th', ',', 'to', 'mrs', '.', 'saville', ','),
#  (',', 'dec', '.', 'th', ',', 'to', 'mrs', '.', 'saville', ',', 'england'),
#  ('dec', '.', 'th', ',', 'to', 'mrs', '.', 'saville', ',', 'england', 'you'),
#  ('.', 'th', ',', 'to', 'mrs', '.', 'saville', ',', 'england', 'you', 'will'),
#  ('th',
#   ',',
#   'to',
#   'mrs',
#   '.',
#   'saville',
#   ',',
#   'england',
#   'you',
#   'will',
#   'rejoice'),
#  (',',
#   'to',
#   'mrs',
#   '.',
#   'saville',
#   ',',
#   'england',
#   'you',
#   'will',
#   'rejoice',
#   'to'),
#  ('to',
#   'mrs',
#   '.',
#   'saville',
#   ',',
#   'england',
#   'you',
#   'will',
#   'rejoice',
#   'to',
#   'hear'),
#  ('mrs',
#   '.',
#   'saville',
#   ',',
#   'england',
#   'you',
#   'will',
#   'rejoice',
#   'to',
#   'hear',
#   'that'),
#  ('.',
#   'saville',
#   ',',
#   'england',
#   'you',
#   'will',
#   'rejoice',
#   'to',
#   'hear',
#   'that',
#   'no'),
#  ('saville',
#   ',',
#   'england',
#   'you',
#   'will',
#   'rejoice',
#   'to',
#   'hear',
#   'that',
#   'no',
#   'disaster'),
#  (',',
#   'england',
#   'you',
#   'will',
#   'rejoice',
#   'to',
#   'hear',
#   'that',
#   'no',
#   'disaster',
#   'has'),
#  ('england',
#   'you',
#   'will',
#   'rejoice',
#   'to',
#   'hear',
#   'that',
#   'no',
#   'disaster',
#   'has',
#   'accompanied'),
#  ('you',
#   'will',
#   'rejoice',
#   'to',
#   'hear',
#   'that',
#   'no',
#   'disaster',
#   'has',
#   'accompanied',
#   'the'),
#  ('will',
#   'rejoice',
#   'to',
#   'hear',
#   'that',
#   'no',
#   'disaster',
#   'has',
#   'accompanied',
#   'the',
#   'commencement'),
#  ('rejoice',
#   'to',
#   'hear',
#   'that',
#   'no',
#   'disaster',
#   'has',
#   'accompanied',
#   'the',
#   'commencement',
#   'of'),
#  ('to',
#   'hear',
#   'that',
#   'no',
#   'disaster',
#   'has',
#   'accompanied',
#   'the',
#   'commencement',
#   'of',
#   'an'),
#  ('hear',
#   'that',
#   'no',
#   'disaster',
#   'has',
#   'accompanied',
#   'the',
#   'commencement',
#   'of',
#   'an',
#   'enterprise'),
#  ('that',
#   'no',
#   'disaster',
#   'has',
#   'accompanied',
#   'the',
#   'commencement',
#   'of',
#   'an',
#   'enterprise',
#   'which'),
#  ('no',
#   'disaster',
#   'has',
#   'accompanied',
#   'the',
#   'commencement',
#   'of',
#   'an',
#   'enterprise',
#   'which',
#   'you'),
#  ('disaster',
#   'has',
#   'accompanied',
#   'the',
#   'commencement',
#   'of',
#   'an',
#   'enterprise',
#   'which',
#   'you',
#   'have'),
#  ('has',
#   'accompanied',
#   'the',
#   'commencement',
#   'of',
#   'an',
#   'enterprise',
#   'which',
#   'you',
#   'have',
#   'regarded'),
#  ('accompanied',
#   'the',
#   'commencement',
#   'of',
#   'an',
#   'enterprise',
#   'which',
#   'you',
#   'have',
#   'regarded',
#   'with'),
#  ('the',
#   'commencement',
#   'of',
#   'an',
#   'enterprise',
#   'which',
#   'you',
#   'have',
#   'regarded',
#   'with',
#   'such'),
#  ('commencement',
#   'of',
#   'an',
#   'enterprise',
#   'which',
#   'you',
#   'have',
#   'regarded',
#   'with',
#   'such',
#   'evil'),
#  ('of',
#   'an',
#   'enterprise',
#   'which',
#   'you',
#   'have',
#   'regarded',
#   'with',
#   'such',
#   'evil',
#   'forebodings'),
#  ('an',
#   'enterprise',
#   'which',
#   'you',
#   'have',
#   'regarded',
#   'with',
#   'such',
#   'evil',
#   'forebodings',
#   '.'),
#  ('enterprise',
#   'which',
#   'you',
#   'have',
#   'regarded',
#   'with',
#   'such',
#   'evil',
#   'forebodings',
#   '.',
#   ''),
#  ('which',
#   'you',
#   'have',
#   'regarded',
#   'with',
#   'such',
#   'evil',
#   'forebodings',
#   '.',
#   '',
#   '<MASK>'),
#  ('you',
#   'have',
#   'regarded',
#   'with',
#   'such',
#   'evil',
#   'forebodings',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>'),
#  ('have',
#   'regarded',
#   'with',
#   'such',
#   'evil',
#   'forebodings',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('regarded',
#   'with',
#   'such',
#   'evil',
#   'forebodings',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('with',
#   'such',
#   'evil',
#   'forebodings',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'i',
#   'arrived',
#   'here',
#   'yesterday',
#   ',',
#   'and'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'i',
#   'arrived',
#   'here',
#   'yesterday',
#   ',',
#   'and',
#   'my'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'i',
#   'arrived',
#   'here',
#   'yesterday',
#   ',',
#   'and',
#   'my',
#   'first'),
#  ('<MASK>',
#   '<MASK>',
#   'i',
#   'arrived',
#   'here',
#   'yesterday',
#   ',',
#   'and',
#   'my',
#   'first',
#   'task'),
#  ('<MASK>',
#   'i',
#   'arrived',
#   'here',
#   'yesterday',
#   ',',
#   'and',
#   'my',
#   'first',
#   'task',
#   'is'),
#  ('i',
#   'arrived',
#   'here',
#   'yesterday',
#   ',',
#   'and',
#   'my',
#   'first',
#   'task',
#   'is',
#   'to'),
#  ('arrived',
#   'here',
#   'yesterday',
#   ',',
#   'and',
#   'my',
#   'first',
#   'task',
#   'is',
#   'to',
#   'assure'),
#  ('here',
#   'yesterday',
#   ',',
#   'and',
#   'my',
#   'first',
#   'task',
#   'is',
#   'to',
#   'assure',
#   'my'),
#  ('yesterday',
#   ',',
#   'and',
#   'my',
#   'first',
#   'task',
#   'is',
#   'to',
#   'assure',
#   'my',
#   'dear'),
#  (',',
#   'and',
#   'my',
#   'first',
#   'task',
#   'is',
#   'to',
#   'assure',
#   'my',
#   'dear',
#   'sister'),
#  ('and',
#   'my',
#   'first',
#   'task',
#   'is',
#   'to',
#   'assure',
#   'my',
#   'dear',
#   'sister',
#   'of'),
#  ('my',
#   'first',
#   'task',
#   'is',
#   'to',
#   'assure',
#   'my',
#   'dear',
#   'sister',
#   'of',
#   'my'),
#  ('first',
#   'task',
#   'is',
#   'to',
#   'assure',
#   'my',
#   'dear',
#   'sister',
#   'of',
#   'my',
#   'welfare'),
#  ('task',
#   'is',
#   'to',
#   'assure',
#   'my',
#   'dear',
#   'sister',
#   'of',
#   'my',
#   'welfare',
#   'and'),
#  ('is',
#   'to',
#   'assure',
#   'my',
#   'dear',
#   'sister',
#   'of',
#   'my',
#   'welfare',
#   'and',
#   'increasing'),
#  ('to',
#   'assure',
#   'my',
#   'dear',
#   'sister',
#   'of',
#   'my',
#   'welfare',
#   'and',
#   'increasing',
#   'confidence'),
#  ('assure',
#   'my',
#   'dear',
#   'sister',
#   'of',
#   'my',
#   'welfare',
#   'and',
#   'increasing',
#   'confidence',
#   'in'),
#  ('my',
#   'dear',
#   'sister',
#   'of',
#   'my',
#   'welfare',
#   'and',
#   'increasing',
#   'confidence',
#   'in',
#   'the'),
#  ('dear',
#   'sister',
#   'of',
#   'my',
#   'welfare',
#   'and',
#   'increasing',
#   'confidence',
#   'in',
#   'the',
#   'success'),
#  ('sister',
#   'of',
#   'my',
#   'welfare',
#   'and',
#   'increasing',
#   'confidence',
#   'in',
#   'the',
#   'success',
#   'of'),
#  ('of',
#   'my',
#   'welfare',
#   'and',
#   'increasing',
#   'confidence',
#   'in',
#   'the',
#   'success',
#   'of',
#   'my'),
#  ('my',
#   'welfare',
#   'and',
#   'increasing',
#   'confidence',
#   'in',
#   'the',
#   'success',
#   'of',
#   'my',
#   'undertaking'),
#  ('welfare',
#   'and',
#   'increasing',
#   'confidence',
#   'in',
#   'the',
#   'success',
#   'of',
#   'my',
#   'undertaking',
#   '.'),
#  ('and',
#   'increasing',
#   'confidence',
#   'in',
#   'the',
#   'success',
#   'of',
#   'my',
#   'undertaking',
#   '.',
#   ''),
#  ('increasing',
#   'confidence',
#   'in',
#   'the',
#   'success',
#   'of',
#   'my',
#   'undertaking',
#   '.',
#   '',
#   '<MASK>'),
#  ('confidence',
#   'in',
#   'the',
#   'success',
#   'of',
#   'my',
#   'undertaking',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>'),
#  ('in',
#   'the',
#   'success',
#   'of',
#   'my',
#   'undertaking',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('the',
#   'success',
#   'of',
#   'my',
#   'undertaking',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('success',
#   'of',
#   'my',
#   'undertaking',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'i',
#   'am',
#   'already',
#   'far',
#   'north',
#   'of'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'i',
#   'am',
#   'already',
#   'far',
#   'north',
#   'of',
#   'london'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'i',
#   'am',
#   'already',
#   'far',
#   'north',
#   'of',
#   'london',
#   ','),
#  ('<MASK>',
#   '<MASK>',
#   'i',
#   'am',
#   'already',
#   'far',
#   'north',
#   'of',
#   'london',
#   ',',
#   'and'),
#  ('<MASK>',
#   'i',
#   'am',
#   'already',
#   'far',
#   'north',
#   'of',
#   'london',
#   ',',
#   'and',
#   'as'),
#  ('i', 'am', 'already', 'far', 'north', 'of', 'london', ',', 'and', 'as', 'i'),
#  ('am',
#   'already',
#   'far',
#   'north',
#   'of',
#   'london',
#   ',',
#   'and',
#   'as',
#   'i',
#   'walk'),
#  ('already',
#   'far',
#   'north',
#   'of',
#   'london',
#   ',',
#   'and',
#   'as',
#   'i',
#   'walk',
#   'in'),
#  ('far', 'north', 'of', 'london', ',', 'and', 'as', 'i', 'walk', 'in', 'the'),
#  ('north',
#   'of',
#   'london',
#   ',',
#   'and',
#   'as',
#   'i',
#   'walk',
#   'in',
#   'the',
#   'streets'),
#  ('of', 'london', ',', 'and', 'as', 'i', 'walk', 'in', 'the', 'streets', 'of'),
#  ('london',
#   ',',
#   'and',
#   'as',
#   'i',
#   'walk',
#   'in',
#   'the',
#   'streets',
#   'of',
#   'petersburgh'),
#  (',',
#   'and',
#   'as',
#   'i',
#   'walk',
#   'in',
#   'the',
#   'streets',
#   'of',
#   'petersburgh',
#   ','),
#  ('and',
#   'as',
#   'i',
#   'walk',
#   'in',
#   'the',
#   'streets',
#   'of',
#   'petersburgh',
#   ',',
#   'i'),
#  ('as',
#   'i',
#   'walk',
#   'in',
#   'the',
#   'streets',
#   'of',
#   'petersburgh',
#   ',',
#   'i',
#   'feel'),
#  ('i',
#   'walk',
#   'in',
#   'the',
#   'streets',
#   'of',
#   'petersburgh',
#   ',',
#   'i',
#   'feel',
#   'a'),
#  ('walk',
#   'in',
#   'the',
#   'streets',
#   'of',
#   'petersburgh',
#   ',',
#   'i',
#   'feel',
#   'a',
#   'cold'),
#  ('in',
#   'the',
#   'streets',
#   'of',
#   'petersburgh',
#   ',',
#   'i',
#   'feel',
#   'a',
#   'cold',
#   'northern'),
#  ('the',
#   'streets',
#   'of',
#   'petersburgh',
#   ',',
#   'i',
#   'feel',
#   'a',
#   'cold',
#   'northern',
#   'breeze'),
#  ('streets',
#   'of',
#   'petersburgh',
#   ',',
#   'i',
#   'feel',
#   'a',
#   'cold',
#   'northern',
#   'breeze',
#   'play'),
#  ('of',
#   'petersburgh',
#   ',',
#   'i',
#   'feel',
#   'a',
#   'cold',
#   'northern',
#   'breeze',
#   'play',
#   'upon'),
#  ('petersburgh',
#   ',',
#   'i',
#   'feel',
#   'a',
#   'cold',
#   'northern',
#   'breeze',
#   'play',
#   'upon',
#   'my'),
#  (',',
#   'i',
#   'feel',
#   'a',
#   'cold',
#   'northern',
#   'breeze',
#   'play',
#   'upon',
#   'my',
#   'cheeks'),
#  ('i',
#   'feel',
#   'a',
#   'cold',
#   'northern',
#   'breeze',
#   'play',
#   'upon',
#   'my',
#   'cheeks',
#   ','),
#  ('feel',
#   'a',
#   'cold',
#   'northern',
#   'breeze',
#   'play',
#   'upon',
#   'my',
#   'cheeks',
#   ',',
#   'which'),
#  ('a',
#   'cold',
#   'northern',
#   'breeze',
#   'play',
#   'upon',
#   'my',
#   'cheeks',
#   ',',
#   'which',
#   'braces'),
#  ('cold',
#   'northern',
#   'breeze',
#   'play',
#   'upon',
#   'my',
#   'cheeks',
#   ',',
#   'which',
#   'braces',
#   'my'),
#  ('northern',
#   'breeze',
#   'play',
#   'upon',
#   'my',
#   'cheeks',
#   ',',
#   'which',
#   'braces',
#   'my',
#   'nerves'),
#  ('breeze',
#   'play',
#   'upon',
#   'my',
#   'cheeks',
#   ',',
#   'which',
#   'braces',
#   'my',
#   'nerves',
#   'and'),
#  ('play',
#   'upon',
#   'my',
#   'cheeks',
#   ',',
#   'which',
#   'braces',
#   'my',
#   'nerves',
#   'and',
#   'fills'),
#  ('upon',
#   'my',
#   'cheeks',
#   ',',
#   'which',
#   'braces',
#   'my',
#   'nerves',
#   'and',
#   'fills',
#   'me'),
#  ('my',
#   'cheeks',
#   ',',
#   'which',
#   'braces',
#   'my',
#   'nerves',
#   'and',
#   'fills',
#   'me',
#   'with'),
#  ('cheeks',
#   ',',
#   'which',
#   'braces',
#   'my',
#   'nerves',
#   'and',
#   'fills',
#   'me',
#   'with',
#   'delight'),
#  (',',
#   'which',
#   'braces',
#   'my',
#   'nerves',
#   'and',
#   'fills',
#   'me',
#   'with',
#   'delight',
#   '.'),
#  ('which',
#   'braces',
#   'my',
#   'nerves',
#   'and',
#   'fills',
#   'me',
#   'with',
#   'delight',
#   '.',
#   ''),
#  ('braces',
#   'my',
#   'nerves',
#   'and',
#   'fills',
#   'me',
#   'with',
#   'delight',
#   '.',
#   '',
#   '<MASK>'),
#  ('my',
#   'nerves',
#   'and',
#   'fills',
#   'me',
#   'with',
#   'delight',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>'),
#  ('nerves',
#   'and',
#   'fills',
#   'me',
#   'with',
#   'delight',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('and',
#   'fills',
#   'me',
#   'with',
#   'delight',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('fills',
#   'me',
#   'with',
#   'delight',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'do',
#   'you',
#   'understand',
#   'this',
#   'feeling',
#   '?'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'do',
#   'you',
#   'understand',
#   'this',
#   'feeling',
#   '?',
#   ''),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'do',
#   'you',
#   'understand',
#   'this',
#   'feeling',
#   '?',
#   '',
#   '<MASK>'),
#  ('<MASK>',
#   '<MASK>',
#   'do',
#   'you',
#   'understand',
#   'this',
#   'feeling',
#   '?',
#   '',
#   '<MASK>',
#   '<MASK>'),
#  ('<MASK>',
#   'do',
#   'you',
#   'understand',
#   'this',
#   'feeling',
#   '?',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('do',
#   'you',
#   'understand',
#   'this',
#   'feeling',
#   '?',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('you',
#   'understand',
#   'this',
#   'feeling',
#   '?',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'this',
#   'breeze',
#   ',',
#   'which',
#   'has',
#   'travelled'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'this',
#   'breeze',
#   ',',
#   'which',
#   'has',
#   'travelled',
#   'from'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'this',
#   'breeze',
#   ',',
#   'which',
#   'has',
#   'travelled',
#   'from',
#   'the'),
#  ('<MASK>',
#   '<MASK>',
#   'this',
#   'breeze',
#   ',',
#   'which',
#   'has',
#   'travelled',
#   'from',
#   'the',
#   'regions'),
#  ('<MASK>',
#   'this',
#   'breeze',
#   ',',
#   'which',
#   'has',
#   'travelled',
#   'from',
#   'the',
#   'regions',
#   'towards'),
#  ('this',
#   'breeze',
#   ',',
#   'which',
#   'has',
#   'travelled',
#   'from',
#   'the',
#   'regions',
#   'towards',
#   'which'),
#  ('breeze',
#   ',',
#   'which',
#   'has',
#   'travelled',
#   'from',
#   'the',
#   'regions',
#   'towards',
#   'which',
#   'i'),
#  (',',
#   'which',
#   'has',
#   'travelled',
#   'from',
#   'the',
#   'regions',
#   'towards',
#   'which',
#   'i',
#   'am'),
#  ('which',
#   'has',
#   'travelled',
#   'from',
#   'the',
#   'regions',
#   'towards',
#   'which',
#   'i',
#   'am',
#   'advancing'),
#  ('has',
#   'travelled',
#   'from',
#   'the',
#   'regions',
#   'towards',
#   'which',
#   'i',
#   'am',
#   'advancing',
#   ','),
#  ('travelled',
#   'from',
#   'the',
#   'regions',
#   'towards',
#   'which',
#   'i',
#   'am',
#   'advancing',
#   ',',
#   'gives'),
#  ('from',
#   'the',
#   'regions',
#   'towards',
#   'which',
#   'i',
#   'am',
#   'advancing',
#   ',',
#   'gives',
#   'me'),
#  ('the',
#   'regions',
#   'towards',
#   'which',
#   'i',
#   'am',
#   'advancing',
#   ',',
#   'gives',
#   'me',
#   'a'),
#  ('regions',
#   'towards',
#   'which',
#   'i',
#   'am',
#   'advancing',
#   ',',
#   'gives',
#   'me',
#   'a',
#   'foretaste'),
#  ('towards',
#   'which',
#   'i',
#   'am',
#   'advancing',
#   ',',
#   'gives',
#   'me',
#   'a',
#   'foretaste',
#   'of'),
#  ('which',
#   'i',
#   'am',
#   'advancing',
#   ',',
#   'gives',
#   'me',
#   'a',
#   'foretaste',
#   'of',
#   'those'),
#  ('i',
#   'am',
#   'advancing',
#   ',',
#   'gives',
#   'me',
#   'a',
#   'foretaste',
#   'of',
#   'those',
#   'icy'),
#  ('am',
#   'advancing',
#   ',',
#   'gives',
#   'me',
#   'a',
#   'foretaste',
#   'of',
#   'those',
#   'icy',
#   'climes'),
#  ('advancing',
#   ',',
#   'gives',
#   'me',
#   'a',
#   'foretaste',
#   'of',
#   'those',
#   'icy',
#   'climes',
#   '.'),
#  (',',
#   'gives',
#   'me',
#   'a',
#   'foretaste',
#   'of',
#   'those',
#   'icy',
#   'climes',
#   '.',
#   ''),
#  ('gives',
#   'me',
#   'a',
#   'foretaste',
#   'of',
#   'those',
#   'icy',
#   'climes',
#   '.',
#   '',
#   '<MASK>'),
#  ('me',
#   'a',
#   'foretaste',
#   'of',
#   'those',
#   'icy',
#   'climes',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>'),
#  ('a',
#   'foretaste',
#   'of',
#   'those',
#   'icy',
#   'climes',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('foretaste',
#   'of',
#   'those',
#   'icy',
#   'climes',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('of',
#   'those',
#   'icy',
#   'climes',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'inspirited',
#   'by',
#   'this',
#   'wind',
#   'of',
#   'promise'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'inspirited',
#   'by',
#   'this',
#   'wind',
#   'of',
#   'promise',
#   ','),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'inspirited',
#   'by',
#   'this',
#   'wind',
#   'of',
#   'promise',
#   ',',
#   'my'),
#  ('<MASK>',
#   '<MASK>',
#   'inspirited',
#   'by',
#   'this',
#   'wind',
#   'of',
#   'promise',
#   ',',
#   'my',
#   'daydreams'),
#  ('<MASK>',
#   'inspirited',
#   'by',
#   'this',
#   'wind',
#   'of',
#   'promise',
#   ',',
#   'my',
#   'daydreams',
#   'become'),
#  ('inspirited',
#   'by',
#   'this',
#   'wind',
#   'of',
#   'promise',
#   ',',
#   'my',
#   'daydreams',
#   'become',
#   'more'),
#  ('by',
#   'this',
#   'wind',
#   'of',
#   'promise',
#   ',',
#   'my',
#   'daydreams',
#   'become',
#   'more',
#   'fervent'),
#  ('this',
#   'wind',
#   'of',
#   'promise',
#   ',',
#   'my',
#   'daydreams',
#   'become',
#   'more',
#   'fervent',
#   'and'),
#  ('wind',
#   'of',
#   'promise',
#   ',',
#   'my',
#   'daydreams',
#   'become',
#   'more',
#   'fervent',
#   'and',
#   'vivid'),
#  ('of',
#   'promise',
#   ',',
#   'my',
#   'daydreams',
#   'become',
#   'more',
#   'fervent',
#   'and',
#   'vivid',
#   '.'),
#  ('promise',
#   ',',
#   'my',
#   'daydreams',
#   'become',
#   'more',
#   'fervent',
#   'and',
#   'vivid',
#   '.',
#   ''),
#  (',',
#   'my',
#   'daydreams',
#   'become',
#   'more',
#   'fervent',
#   'and',
#   'vivid',
#   '.',
#   '',
#   '<MASK>'),
#  ('my',
#   'daydreams',
#   'become',
#   'more',
#   'fervent',
#   'and',
#   'vivid',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>'),
#  ('daydreams',
#   'become',
#   'more',
#   'fervent',
#   'and',
#   'vivid',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('become',
#   'more',
#   'fervent',
#   'and',
#   'vivid',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('more',
#   'fervent',
#   'and',
#   'vivid',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'i',
#   'try',
#   'in',
#   'vain',
#   'to',
#   'be'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'i',
#   'try',
#   'in',
#   'vain',
#   'to',
#   'be',
#   'persuaded'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'i',
#   'try',
#   'in',
#   'vain',
#   'to',
#   'be',
#   'persuaded',
#   'that'),
#  ('<MASK>',
#   '<MASK>',
#   'i',
#   'try',
#   'in',
#   'vain',
#   'to',
#   'be',
#   'persuaded',
#   'that',
#   'the'),
#  ('<MASK>',
#   'i',
#   'try',
#   'in',
#   'vain',
#   'to',
#   'be',
#   'persuaded',
#   'that',
#   'the',
#   'pole'),
#  ('i',
#   'try',
#   'in',
#   'vain',
#   'to',
#   'be',
#   'persuaded',
#   'that',
#   'the',
#   'pole',
#   'is'),
#  ('try',
#   'in',
#   'vain',
#   'to',
#   'be',
#   'persuaded',
#   'that',
#   'the',
#   'pole',
#   'is',
#   'the'),
#  ('in',
#   'vain',
#   'to',
#   'be',
#   'persuaded',
#   'that',
#   'the',
#   'pole',
#   'is',
#   'the',
#   'seat'),
#  ('vain',
#   'to',
#   'be',
#   'persuaded',
#   'that',
#   'the',
#   'pole',
#   'is',
#   'the',
#   'seat',
#   'of'),
#  ('to',
#   'be',
#   'persuaded',
#   'that',
#   'the',
#   'pole',
#   'is',
#   'the',
#   'seat',
#   'of',
#   'frost'),
#  ('be',
#   'persuaded',
#   'that',
#   'the',
#   'pole',
#   'is',
#   'the',
#   'seat',
#   'of',
#   'frost',
#   'and'),
#  ('persuaded',
#   'that',
#   'the',
#   'pole',
#   'is',
#   'the',
#   'seat',
#   'of',
#   'frost',
#   'and',
#   'desolation'),
#  ('that',
#   'the',
#   'pole',
#   'is',
#   'the',
#   'seat',
#   'of',
#   'frost',
#   'and',
#   'desolation',
#   'it'),
#  ('the',
#   'pole',
#   'is',
#   'the',
#   'seat',
#   'of',
#   'frost',
#   'and',
#   'desolation',
#   'it',
#   'ever'),
#  ('pole',
#   'is',
#   'the',
#   'seat',
#   'of',
#   'frost',
#   'and',
#   'desolation',
#   'it',
#   'ever',
#   'presents'),
#  ('is',
#   'the',
#   'seat',
#   'of',
#   'frost',
#   'and',
#   'desolation',
#   'it',
#   'ever',
#   'presents',
#   'itself'),
#  ('the',
#   'seat',
#   'of',
#   'frost',
#   'and',
#   'desolation',
#   'it',
#   'ever',
#   'presents',
#   'itself',
#   'to'),
#  ('seat',
#   'of',
#   'frost',
#   'and',
#   'desolation',
#   'it',
#   'ever',
#   'presents',
#   'itself',
#   'to',
#   'my'),
#  ('of',
#   'frost',
#   'and',
#   'desolation',
#   'it',
#   'ever',
#   'presents',
#   'itself',
#   'to',
#   'my',
#   'imagination'),
#  ('frost',
#   'and',
#   'desolation',
#   'it',
#   'ever',
#   'presents',
#   'itself',
#   'to',
#   'my',
#   'imagination',
#   'as'),
#  ('and',
#   'desolation',
#   'it',
#   'ever',
#   'presents',
#   'itself',
#   'to',
#   'my',
#   'imagination',
#   'as',
#   'the'),
#  ('desolation',
#   'it',
#   'ever',
#   'presents',
#   'itself',
#   'to',
#   'my',
#   'imagination',
#   'as',
#   'the',
#   'region'),
#  ('it',
#   'ever',
#   'presents',
#   'itself',
#   'to',
#   'my',
#   'imagination',
#   'as',
#   'the',
#   'region',
#   'of'),
#  ('ever',
#   'presents',
#   'itself',
#   'to',
#   'my',
#   'imagination',
#   'as',
#   'the',
#   'region',
#   'of',
#   'beauty'),
#  ('presents',
#   'itself',
#   'to',
#   'my',
#   'imagination',
#   'as',
#   'the',
#   'region',
#   'of',
#   'beauty',
#   'and'),
#  ('itself',
#   'to',
#   'my',
#   'imagination',
#   'as',
#   'the',
#   'region',
#   'of',
#   'beauty',
#   'and',
#   'delight'),
#  ('to',
#   'my',
#   'imagination',
#   'as',
#   'the',
#   'region',
#   'of',
#   'beauty',
#   'and',
#   'delight',
#   '.'),
#  ('my',
#   'imagination',
#   'as',
#   'the',
#   'region',
#   'of',
#   'beauty',
#   'and',
#   'delight',
#   '.',
#   ''),
#  ('imagination',
#   'as',
#   'the',
#   'region',
#   'of',
#   'beauty',
#   'and',
#   'delight',
#   '.',
#   '',
#   '<MASK>'),
#  ('as',
#   'the',
#   'region',
#   'of',
#   'beauty',
#   'and',
#   'delight',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>'),
#  ('the',
#   'region',
#   'of',
#   'beauty',
#   'and',
#   'delight',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('region',
#   'of',
#   'beauty',
#   'and',
#   'delight',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('of',
#   'beauty',
#   'and',
#   'delight',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'there',
#   ',',
#   'margaret',
#   ',',
#   'the',
#   'sun'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'there',
#   ',',
#   'margaret',
#   ',',
#   'the',
#   'sun',
#   'is'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'there',
#   ',',
#   'margaret',
#   ',',
#   'the',
#   'sun',
#   'is',
#   'forever'),
#  ('<MASK>',
#   '<MASK>',
#   'there',
#   ',',
#   'margaret',
#   ',',
#   'the',
#   'sun',
#   'is',
#   'forever',
#   'visible'),
#  ('<MASK>',
#   'there',
#   ',',
#   'margaret',
#   ',',
#   'the',
#   'sun',
#   'is',
#   'forever',
#   'visible',
#   ','),
#  ('there',
#   ',',
#   'margaret',
#   ',',
#   'the',
#   'sun',
#   'is',
#   'forever',
#   'visible',
#   ',',
#   'its'),
#  (',',
#   'margaret',
#   ',',
#   'the',
#   'sun',
#   'is',
#   'forever',
#   'visible',
#   ',',
#   'its',
#   'broad'),
#  ('margaret',
#   ',',
#   'the',
#   'sun',
#   'is',
#   'forever',
#   'visible',
#   ',',
#   'its',
#   'broad',
#   'disk'),
#  (',',
#   'the',
#   'sun',
#   'is',
#   'forever',
#   'visible',
#   ',',
#   'its',
#   'broad',
#   'disk',
#   'just'),
#  ('the',
#   'sun',
#   'is',
#   'forever',
#   'visible',
#   ',',
#   'its',
#   'broad',
#   'disk',
#   'just',
#   'skirting'),
#  ('sun',
#   'is',
#   'forever',
#   'visible',
#   ',',
#   'its',
#   'broad',
#   'disk',
#   'just',
#   'skirting',
#   'the'),
#  ('is',
#   'forever',
#   'visible',
#   ',',
#   'its',
#   'broad',
#   'disk',
#   'just',
#   'skirting',
#   'the',
#   'horizon'),
#  ('forever',
#   'visible',
#   ',',
#   'its',
#   'broad',
#   'disk',
#   'just',
#   'skirting',
#   'the',
#   'horizon',
#   'and'),
#  ('visible',
#   ',',
#   'its',
#   'broad',
#   'disk',
#   'just',
#   'skirting',
#   'the',
#   'horizon',
#   'and',
#   'diffusing'),
#  (',',
#   'its',
#   'broad',
#   'disk',
#   'just',
#   'skirting',
#   'the',
#   'horizon',
#   'and',
#   'diffusing',
#   'a'),
#  ('its',
#   'broad',
#   'disk',
#   'just',
#   'skirting',
#   'the',
#   'horizon',
#   'and',
#   'diffusing',
#   'a',
#   'perpetual'),
#  ('broad',
#   'disk',
#   'just',
#   'skirting',
#   'the',
#   'horizon',
#   'and',
#   'diffusing',
#   'a',
#   'perpetual',
#   'splendour'),
#  ('disk',
#   'just',
#   'skirting',
#   'the',
#   'horizon',
#   'and',
#   'diffusing',
#   'a',
#   'perpetual',
#   'splendour',
#   '.'),
#  ('just',
#   'skirting',
#   'the',
#   'horizon',
#   'and',
#   'diffusing',
#   'a',
#   'perpetual',
#   'splendour',
#   '.',
#   ''),
#  ('skirting',
#   'the',
#   'horizon',
#   'and',
#   'diffusing',
#   'a',
#   'perpetual',
#   'splendour',
#   '.',
#   '',
#   '<MASK>'),
#  ('the',
#   'horizon',
#   'and',
#   'diffusing',
#   'a',
#   'perpetual',
#   'splendour',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>'),
#  ('horizon',
#   'and',
#   'diffusing',
#   'a',
#   'perpetual',
#   'splendour',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('and',
#   'diffusing',
#   'a',
#   'perpetual',
#   'splendour',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('diffusing',
#   'a',
#   'perpetual',
#   'splendour',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'there',
#   'for',
#   'with',
#   'your',
#   'leave',
#   ','),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'there',
#   'for',
#   'with',
#   'your',
#   'leave',
#   ',',
#   'my'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'there',
#   'for',
#   'with',
#   'your',
#   'leave',
#   ',',
#   'my',
#   'sister'),
#  ('<MASK>',
#   '<MASK>',
#   'there',
#   'for',
#   'with',
#   'your',
#   'leave',
#   ',',
#   'my',
#   'sister',
#   ','),
#  ('<MASK>',
#   'there',
#   'for',
#   'with',
#   'your',
#   'leave',
#   ',',
#   'my',
#   'sister',
#   ',',
#   'i'),
#  ('there',
#   'for',
#   'with',
#   'your',
#   'leave',
#   ',',
#   'my',
#   'sister',
#   ',',
#   'i',
#   'will'),
#  ('for',
#   'with',
#   'your',
#   'leave',
#   ',',
#   'my',
#   'sister',
#   ',',
#   'i',
#   'will',
#   'put'),
#  ('with',
#   'your',
#   'leave',
#   ',',
#   'my',
#   'sister',
#   ',',
#   'i',
#   'will',
#   'put',
#   'some'),
#  ('your',
#   'leave',
#   ',',
#   'my',
#   'sister',
#   ',',
#   'i',
#   'will',
#   'put',
#   'some',
#   'trust'),
#  ('leave',
#   ',',
#   'my',
#   'sister',
#   ',',
#   'i',
#   'will',
#   'put',
#   'some',
#   'trust',
#   'in'),
#  (',',
#   'my',
#   'sister',
#   ',',
#   'i',
#   'will',
#   'put',
#   'some',
#   'trust',
#   'in',
#   'preceding'),
#  ('my',
#   'sister',
#   ',',
#   'i',
#   'will',
#   'put',
#   'some',
#   'trust',
#   'in',
#   'preceding',
#   'navigators'),
#  ('sister',
#   ',',
#   'i',
#   'will',
#   'put',
#   'some',
#   'trust',
#   'in',
#   'preceding',
#   'navigators',
#   'there'),
#  (',',
#   'i',
#   'will',
#   'put',
#   'some',
#   'trust',
#   'in',
#   'preceding',
#   'navigators',
#   'there',
#   'snow'),
#  ('i',
#   'will',
#   'put',
#   'some',
#   'trust',
#   'in',
#   'preceding',
#   'navigators',
#   'there',
#   'snow',
#   'and'),
#  ('will',
#   'put',
#   'some',
#   'trust',
#   'in',
#   'preceding',
#   'navigators',
#   'there',
#   'snow',
#   'and',
#   'frost'),
#  ('put',
#   'some',
#   'trust',
#   'in',
#   'preceding',
#   'navigators',
#   'there',
#   'snow',
#   'and',
#   'frost',
#   'are'),
#  ('some',
#   'trust',
#   'in',
#   'preceding',
#   'navigators',
#   'there',
#   'snow',
#   'and',
#   'frost',
#   'are',
#   'banished'),
#  ('trust',
#   'in',
#   'preceding',
#   'navigators',
#   'there',
#   'snow',
#   'and',
#   'frost',
#   'are',
#   'banished',
#   'and'),
#  ('in',
#   'preceding',
#   'navigators',
#   'there',
#   'snow',
#   'and',
#   'frost',
#   'are',
#   'banished',
#   'and',
#   ','),
#  ('preceding',
#   'navigators',
#   'there',
#   'snow',
#   'and',
#   'frost',
#   'are',
#   'banished',
#   'and',
#   ',',
#   'sailing'),
#  ('navigators',
#   'there',
#   'snow',
#   'and',
#   'frost',
#   'are',
#   'banished',
#   'and',
#   ',',
#   'sailing',
#   'over'),
#  ('there',
#   'snow',
#   'and',
#   'frost',
#   'are',
#   'banished',
#   'and',
#   ',',
#   'sailing',
#   'over',
#   'a'),
#  ('snow',
#   'and',
#   'frost',
#   'are',
#   'banished',
#   'and',
#   ',',
#   'sailing',
#   'over',
#   'a',
#   'calm'),
#  ('and',
#   'frost',
#   'are',
#   'banished',
#   'and',
#   ',',
#   'sailing',
#   'over',
#   'a',
#   'calm',
#   'sea'),
#  ('frost',
#   'are',
#   'banished',
#   'and',
#   ',',
#   'sailing',
#   'over',
#   'a',
#   'calm',
#   'sea',
#   ','),
#  ('are',
#   'banished',
#   'and',
#   ',',
#   'sailing',
#   'over',
#   'a',
#   'calm',
#   'sea',
#   ',',
#   'we'),
#  ('banished',
#   'and',
#   ',',
#   'sailing',
#   'over',
#   'a',
#   'calm',
#   'sea',
#   ',',
#   'we',
#   'may'),
#  ('and', ',', 'sailing', 'over', 'a', 'calm', 'sea', ',', 'we', 'may', 'be'),
#  (',',
#   'sailing',
#   'over',
#   'a',
#   'calm',
#   'sea',
#   ',',
#   'we',
#   'may',
#   'be',
#   'wafted'),
#  ('sailing',
#   'over',
#   'a',
#   'calm',
#   'sea',
#   ',',
#   'we',
#   'may',
#   'be',
#   'wafted',
#   'to'),
#  ('over', 'a', 'calm', 'sea', ',', 'we', 'may', 'be', 'wafted', 'to', 'a'),
#  ('a', 'calm', 'sea', ',', 'we', 'may', 'be', 'wafted', 'to', 'a', 'land'),
#  ('calm',
#   'sea',
#   ',',
#   'we',
#   'may',
#   'be',
#   'wafted',
#   'to',
#   'a',
#   'land',
#   'surpassing'),
#  ('sea',
#   ',',
#   'we',
#   'may',
#   'be',
#   'wafted',
#   'to',
#   'a',
#   'land',
#   'surpassing',
#   'in'),
#  (',',
#   'we',
#   'may',
#   'be',
#   'wafted',
#   'to',
#   'a',
#   'land',
#   'surpassing',
#   'in',
#   'wonders'),
#  ('we',
#   'may',
#   'be',
#   'wafted',
#   'to',
#   'a',
#   'land',
#   'surpassing',
#   'in',
#   'wonders',
#   'and'),
#  ('may',
#   'be',
#   'wafted',
#   'to',
#   'a',
#   'land',
#   'surpassing',
#   'in',
#   'wonders',
#   'and',
#   'in'),
#  ('be',
#   'wafted',
#   'to',
#   'a',
#   'land',
#   'surpassing',
#   'in',
#   'wonders',
#   'and',
#   'in',
#   'beauty'),
#  ('wafted',
#   'to',
#   'a',
#   'land',
#   'surpassing',
#   'in',
#   'wonders',
#   'and',
#   'in',
#   'beauty',
#   'every'),
#  ('to',
#   'a',
#   'land',
#   'surpassing',
#   'in',
#   'wonders',
#   'and',
#   'in',
#   'beauty',
#   'every',
#   'region'),
#  ('a',
#   'land',
#   'surpassing',
#   'in',
#   'wonders',
#   'and',
#   'in',
#   'beauty',
#   'every',
#   'region',
#   'hitherto'),
#  ('land',
#   'surpassing',
#   'in',
#   'wonders',
#   'and',
#   'in',
#   'beauty',
#   'every',
#   'region',
#   'hitherto',
#   'discovered'),
#  ('surpassing',
#   'in',
#   'wonders',
#   'and',
#   'in',
#   'beauty',
#   'every',
#   'region',
#   'hitherto',
#   'discovered',
#   'on'),
#  ('in',
#   'wonders',
#   'and',
#   'in',
#   'beauty',
#   'every',
#   'region',
#   'hitherto',
#   'discovered',
#   'on',
#   'the'),
#  ('wonders',
#   'and',
#   'in',
#   'beauty',
#   'every',
#   'region',
#   'hitherto',
#   'discovered',
#   'on',
#   'the',
#   'habitable'),
#  ('and',
#   'in',
#   'beauty',
#   'every',
#   'region',
#   'hitherto',
#   'discovered',
#   'on',
#   'the',
#   'habitable',
#   'globe'),
#  ('in',
#   'beauty',
#   'every',
#   'region',
#   'hitherto',
#   'discovered',
#   'on',
#   'the',
#   'habitable',
#   'globe',
#   '.'),
#  ('beauty',
#   'every',
#   'region',
#   'hitherto',
#   'discovered',
#   'on',
#   'the',
#   'habitable',
#   'globe',
#   '.',
#   ''),
#  ('every',
#   'region',
#   'hitherto',
#   'discovered',
#   'on',
#   'the',
#   'habitable',
#   'globe',
#   '.',
#   '',
#   '<MASK>'),
#  ('region',
#   'hitherto',
#   'discovered',
#   'on',
#   'the',
#   'habitable',
#   'globe',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>'),
#  ('hitherto',
#   'discovered',
#   'on',
#   'the',
#   'habitable',
#   'globe',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('discovered',
#   'on',
#   'the',
#   'habitable',
#   'globe',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('on',
#   'the',
#   'habitable',
#   'globe',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'its',
#   'productions',
#   'and',
#   'features',
#   'may',
#   'be'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'its',
#   'productions',
#   'and',
#   'features',
#   'may',
#   'be',
#   'without'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'its',
#   'productions',
#   'and',
#   'features',
#   'may',
#   'be',
#   'without',
#   'example'),
#  ('<MASK>',
#   '<MASK>',
#   'its',
#   'productions',
#   'and',
#   'features',
#   'may',
#   'be',
#   'without',
#   'example',
#   ','),
#  ('<MASK>',
#   'its',
#   'productions',
#   'and',
#   'features',
#   'may',
#   'be',
#   'without',
#   'example',
#   ',',
#   'as'),
#  ('its',
#   'productions',
#   'and',
#   'features',
#   'may',
#   'be',
#   'without',
#   'example',
#   ',',
#   'as',
#   'the'),
#  ('productions',
#   'and',
#   'features',
#   'may',
#   'be',
#   'without',
#   'example',
#   ',',
#   'as',
#   'the',
#   'phenomena'),
#  ('and',
#   'features',
#   'may',
#   'be',
#   'without',
#   'example',
#   ',',
#   'as',
#   'the',
#   'phenomena',
#   'of'),
#  ('features',
#   'may',
#   'be',
#   'without',
#   'example',
#   ',',
#   'as',
#   'the',
#   'phenomena',
#   'of',
#   'the'),
#  ('may',
#   'be',
#   'without',
#   'example',
#   ',',
#   'as',
#   'the',
#   'phenomena',
#   'of',
#   'the',
#   'heavenly'),
#  ('be',
#   'without',
#   'example',
#   ',',
#   'as',
#   'the',
#   'phenomena',
#   'of',
#   'the',
#   'heavenly',
#   'bodies'),
#  ('without',
#   'example',
#   ',',
#   'as',
#   'the',
#   'phenomena',
#   'of',
#   'the',
#   'heavenly',
#   'bodies',
#   'undoubtedly'),
#  ('example',
#   ',',
#   'as',
#   'the',
#   'phenomena',
#   'of',
#   'the',
#   'heavenly',
#   'bodies',
#   'undoubtedly',
#   'are'),
#  (',',
#   'as',
#   'the',
#   'phenomena',
#   'of',
#   'the',
#   'heavenly',
#   'bodies',
#   'undoubtedly',
#   'are',
#   'in'),
#  ('as',
#   'the',
#   'phenomena',
#   'of',
#   'the',
#   'heavenly',
#   'bodies',
#   'undoubtedly',
#   'are',
#   'in',
#   'those'),
#  ('the',
#   'phenomena',
#   'of',
#   'the',
#   'heavenly',
#   'bodies',
#   'undoubtedly',
#   'are',
#   'in',
#   'those',
#   'undiscovered'),
#  ('phenomena',
#   'of',
#   'the',
#   'heavenly',
#   'bodies',
#   'undoubtedly',
#   'are',
#   'in',
#   'those',
#   'undiscovered',
#   'solitudes'),
#  ('of',
#   'the',
#   'heavenly',
#   'bodies',
#   'undoubtedly',
#   'are',
#   'in',
#   'those',
#   'undiscovered',
#   'solitudes',
#   '.'),
#  ('the',
#   'heavenly',
#   'bodies',
#   'undoubtedly',
#   'are',
#   'in',
#   'those',
#   'undiscovered',
#   'solitudes',
#   '.',
#   ''),
#  ('heavenly',
#   'bodies',
#   'undoubtedly',
#   'are',
#   'in',
#   'those',
#   'undiscovered',
#   'solitudes',
#   '.',
#   '',
#   '<MASK>'),
#  ('bodies',
#   'undoubtedly',
#   'are',
#   'in',
#   'those',
#   'undiscovered',
#   'solitudes',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>'),
#  ('undoubtedly',
#   'are',
#   'in',
#   'those',
#   'undiscovered',
#   'solitudes',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('are',
#   'in',
#   'those',
#   'undiscovered',
#   'solitudes',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('in',
#   'those',
#   'undiscovered',
#   'solitudes',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'what',
#   'may',
#   'not',
#   'be',
#   'expected',
#   'in'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'what',
#   'may',
#   'not',
#   'be',
#   'expected',
#   'in',
#   'a'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'what',
#   'may',
#   'not',
#   'be',
#   'expected',
#   'in',
#   'a',
#   'country'),
#  ('<MASK>',
#   '<MASK>',
#   'what',
#   'may',
#   'not',
#   'be',
#   'expected',
#   'in',
#   'a',
#   'country',
#   'of'),
#  ('<MASK>',
#   'what',
#   'may',
#   'not',
#   'be',
#   'expected',
#   'in',
#   'a',
#   'country',
#   'of',
#   'eternal'),
#  ('what',
#   'may',
#   'not',
#   'be',
#   'expected',
#   'in',
#   'a',
#   'country',
#   'of',
#   'eternal',
#   'light'),
#  ('may',
#   'not',
#   'be',
#   'expected',
#   'in',
#   'a',
#   'country',
#   'of',
#   'eternal',
#   'light',
#   '?'),
#  ('not',
#   'be',
#   'expected',
#   'in',
#   'a',
#   'country',
#   'of',
#   'eternal',
#   'light',
#   '?',
#   ''),
#  ('be',
#   'expected',
#   'in',
#   'a',
#   'country',
#   'of',
#   'eternal',
#   'light',
#   '?',
#   '',
#   '<MASK>'),
#  ('expected',
#   'in',
#   'a',
#   'country',
#   'of',
#   'eternal',
#   'light',
#   '?',
#   '',
#   '<MASK>',
#   '<MASK>'),
#  ('in',
#   'a',
#   'country',
#   'of',
#   'eternal',
#   'light',
#   '?',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('a',
#   'country',
#   'of',
#   'eternal',
#   'light',
#   '?',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('country',
#   'of',
#   'eternal',
#   'light',
#   '?',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'i',
#   'may',
#   'there',
#   'discover',
#   'the',
#   'wondrous'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'i',
#   'may',
#   'there',
#   'discover',
#   'the',
#   'wondrous',
#   'power'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'i',
#   'may',
#   'there',
#   'discover',
#   'the',
#   'wondrous',
#   'power',
#   'which'),
#  ('<MASK>',
#   '<MASK>',
#   'i',
#   'may',
#   'there',
#   'discover',
#   'the',
#   'wondrous',
#   'power',
#   'which',
#   'attracts'),
#  ('<MASK>',
#   'i',
#   'may',
#   'there',
#   'discover',
#   'the',
#   'wondrous',
#   'power',
#   'which',
#   'attracts',
#   'the'),
#  ('i',
#   'may',
#   'there',
#   'discover',
#   'the',
#   'wondrous',
#   'power',
#   'which',
#   'attracts',
#   'the',
#   'needle'),
#  ('may',
#   'there',
#   'discover',
#   'the',
#   'wondrous',
#   'power',
#   'which',
#   'attracts',
#   'the',
#   'needle',
#   'and'),
#  ('there',
#   'discover',
#   'the',
#   'wondrous',
#   'power',
#   'which',
#   'attracts',
#   'the',
#   'needle',
#   'and',
#   'may'),
#  ('discover',
#   'the',
#   'wondrous',
#   'power',
#   'which',
#   'attracts',
#   'the',
#   'needle',
#   'and',
#   'may',
#   'regulate'),
#  ('the',
#   'wondrous',
#   'power',
#   'which',
#   'attracts',
#   'the',
#   'needle',
#   'and',
#   'may',
#   'regulate',
#   'a'),
#  ('wondrous',
#   'power',
#   'which',
#   'attracts',
#   'the',
#   'needle',
#   'and',
#   'may',
#   'regulate',
#   'a',
#   'thousand'),
#  ('power',
#   'which',
#   'attracts',
#   'the',
#   'needle',
#   'and',
#   'may',
#   'regulate',
#   'a',
#   'thousand',
#   'celestial'),
#  ('which',
#   'attracts',
#   'the',
#   'needle',
#   'and',
#   'may',
#   'regulate',
#   'a',
#   'thousand',
#   'celestial',
#   'observations'),
#  ('attracts',
#   'the',
#   'needle',
#   'and',
#   'may',
#   'regulate',
#   'a',
#   'thousand',
#   'celestial',
#   'observations',
#   'that'),
#  ('the',
#   'needle',
#   'and',
#   'may',
#   'regulate',
#   'a',
#   'thousand',
#   'celestial',
#   'observations',
#   'that',
#   'require'),
#  ('needle',
#   'and',
#   'may',
#   'regulate',
#   'a',
#   'thousand',
#   'celestial',
#   'observations',
#   'that',
#   'require',
#   'only'),
#  ('and',
#   'may',
#   'regulate',
#   'a',
#   'thousand',
#   'celestial',
#   'observations',
#   'that',
#   'require',
#   'only',
#   'this'),
#  ('may',
#   'regulate',
#   'a',
#   'thousand',
#   'celestial',
#   'observations',
#   'that',
#   'require',
#   'only',
#   'this',
#   'voyage'),
#  ('regulate',
#   'a',
#   'thousand',
#   'celestial',
#   'observations',
#   'that',
#   'require',
#   'only',
#   'this',
#   'voyage',
#   'to'),
#  ('a',
#   'thousand',
#   'celestial',
#   'observations',
#   'that',
#   'require',
#   'only',
#   'this',
#   'voyage',
#   'to',
#   'render'),
#  ('thousand',
#   'celestial',
#   'observations',
#   'that',
#   'require',
#   'only',
#   'this',
#   'voyage',
#   'to',
#   'render',
#   'their'),
#  ('celestial',
#   'observations',
#   'that',
#   'require',
#   'only',
#   'this',
#   'voyage',
#   'to',
#   'render',
#   'their',
#   'seeming'),
#  ('observations',
#   'that',
#   'require',
#   'only',
#   'this',
#   'voyage',
#   'to',
#   'render',
#   'their',
#   'seeming',
#   'eccentricities'),
#  ('that',
#   'require',
#   'only',
#   'this',
#   'voyage',
#   'to',
#   'render',
#   'their',
#   'seeming',
#   'eccentricities',
#   'consistent'),
#  ('require',
#   'only',
#   'this',
#   'voyage',
#   'to',
#   'render',
#   'their',
#   'seeming',
#   'eccentricities',
#   'consistent',
#   'forever'),
#  ('only',
#   'this',
#   'voyage',
#   'to',
#   'render',
#   'their',
#   'seeming',
#   'eccentricities',
#   'consistent',
#   'forever',
#   '.'),
#  ('this',
#   'voyage',
#   'to',
#   'render',
#   'their',
#   'seeming',
#   'eccentricities',
#   'consistent',
#   'forever',
#   '.',
#   ''),
#  ('voyage',
#   'to',
#   'render',
#   'their',
#   'seeming',
#   'eccentricities',
#   'consistent',
#   'forever',
#   '.',
#   '',
#   '<MASK>'),
#  ('to',
#   'render',
#   'their',
#   'seeming',
#   'eccentricities',
#   'consistent',
#   'forever',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>'),
#  ('render',
#   'their',
#   'seeming',
#   'eccentricities',
#   'consistent',
#   'forever',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('their',
#   'seeming',
#   'eccentricities',
#   'consistent',
#   'forever',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('seeming',
#   'eccentricities',
#   'consistent',
#   'forever',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'i',
#   'shall',
#   'satiate',
#   'my',
#   'ardent',
#   'curiosity'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'i',
#   'shall',
#   'satiate',
#   'my',
#   'ardent',
#   'curiosity',
#   'with'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'i',
#   'shall',
#   'satiate',
#   'my',
#   'ardent',
#   'curiosity',
#   'with',
#   'the'),
#  ('<MASK>',
#   '<MASK>',
#   'i',
#   'shall',
#   'satiate',
#   'my',
#   'ardent',
#   'curiosity',
#   'with',
#   'the',
#   'sight'),
#  ('<MASK>',
#   'i',
#   'shall',
#   'satiate',
#   'my',
#   'ardent',
#   'curiosity',
#   'with',
#   'the',
#   'sight',
#   'of'),
#  ('i',
#   'shall',
#   'satiate',
#   'my',
#   'ardent',
#   'curiosity',
#   'with',
#   'the',
#   'sight',
#   'of',
#   'a'),
#  ('shall',
#   'satiate',
#   'my',
#   'ardent',
#   'curiosity',
#   'with',
#   'the',
#   'sight',
#   'of',
#   'a',
#   'part'),
#  ('satiate',
#   'my',
#   'ardent',
#   'curiosity',
#   'with',
#   'the',
#   'sight',
#   'of',
#   'a',
#   'part',
#   'of'),
#  ('my',
#   'ardent',
#   'curiosity',
#   'with',
#   'the',
#   'sight',
#   'of',
#   'a',
#   'part',
#   'of',
#   'the'),
#  ('ardent',
#   'curiosity',
#   'with',
#   'the',
#   'sight',
#   'of',
#   'a',
#   'part',
#   'of',
#   'the',
#   'world'),
#  ('curiosity',
#   'with',
#   'the',
#   'sight',
#   'of',
#   'a',
#   'part',
#   'of',
#   'the',
#   'world',
#   'never'),
#  ('with',
#   'the',
#   'sight',
#   'of',
#   'a',
#   'part',
#   'of',
#   'the',
#   'world',
#   'never',
#   'before'),
#  ('the',
#   'sight',
#   'of',
#   'a',
#   'part',
#   'of',
#   'the',
#   'world',
#   'never',
#   'before',
#   'visited'),
#  ('sight',
#   'of',
#   'a',
#   'part',
#   'of',
#   'the',
#   'world',
#   'never',
#   'before',
#   'visited',
#   ','),
#  ('of',
#   'a',
#   'part',
#   'of',
#   'the',
#   'world',
#   'never',
#   'before',
#   'visited',
#   ',',
#   'and'),
#  ('a',
#   'part',
#   'of',
#   'the',
#   'world',
#   'never',
#   'before',
#   'visited',
#   ',',
#   'and',
#   'may'),
#  ('part',
#   'of',
#   'the',
#   'world',
#   'never',
#   'before',
#   'visited',
#   ',',
#   'and',
#   'may',
#   'tread'),
#  ('of',
#   'the',
#   'world',
#   'never',
#   'before',
#   'visited',
#   ',',
#   'and',
#   'may',
#   'tread',
#   'a'),
#  ('the',
#   'world',
#   'never',
#   'before',
#   'visited',
#   ',',
#   'and',
#   'may',
#   'tread',
#   'a',
#   'land'),
#  ('world',
#   'never',
#   'before',
#   'visited',
#   ',',
#   'and',
#   'may',
#   'tread',
#   'a',
#   'land',
#   'never'),
#  ('never',
#   'before',
#   'visited',
#   ',',
#   'and',
#   'may',
#   'tread',
#   'a',
#   'land',
#   'never',
#   'before'),
#  ('before',
#   'visited',
#   ',',
#   'and',
#   'may',
#   'tread',
#   'a',
#   'land',
#   'never',
#   'before',
#   'imprinted'),
#  ('visited',
#   ',',
#   'and',
#   'may',
#   'tread',
#   'a',
#   'land',
#   'never',
#   'before',
#   'imprinted',
#   'by'),
#  (',',
#   'and',
#   'may',
#   'tread',
#   'a',
#   'land',
#   'never',
#   'before',
#   'imprinted',
#   'by',
#   'the'),
#  ('and',
#   'may',
#   'tread',
#   'a',
#   'land',
#   'never',
#   'before',
#   'imprinted',
#   'by',
#   'the',
#   'foot'),
#  ('may',
#   'tread',
#   'a',
#   'land',
#   'never',
#   'before',
#   'imprinted',
#   'by',
#   'the',
#   'foot',
#   'of'),
#  ('tread',
#   'a',
#   'land',
#   'never',
#   'before',
#   'imprinted',
#   'by',
#   'the',
#   'foot',
#   'of',
#   'man'),
#  ('a',
#   'land',
#   'never',
#   'before',
#   'imprinted',
#   'by',
#   'the',
#   'foot',
#   'of',
#   'man',
#   '.'),
#  ('land',
#   'never',
#   'before',
#   'imprinted',
#   'by',
#   'the',
#   'foot',
#   'of',
#   'man',
#   '.',
#   ''),
#  ('never',
#   'before',
#   'imprinted',
#   'by',
#   'the',
#   'foot',
#   'of',
#   'man',
#   '.',
#   '',
#   '<MASK>'),
#  ('before',
#   'imprinted',
#   'by',
#   'the',
#   'foot',
#   'of',
#   'man',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>'),
#  ('imprinted',
#   'by',
#   'the',
#   'foot',
#   'of',
#   'man',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('by',
#   'the',
#   'foot',
#   'of',
#   'man',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('the',
#   'foot',
#   'of',
#   'man',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'these',
#   'are',
#   'my',
#   'enticements',
#   ',',
#   'and'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'these',
#   'are',
#   'my',
#   'enticements',
#   ',',
#   'and',
#   'they'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'these',
#   'are',
#   'my',
#   'enticements',
#   ',',
#   'and',
#   'they',
#   'are'),
#  ('<MASK>',
#   '<MASK>',
#   'these',
#   'are',
#   'my',
#   'enticements',
#   ',',
#   'and',
#   'they',
#   'are',
#   'sufficient'),
#  ('<MASK>',
#   'these',
#   'are',
#   'my',
#   'enticements',
#   ',',
#   'and',
#   'they',
#   'are',
#   'sufficient',
#   'to'),
#  ('these',
#   'are',
#   'my',
#   'enticements',
#   ',',
#   'and',
#   'they',
#   'are',
#   'sufficient',
#   'to',
#   'conquer'),
#  ('are',
#   'my',
#   'enticements',
#   ',',
#   'and',
#   'they',
#   'are',
#   'sufficient',
#   'to',
#   'conquer',
#   'all'),
#  ('my',
#   'enticements',
#   ',',
#   'and',
#   'they',
#   'are',
#   'sufficient',
#   'to',
#   'conquer',
#   'all',
#   'fear'),
#  ('enticements',
#   ',',
#   'and',
#   'they',
#   'are',
#   'sufficient',
#   'to',
#   'conquer',
#   'all',
#   'fear',
#   'of'),
#  (',',
#   'and',
#   'they',
#   'are',
#   'sufficient',
#   'to',
#   'conquer',
#   'all',
#   'fear',
#   'of',
#   'danger'),
#  ('and',
#   'they',
#   'are',
#   'sufficient',
#   'to',
#   'conquer',
#   'all',
#   'fear',
#   'of',
#   'danger',
#   'or'),
#  ('they',
#   'are',
#   'sufficient',
#   'to',
#   'conquer',
#   'all',
#   'fear',
#   'of',
#   'danger',
#   'or',
#   'death'),
#  ('are',
#   'sufficient',
#   'to',
#   'conquer',
#   'all',
#   'fear',
#   'of',
#   'danger',
#   'or',
#   'death',
#   'and'),
#  ('sufficient',
#   'to',
#   'conquer',
#   'all',
#   'fear',
#   'of',
#   'danger',
#   'or',
#   'death',
#   'and',
#   'to'),
#  ('to',
#   'conquer',
#   'all',
#   'fear',
#   'of',
#   'danger',
#   'or',
#   'death',
#   'and',
#   'to',
#   'induce'),
#  ('conquer',
#   'all',
#   'fear',
#   'of',
#   'danger',
#   'or',
#   'death',
#   'and',
#   'to',
#   'induce',
#   'me'),
#  ('all',
#   'fear',
#   'of',
#   'danger',
#   'or',
#   'death',
#   'and',
#   'to',
#   'induce',
#   'me',
#   'to'),
#  ('fear',
#   'of',
#   'danger',
#   'or',
#   'death',
#   'and',
#   'to',
#   'induce',
#   'me',
#   'to',
#   'commence'),
#  ('of',
#   'danger',
#   'or',
#   'death',
#   'and',
#   'to',
#   'induce',
#   'me',
#   'to',
#   'commence',
#   'this'),
#  ('danger',
#   'or',
#   'death',
#   'and',
#   'to',
#   'induce',
#   'me',
#   'to',
#   'commence',
#   'this',
#   'laborious'),
#  ('or',
#   'death',
#   'and',
#   'to',
#   'induce',
#   'me',
#   'to',
#   'commence',
#   'this',
#   'laborious',
#   'voyage'),
#  ('death',
#   'and',
#   'to',
#   'induce',
#   'me',
#   'to',
#   'commence',
#   'this',
#   'laborious',
#   'voyage',
#   'with'),
#  ('and',
#   'to',
#   'induce',
#   'me',
#   'to',
#   'commence',
#   'this',
#   'laborious',
#   'voyage',
#   'with',
#   'the'),
#  ('to',
#   'induce',
#   'me',
#   'to',
#   'commence',
#   'this',
#   'laborious',
#   'voyage',
#   'with',
#   'the',
#   'joy'),
#  ('induce',
#   'me',
#   'to',
#   'commence',
#   'this',
#   'laborious',
#   'voyage',
#   'with',
#   'the',
#   'joy',
#   'a'),
#  ('me',
#   'to',
#   'commence',
#   'this',
#   'laborious',
#   'voyage',
#   'with',
#   'the',
#   'joy',
#   'a',
#   'child'),
#  ('to',
#   'commence',
#   'this',
#   'laborious',
#   'voyage',
#   'with',
#   'the',
#   'joy',
#   'a',
#   'child',
#   'feels'),
#  ('commence',
#   'this',
#   'laborious',
#   'voyage',
#   'with',
#   'the',
#   'joy',
#   'a',
#   'child',
#   'feels',
#   'when'),
#  ('this',
#   'laborious',
#   'voyage',
#   'with',
#   'the',
#   'joy',
#   'a',
#   'child',
#   'feels',
#   'when',
#   'he'),
#  ('laborious',
#   'voyage',
#   'with',
#   'the',
#   'joy',
#   'a',
#   'child',
#   'feels',
#   'when',
#   'he',
#   'embarks'),
#  ('voyage',
#   'with',
#   'the',
#   'joy',
#   'a',
#   'child',
#   'feels',
#   'when',
#   'he',
#   'embarks',
#   'in'),
#  ('with',
#   'the',
#   'joy',
#   'a',
#   'child',
#   'feels',
#   'when',
#   'he',
#   'embarks',
#   'in',
#   'a'),
#  ('the',
#   'joy',
#   'a',
#   'child',
#   'feels',
#   'when',
#   'he',
#   'embarks',
#   'in',
#   'a',
#   'little'),
#  ('joy',
#   'a',
#   'child',
#   'feels',
#   'when',
#   'he',
#   'embarks',
# ...
#   'whale',
#   'fishers',
#   'on',
#   'several',
#   'expeditions',
#   'to',
#   'the',
#   'north'),
#  ('accompanied',
#   'the',
#   'whale',
#   'fishers',
#   'on',
#   'several',
#   'expeditions',
#   'to',
#   'the',
#   'north',
#   'sea'),
#  ('the',
#   'whale',
#   'fishers',
#   'on',
#   'several',
#   'expeditions',
#   'to',
#   'the',
#   'north',
#   'sea',
#   'i'),
#  ('whale',
#   'fishers',
#   'on',
#   'several',
#   'expeditions',
#   'to',
#   'the',
#   'north',
#   'sea',
#   'i',
#   'voluntarily'),
#  ('fishers',
#   'on',
#   'several',
#   'expeditions',
#   'to',
#   'the',
#   'north',
#   'sea',
#   'i',
#   'voluntarily',
#   'endured'),
#  ('on',
#   'several',
#   'expeditions',
#   'to',
#   'the',
#   'north',
#   'sea',
#   'i',
#   'voluntarily',
#   'endured',
#   'cold'),
#  ('several',
#   'expeditions',
#   'to',
#   'the',
#   'north',
#   'sea',
#   'i',
#   'voluntarily',
#   'endured',
#   'cold',
#   ','),
#  ('expeditions',
#   'to',
#   'the',
#   'north',
#   'sea',
#   'i',
#   'voluntarily',
#   'endured',
#   'cold',
#   ',',
#   'famine'),
#  ('to',
#   'the',
#   'north',
#   'sea',
#   'i',
#   'voluntarily',
#   'endured',
#   'cold',
#   ',',
#   'famine',
#   ','),
#  ('the',
#   'north',
#   'sea',
#   'i',
#   'voluntarily',
#   'endured',
#   'cold',
#   ',',
#   'famine',
#   ',',
#   'thirst'),
#  ('north',
#   'sea',
#   'i',
#   'voluntarily',
#   'endured',
#   'cold',
#   ',',
#   'famine',
#   ',',
#   'thirst',
#   ','),
#  ('sea',
#   'i',
#   'voluntarily',
#   'endured',
#   'cold',
#   ',',
#   'famine',
#   ',',
#   'thirst',
#   ',',
#   'and'),
#  ('i',
#   'voluntarily',
#   'endured',
#   'cold',
#   ',',
#   'famine',
#   ',',
#   'thirst',
#   ',',
#   'and',
#   'want'),
#  ('voluntarily',
#   'endured',
#   'cold',
#   ',',
#   'famine',
#   ',',
#   'thirst',
#   ',',
#   'and',
#   'want',
#   'of'),
#  ('endured',
#   'cold',
#   ',',
#   'famine',
#   ',',
#   'thirst',
#   ',',
#   'and',
#   'want',
#   'of',
#   'sleep'),
#  ('cold',
#   ',',
#   'famine',
#   ',',
#   'thirst',
#   ',',
#   'and',
#   'want',
#   'of',
#   'sleep',
#   'i'),
#  (',',
#   'famine',
#   ',',
#   'thirst',
#   ',',
#   'and',
#   'want',
#   'of',
#   'sleep',
#   'i',
#   'often'),
#  ('famine',
#   ',',
#   'thirst',
#   ',',
#   'and',
#   'want',
#   'of',
#   'sleep',
#   'i',
#   'often',
#   'worked'),
#  (',',
#   'thirst',
#   ',',
#   'and',
#   'want',
#   'of',
#   'sleep',
#   'i',
#   'often',
#   'worked',
#   'harder'),
#  ('thirst',
#   ',',
#   'and',
#   'want',
#   'of',
#   'sleep',
#   'i',
#   'often',
#   'worked',
#   'harder',
#   'than'),
#  (',',
#   'and',
#   'want',
#   'of',
#   'sleep',
#   'i',
#   'often',
#   'worked',
#   'harder',
#   'than',
#   'the'),
#  ('and',
#   'want',
#   'of',
#   'sleep',
#   'i',
#   'often',
#   'worked',
#   'harder',
#   'than',
#   'the',
#   'common'),
#  ('want',
#   'of',
#   'sleep',
#   'i',
#   'often',
#   'worked',
#   'harder',
#   'than',
#   'the',
#   'common',
#   'sailors'),
#  ('of',
#   'sleep',
#   'i',
#   'often',
#   'worked',
#   'harder',
#   'than',
#   'the',
#   'common',
#   'sailors',
#   'during'),
#  ('sleep',
#   'i',
#   'often',
#   'worked',
#   'harder',
#   'than',
#   'the',
#   'common',
#   'sailors',
#   'during',
#   'the'),
#  ('i',
#   'often',
#   'worked',
#   'harder',
#   'than',
#   'the',
#   'common',
#   'sailors',
#   'during',
#   'the',
#   'day'),
#  ('often',
#   'worked',
#   'harder',
#   'than',
#   'the',
#   'common',
#   'sailors',
#   'during',
#   'the',
#   'day',
#   'and'),
#  ('worked',
#   'harder',
#   'than',
#   'the',
#   'common',
#   'sailors',
#   'during',
#   'the',
#   'day',
#   'and',
#   'devoted'),
#  ('harder',
#   'than',
#   'the',
#   'common',
#   'sailors',
#   'during',
#   'the',
#   'day',
#   'and',
#   'devoted',
#   'my'),
#  ('than',
#   'the',
#   'common',
#   'sailors',
#   'during',
#   'the',
#   'day',
#   'and',
#   'devoted',
#   'my',
#   'nights'),
#  ('the',
#   'common',
#   'sailors',
#   'during',
#   'the',
#   'day',
#   'and',
#   'devoted',
#   'my',
#   'nights',
#   'to'),
#  ('common',
#   'sailors',
#   'during',
#   'the',
#   'day',
#   'and',
#   'devoted',
#   'my',
#   'nights',
#   'to',
#   'the'),
#  ('sailors',
#   'during',
#   'the',
#   'day',
#   'and',
#   'devoted',
#   'my',
#   'nights',
#   'to',
#   'the',
#   'study'),
#  ('during',
#   'the',
#   'day',
#   'and',
#   'devoted',
#   'my',
#   'nights',
#   'to',
#   'the',
#   'study',
#   'of'),
#  ('the',
#   'day',
#   'and',
#   'devoted',
#   'my',
#   'nights',
#   'to',
#   'the',
#   'study',
#   'of',
#   'mathematics'),
#  ('day',
#   'and',
#   'devoted',
#   'my',
#   'nights',
#   'to',
#   'the',
#   'study',
#   'of',
#   'mathematics',
#   ','),
#  ('and',
#   'devoted',
#   'my',
#   'nights',
#   'to',
#   'the',
#   'study',
#   'of',
#   'mathematics',
#   ',',
#   'the'),
#  ('devoted',
#   'my',
#   'nights',
#   'to',
#   'the',
#   'study',
#   'of',
#   'mathematics',
#   ',',
#   'the',
#   'theory'),
#  ('my',
#   'nights',
#   'to',
#   'the',
#   'study',
#   'of',
#   'mathematics',
#   ',',
#   'the',
#   'theory',
#   'of'),
#  ('nights',
#   'to',
#   'the',
#   'study',
#   'of',
#   'mathematics',
#   ',',
#   'the',
#   'theory',
#   'of',
#   'medicine'),
#  ('to',
#   'the',
#   'study',
#   'of',
#   'mathematics',
#   ',',
#   'the',
#   'theory',
#   'of',
#   'medicine',
#   ','),
#  ('the',
#   'study',
#   'of',
#   'mathematics',
#   ',',
#   'the',
#   'theory',
#   'of',
#   'medicine',
#   ',',
#   'and'),
#  ('study',
#   'of',
#   'mathematics',
#   ',',
#   'the',
#   'theory',
#   'of',
#   'medicine',
#   ',',
#   'and',
#   'those'),
#  ('of',
#   'mathematics',
#   ',',
#   'the',
#   'theory',
#   'of',
#   'medicine',
#   ',',
#   'and',
#   'those',
#   'branches'),
#  ('mathematics',
#   ',',
#   'the',
#   'theory',
#   'of',
#   'medicine',
#   ',',
#   'and',
#   'those',
#   'branches',
#   'of'),
#  (',',
#   'the',
#   'theory',
#   'of',
#   'medicine',
#   ',',
#   'and',
#   'those',
#   'branches',
#   'of',
#   'physical'),
#  ('the',
#   'theory',
#   'of',
#   'medicine',
#   ',',
#   'and',
#   'those',
#   'branches',
#   'of',
#   'physical',
#   'science'),
#  ('theory',
#   'of',
#   'medicine',
#   ',',
#   'and',
#   'those',
#   'branches',
#   'of',
#   'physical',
#   'science',
#   'from'),
#  ('of',
#   'medicine',
#   ',',
#   'and',
#   'those',
#   'branches',
#   'of',
#   'physical',
#   'science',
#   'from',
#   'which'),
#  ('medicine',
#   ',',
#   'and',
#   'those',
#   'branches',
#   'of',
#   'physical',
#   'science',
#   'from',
#   'which',
#   'a'),
#  (',',
#   'and',
#   'those',
#   'branches',
#   'of',
#   'physical',
#   'science',
#   'from',
#   'which',
#   'a',
#   'naval'),
#  ('and',
#   'those',
#   'branches',
#   'of',
#   'physical',
#   'science',
#   'from',
#   'which',
#   'a',
#   'naval',
#   'adventurer'),
#  ('those',
#   'branches',
#   'of',
#   'physical',
#   'science',
#   'from',
#   'which',
#   'a',
#   'naval',
#   'adventurer',
#   'might'),
#  ('branches',
#   'of',
#   'physical',
#   'science',
#   'from',
#   'which',
#   'a',
#   'naval',
#   'adventurer',
#   'might',
#   'derive'),
#  ('of',
#   'physical',
#   'science',
#   'from',
#   'which',
#   'a',
#   'naval',
#   'adventurer',
#   'might',
#   'derive',
#   'the'),
#  ('physical',
#   'science',
#   'from',
#   'which',
#   'a',
#   'naval',
#   'adventurer',
#   'might',
#   'derive',
#   'the',
#   'greatest'),
#  ('science',
#   'from',
#   'which',
#   'a',
#   'naval',
#   'adventurer',
#   'might',
#   'derive',
#   'the',
#   'greatest',
#   'practical'),
#  ('from',
#   'which',
#   'a',
#   'naval',
#   'adventurer',
#   'might',
#   'derive',
#   'the',
#   'greatest',
#   'practical',
#   'advantage'),
#  ('which',
#   'a',
#   'naval',
#   'adventurer',
#   'might',
#   'derive',
#   'the',
#   'greatest',
#   'practical',
#   'advantage',
#   '.'),
#  ('a',
#   'naval',
#   'adventurer',
#   'might',
#   'derive',
#   'the',
#   'greatest',
#   'practical',
#   'advantage',
#   '.',
#   ''),
#  ('naval',
#   'adventurer',
#   'might',
#   'derive',
#   'the',
#   'greatest',
#   'practical',
#   'advantage',
#   '.',
#   '',
#   '<MASK>'),
#  ('adventurer',
#   'might',
#   'derive',
#   'the',
#   'greatest',
#   'practical',
#   'advantage',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>'),
#  ('might',
#   'derive',
#   'the',
#   'greatest',
#   'practical',
#   'advantage',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('derive',
#   'the',
#   'greatest',
#   'practical',
#   'advantage',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('the',
#   'greatest',
#   'practical',
#   'advantage',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'twice',
#   'i',
#   'actually',
#   'hired',
#   'myself',
#   'as'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'twice',
#   'i',
#   'actually',
#   'hired',
#   'myself',
#   'as',
#   'an'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'twice',
#   'i',
#   'actually',
#   'hired',
#   'myself',
#   'as',
#   'an',
#   'under'),
#  ('<MASK>',
#   '<MASK>',
#   'twice',
#   'i',
#   'actually',
#   'hired',
#   'myself',
#   'as',
#   'an',
#   'under',
#   'mate'),
#  ('<MASK>',
#   'twice',
#   'i',
#   'actually',
#   'hired',
#   'myself',
#   'as',
#   'an',
#   'under',
#   'mate',
#   'in'),
#  ('twice',
#   'i',
#   'actually',
#   'hired',
#   'myself',
#   'as',
#   'an',
#   'under',
#   'mate',
#   'in',
#   'a'),
#  ('i',
#   'actually',
#   'hired',
#   'myself',
#   'as',
#   'an',
#   'under',
#   'mate',
#   'in',
#   'a',
#   'greenland'),
#  ('actually',
#   'hired',
#   'myself',
#   'as',
#   'an',
#   'under',
#   'mate',
#   'in',
#   'a',
#   'greenland',
#   'whaler'),
#  ('hired',
#   'myself',
#   'as',
#   'an',
#   'under',
#   'mate',
#   'in',
#   'a',
#   'greenland',
#   'whaler',
#   ','),
#  ('myself',
#   'as',
#   'an',
#   'under',
#   'mate',
#   'in',
#   'a',
#   'greenland',
#   'whaler',
#   ',',
#   'and'),
#  ('as',
#   'an',
#   'under',
#   'mate',
#   'in',
#   'a',
#   'greenland',
#   'whaler',
#   ',',
#   'and',
#   'acquitted'),
#  ('an',
#   'under',
#   'mate',
#   'in',
#   'a',
#   'greenland',
#   'whaler',
#   ',',
#   'and',
#   'acquitted',
#   'myself'),
#  ('under',
#   'mate',
#   'in',
#   'a',
#   'greenland',
#   'whaler',
#   ',',
#   'and',
#   'acquitted',
#   'myself',
#   'to'),
#  ('mate',
#   'in',
#   'a',
#   'greenland',
#   'whaler',
#   ',',
#   'and',
#   'acquitted',
#   'myself',
#   'to',
#   'admiration'),
#  ('in',
#   'a',
#   'greenland',
#   'whaler',
#   ',',
#   'and',
#   'acquitted',
#   'myself',
#   'to',
#   'admiration',
#   '.'),
#  ('a',
#   'greenland',
#   'whaler',
#   ',',
#   'and',
#   'acquitted',
#   'myself',
#   'to',
#   'admiration',
#   '.',
#   ''),
#  ('greenland',
#   'whaler',
#   ',',
#   'and',
#   'acquitted',
#   'myself',
#   'to',
#   'admiration',
#   '.',
#   '',
#   '<MASK>'),
#  ('whaler',
#   ',',
#   'and',
#   'acquitted',
#   'myself',
#   'to',
#   'admiration',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>'),
#  (',',
#   'and',
#   'acquitted',
#   'myself',
#   'to',
#   'admiration',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('and',
#   'acquitted',
#   'myself',
#   'to',
#   'admiration',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('acquitted',
#   'myself',
#   'to',
#   'admiration',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'i',
#   'must',
#   'own',
#   'i',
#   'felt',
#   'a'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'i',
#   'must',
#   'own',
#   'i',
#   'felt',
#   'a',
#   'little'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'i',
#   'must',
#   'own',
#   'i',
#   'felt',
#   'a',
#   'little',
#   'proud'),
#  ('<MASK>',
#   '<MASK>',
#   'i',
#   'must',
#   'own',
#   'i',
#   'felt',
#   'a',
#   'little',
#   'proud',
#   'when'),
#  ('<MASK>',
#   'i',
#   'must',
#   'own',
#   'i',
#   'felt',
#   'a',
#   'little',
#   'proud',
#   'when',
#   'my'),
#  ('i',
#   'must',
#   'own',
#   'i',
#   'felt',
#   'a',
#   'little',
#   'proud',
#   'when',
#   'my',
#   'captain'),
#  ('must',
#   'own',
#   'i',
#   'felt',
#   'a',
#   'little',
#   'proud',
#   'when',
#   'my',
#   'captain',
#   'offered'),
#  ('own',
#   'i',
#   'felt',
#   'a',
#   'little',
#   'proud',
#   'when',
#   'my',
#   'captain',
#   'offered',
#   'me'),
#  ('i',
#   'felt',
#   'a',
#   'little',
#   'proud',
#   'when',
#   'my',
#   'captain',
#   'offered',
#   'me',
#   'the'),
#  ('felt',
#   'a',
#   'little',
#   'proud',
#   'when',
#   'my',
#   'captain',
#   'offered',
#   'me',
#   'the',
#   'second'),
#  ('a',
#   'little',
#   'proud',
#   'when',
#   'my',
#   'captain',
#   'offered',
#   'me',
#   'the',
#   'second',
#   'dignity'),
#  ('little',
#   'proud',
#   'when',
#   'my',
#   'captain',
#   'offered',
#   'me',
#   'the',
#   'second',
#   'dignity',
#   'in'),
#  ('proud',
#   'when',
#   'my',
#   'captain',
#   'offered',
#   'me',
#   'the',
#   'second',
#   'dignity',
#   'in',
#   'the'),
#  ('when',
#   'my',
#   'captain',
#   'offered',
#   'me',
#   'the',
#   'second',
#   'dignity',
#   'in',
#   'the',
#   'vessel'),
#  ('my',
#   'captain',
#   'offered',
#   'me',
#   'the',
#   'second',
#   'dignity',
#   'in',
#   'the',
#   'vessel',
#   'and'),
#  ('captain',
#   'offered',
#   'me',
#   'the',
#   'second',
#   'dignity',
#   'in',
#   'the',
#   'vessel',
#   'and',
#   'entreated'),
#  ('offered',
#   'me',
#   'the',
#   'second',
#   'dignity',
#   'in',
#   'the',
#   'vessel',
#   'and',
#   'entreated',
#   'me'),
#  ('me',
#   'the',
#   'second',
#   'dignity',
#   'in',
#   'the',
#   'vessel',
#   'and',
#   'entreated',
#   'me',
#   'to'),
#  ('the',
#   'second',
#   'dignity',
#   'in',
#   'the',
#   'vessel',
#   'and',
#   'entreated',
#   'me',
#   'to',
#   'remain'),
#  ('second',
#   'dignity',
#   'in',
#   'the',
#   'vessel',
#   'and',
#   'entreated',
#   'me',
#   'to',
#   'remain',
#   'with'),
#  ('dignity',
#   'in',
#   'the',
#   'vessel',
#   'and',
#   'entreated',
#   'me',
#   'to',
#   'remain',
#   'with',
#   'the'),
#  ('in',
#   'the',
#   'vessel',
#   'and',
#   'entreated',
#   'me',
#   'to',
#   'remain',
#   'with',
#   'the',
#   'greatest'),
#  ('the',
#   'vessel',
#   'and',
#   'entreated',
#   'me',
#   'to',
#   'remain',
#   'with',
#   'the',
#   'greatest',
#   'earnestness'),
#  ('vessel',
#   'and',
#   'entreated',
#   'me',
#   'to',
#   'remain',
#   'with',
#   'the',
#   'greatest',
#   'earnestness',
#   ','),
#  ('and',
#   'entreated',
#   'me',
#   'to',
#   'remain',
#   'with',
#   'the',
#   'greatest',
#   'earnestness',
#   ',',
#   'so'),
#  ('entreated',
#   'me',
#   'to',
#   'remain',
#   'with',
#   'the',
#   'greatest',
#   'earnestness',
#   ',',
#   'so',
#   'valuable'),
#  ('me',
#   'to',
#   'remain',
#   'with',
#   'the',
#   'greatest',
#   'earnestness',
#   ',',
#   'so',
#   'valuable',
#   'did'),
#  ('to',
#   'remain',
#   'with',
#   'the',
#   'greatest',
#   'earnestness',
#   ',',
#   'so',
#   'valuable',
#   'did',
#   'he'),
#  ('remain',
#   'with',
#   'the',
#   'greatest',
#   'earnestness',
#   ',',
#   'so',
#   'valuable',
#   'did',
#   'he',
#   'consider'),
#  ('with',
#   'the',
#   'greatest',
#   'earnestness',
#   ',',
#   'so',
#   'valuable',
#   'did',
#   'he',
#   'consider',
#   'my'),
#  ('the',
#   'greatest',
#   'earnestness',
#   ',',
#   'so',
#   'valuable',
#   'did',
#   'he',
#   'consider',
#   'my',
#   'services'),
#  ('greatest',
#   'earnestness',
#   ',',
#   'so',
#   'valuable',
#   'did',
#   'he',
#   'consider',
#   'my',
#   'services',
#   '.'),
#  ('earnestness',
#   ',',
#   'so',
#   'valuable',
#   'did',
#   'he',
#   'consider',
#   'my',
#   'services',
#   '.',
#   ''),
#  (',',
#   'so',
#   'valuable',
#   'did',
#   'he',
#   'consider',
#   'my',
#   'services',
#   '.',
#   '',
#   '<MASK>'),
#  ('so',
#   'valuable',
#   'did',
#   'he',
#   'consider',
#   'my',
#   'services',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>'),
#  ('valuable',
#   'did',
#   'he',
#   'consider',
#   'my',
#   'services',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('did',
#   'he',
#   'consider',
#   'my',
#   'services',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('he',
#   'consider',
#   'my',
#   'services',
#   '.',
#   '',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'and',
#   'now',
#   ',',
#   'dear',
#   'margaret',
#   ','),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'and',
#   'now',
#   ',',
#   'dear',
#   'margaret',
#   ',',
#   'do'),
#  ('<MASK>',
#   '<MASK>',
#   '<MASK>',
#   'and',
#   'now',
#   ',',
#   'dear',
#   'margaret',
#   ',',
#   'do',
#   'i'),
#  ('<MASK>',
#   '<MASK>',
#   'and',
#   'now',
#   ',',
#   'dear',
#   'margaret',
#   ',',
#   'do',
#   'i',
#   'not'),
#  ('<MASK>',
#   'and',
#   'now',
#   ',',
#   'dear',
#   'margaret',
#   ',',
#   'do',
#   'i',
#   'not',
#   'deserve'),
#  ('and',
#   'now',
#   ',',
#   'dear',
#   'margaret',
#   ',',
#   'do',
#   'i',
#   'not',
#   'deserve',
#   'to'),
#  ('now',
#   ',',
#   'dear',
#   'margaret',
#   ',',
#   'do',
#   'i',
#   'not',
#   'deserve',
#   'to',
#   'accomplish'),
#  (',',
#   'dear',
#   'margaret',
#   ',',
#   'do',
#   'i',
#   'not',
#   'deserve',
#   'to',
#   'accomplish',
#   'some'),
#  ('dear',
#   'margaret',
#   ',',
#   'do',
#   'i',
#   'not',
#   'deserve',
#   'to',
#   'accomplish',
#   'some',
#   'great'),
#  ('margaret',
#   ',',
#   'do',
#   'i',
#   'not',
#   'deserve',
#   'to',
#   'accomplish',
#   'some',
#   'great',
#   'purpose'),
#  (',',
#   'do',
#   'i',
#   'not',
#   'deserve',
#   'to',
#   'accomplish',
#   'some',
#   'great',
#   'purpose',
#   '?'),
#  ('do',
#   'i',
#   'not',
#   'deserve',
#   'to',
#   'accomplish',
#   'some',
#   'great',
#   'purpose',
#   '?',
#   ''),
#  ('i',
#   'not',
#   'deserve',
#   'to',
#   'accomplish',
#   'some',
#   'great',
#   'purpose',
#   '?',
#   '',
#   '<MASK>'),
#  ('not',
#   'deserve',
#   'to',
#   'accomplish',
#   'some',
#   'great',
#   'purpose',
#   '?',
#   '',
#   '<MASK>',
#   '<MASK>'),
#  ...]

# %%
# Create split data
n = len(cbow_data)
def get_split(row_num):
    if row_num <= n*args.train_proportion:
        return 'train'
    elif (row_num > n*args.train_proportion) and (row_num <= n*args.train_proportion + n*args.val_proportion):
        return 'val'
    else:
        return 'test'
cbow_data['split']= cbow_data.apply(lambda row: get_split(row.name), axis=1)  # axis=1: apply function to columns axis

# %%
cbow_data.head()  # in cbow, predict the target "frankenstein" with the context words ", or the modern prometheus"
# Out:
#                                              context        target  split
# 0                         , or the modern prometheus  frankenstein  train
# 1           frankenstein or the modern prometheus by             ,  train
# 2       frankenstein , the modern prometheus by mary            or  train
# 3  frankenstein , or modern prometheus by mary wo...           the  train
# 4  frankenstein , or the prometheus by mary wolls...        modern  train

# %%
cleaned_sentences[0]
# Out:
# 'frankenstein , or the modern prometheus by mary wollstonecraft godwin shelley letter st . petersburgh , dec . th , to mrs . saville , england you will rejoice to hear that no disaster has accompanied the commencement of an enterprise which you have regarded with such evil forebodings . '

# %%
# Write split data to file
cbow_data.to_csv(args.output_munged_csv, index=False)
